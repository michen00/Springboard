# %% [markdown]
# # Contents
# * [Introduction](#Introduction)
# * [Imports and configuration](#Imports-and-configuration)
# * [Setup](#Setup)
# * [Alpha](#Alpha)
# * [Discussion](#Discussion)

# %% [markdown]
# # Introduction
#
# This is a post hoc tuning after seeing disappointing holdout results. We dropped ridge earlier for simplicity and speed, but now it's back in.
#
# Since I'm close to wrapping up at this point, we'll do a quick tune and won't stop to evaluate too much.

# %%
from time import time

notebook_begin_time = time()

# set random seeds

from os import environ
from random import seed as random_seed
from numpy.random import seed as np_seed
from tensorflow.random import set_seed


def reset_seeds(seed: int) -> None:
    """Utility function for resetting random seeds"""
    environ["PYTHONHASHSEED"] = str(seed)
    random_seed(seed)
    np_seed(seed)
    set_seed(seed)


reset_seeds(SEED := 2022)
del environ
del random_seed
del np_seed
del set_seed
del reset_seeds

# %%
# extensions
# %load_ext autotime
# %load_ext lab_black
# %load_ext nb_black

# %%
# core
import numpy as np
import pandas as pd
from scipy.stats import loguniform

# utility
from copy import deepcopy
from gc import collect as gc_collect

# faster sklearn
from sklearnex import patch_sklearn

patch_sklearn()
del patch_sklearn

import swifter

# typing
from typing import Dict, List, Sequence

# other sklearn
from sklearn.calibration import CalibratedClassifierCV
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedGroupKFold

# params
from scipy.stats import loguniform, uniform

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib widget

sns.set_context("notebook")

# full display of rows and columns
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)

# display outputs w/o print calls
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
del InteractiveShell
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# time: 3.53 s

# %%
# Location of FRILL .feather files
FRILL_FEATHERS_FOLDER = "../1.0-mic-extract_FRILL_embeddings"

# Location of pre-final labels and features
FEATURES_FOLDER = "."

# Location where this notebook will output
DATA_OUT_FOLDER = "."

_ = gc_collect()
# Out:
# time: 137 ms

# %% [markdown]
# # Setup

# %%
def load_labels() -> pd.DataFrame:
    """Load just the labels"""
    return pd.read_feather(f"{FEATURES_FOLDER}/simplified_labels.feather").set_index(
        "id"
    )


def load_data() -> pd.DataFrame:
    """Loads the FRILL-based features"""
    df = pd.read_feather(
        f"{FEATURES_FOLDER}/scaled_features_ready_for_selection.feather"
    ).set_index("id")
    df.columns = df.columns.astype(str)
    return df


data = load_data()
labels = load_labels()
assert all(data.index == labels.index)
assert len(data) < 79000
y_true = labels.valence
_ = gc_collect()
# Out:
# time: 162 ms

# %%
data.info()
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# UInt64Index: 78777 entries, 0 to 87363
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     78777 non-null  float64
#  1   LDA2                     78777 non-null  float64
#  2   ocLDA_neg                78777 non-null  float64
#  3   ocLDA_neu                78777 non-null  float64
#  4   ocLDA_pos                78777 non-null  float64
#  5   ocSVM_sgdlinear_LDA1     78777 non-null  float64
#  6   ocSVM_sgdlinear_LDA2     78777 non-null  float64
#  7   ocSVM_sgdlinear_neg      78777 non-null  float64
#  8   ocSVM_sgdlinear_neu      78777 non-null  float64
#  9   ocSVM_sgdlinear_pos      78777 non-null  float64
#  10  LDA-LOF_neg_30           78777 non-null  float64
#  11  LDA-LOF_neu_30           78777 non-null  float64
#  12  LDA-LOF_pos_30           78777 non-null  float64
#  13  LDA-ocSVM_sgdlinear_neg  78777 non-null  float64
#  14  LDA-ocSVM_sgdlinear_neu  78777 non-null  float64
#  15  LDA-ocSVM_sgdlinear_pos  78777 non-null  float64
#  16  LDA-ocSVM_rbf_neg        78777 non-null  float64
#  17  LDA-ocSVM_rbf_neu        78777 non-null  float64
#  18  LDA-ocSVM_rbf_pos        78777 non-null  float64
#  19  LDA-ocSVM_sigmoid_neg    78777 non-null  float64
#  20  LDA-ocSVM_sigmoid_neu    78777 non-null  float64
#  21  LDA-ocSVM_sigmoid_pos    78777 non-null  float64
#  22  LDA-ocSVM_poly5_neg      78777 non-null  float64
#  23  LDA-ocSVM_poly5_neu      78777 non-null  float64
#  24  LDA-ocSVM_poly5_pos      78777 non-null  float64
#  25  LDA-ocSVM_poly6_neg      78777 non-null  float64
#  26  LDA-ocSVM_poly6_neu      78777 non-null  float64
#  27  LDA-ocSVM_poly6_pos      78777 non-null  float64
#  28  spherical-LDA1           78777 non-null  float64
#  29  spherical-LDA2           78777 non-null  float64
#  30  spherical-ocLDA_neg      78777 non-null  float64
#  31  spherical-ocLDA_neu      78777 non-null  float64
#  32  spherical-ocLDA_pos      78777 non-null  float64
# dtypes: float64(33)
# memory usage: 20.4 MB
# <class 'pandas.core.frame.DataFrame'>
# UInt64Index: 78777 entries, 0 to 87363
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   source          78777 non-null  category
#  1   speaker_id      78777 non-null  category
#  2   speaker_gender  78777 non-null  category
#  3   emo             78777 non-null  category
#  4   valence         78777 non-null  int8
#  5   neg             78777 non-null  bool
#  6   neu             78777 non-null  bool
#  7   pos             78777 non-null  bool
#  8   lang1           78777 non-null  category
#  9   length          78777 non-null  category
# dtypes: bool(3), category(6), int8(1)
# memory usage: 1.5 MB
# time: 26.1 ms

# %% [markdown]
# # Strata

# %%
N_SPLITS = 7

# fields are concatentated for quick permutation omitting non-existent combos
strata = labels.loc[
    :, ["source", "speaker_gender", "emo", "valence", "lang1", "length"]
]
strata.valence = strata.valence.astype(str)
strata = strata.swifter.apply("".join, axis=1)
# Out:
# Pandas Apply: 100%|██████████| 78777/78777 [00:01<00:00, 73781.92it/s]
# time: 1.16 s

# %%
# utility function for identifying strata with only i occurences
def get_solo(i: int, strata_: pd.Series) -> np.ndarray:
    """Given a series of stratum memberships, return a shuffled array of strata with only i members."""
    return np.unique(
        strata_.loc[
            strata_.isin(
                (strata_counts := strata_.value_counts())
                .where(strata_counts == i)
                .dropna()
                .index
            )
        ]
        .sample(frac=1, random_state=SEED)
        .values
    )


# get solos, print stuff
def get_onlys(
    strata_: pd.Series, print_me: str = "", n_splits: int = N_SPLITS
) -> List[Dict[int, np.ndarray]]:
    """Optinally prints something and returns calls of get_solo on strata_ in a list"""
    print(print_me)
    solos = []
    for i in range(1, n_splits):
        solo: np.ndarray = get_solo(i, strata_)
        print(f"only {i}:", (_ := solo.size))
        if _:  # >= 1 strata with only i samples
            solos.append({i: solo})
    return solos


def process_strata(strata: pd.Series, n_splits: int = N_SPLITS) -> pd.Series:
    """Corrects strata membership column according to n_splits"""

    count = get_onlys_calls = 0

    while onlys := get_onlys(
        strata,
        print_me=f"merge passes performed: {get_onlys_calls}",
        n_splits=n_splits,
    ):
        get_onlys_calls += 1
        if len(onlys) == 1:
            last = onlys[0]
            strata_to_merge: np.ndarray = list(last.values())[0]
            only_key = list(last.keys())[0]
            tuplet_size = n_splits // only_key + (1 if n_splits % only_key else 0)
            # perform tuplet merge
            interval = len(strata_to_merge) // n_splits
            for strata_tuplet in zip(
                *[
                    strata_to_merge[interval * i : interval * (i + 1)]
                    for i in range(tuplet_size)
                ]
            ):
                strata = strata.replace(strata_tuplet, f"stratum_group_{count}")
                count += 1
            remainder = strata_to_merge[tuplet_size * interval :]
            if len(remainder) == 1:
                # process remainder unmatched
                n = n_splits
                strata_counts = strata.value_counts()
                while not (candidates := strata_counts.loc[strata_counts == n]).size:
                    n += 1
                strata = strata.replace(
                    [remainder[0], candidates.sample(n=1, random_state=SEED).index[0]],
                    f"stratum_group_{count}",
                )
                count += 1
            else:
                # self-pair last
                remainder = remainder.tolist()
                while len(remainder) >= 2:
                    strata = strata.replace(
                        (remainder.pop(), remainder.pop()), f"stratum_group_{count}"
                    )
                    count += 1
        else:
            pop_onlys = lambda _: list(onlys.pop(_).values())[0].tolist()
            while len(onlys) >= 2:
                # pop the ends
                shortside = pop_onlys(0)
                longside = pop_onlys(-1)
                # merge until one end empty
                while shortside and longside:
                    strata = strata.replace(
                        (shortside.pop(), longside.pop()), f"stratum_group_{count}"
                    )
                    count += 1
            if onlys:
                # self-pair middle
                remainder = pop_onlys(0)
                while len(remainder) >= 2:
                    strata = strata.replace(
                        (remainder.pop(), remainder.pop()), f"stratum_group_{count}"
                    )
                    count += 1
    return strata


_ = gc_collect()
# Out:
# time: 104 ms

# %%
STRATA = process_strata(strata, n_splits=N_SPLITS)
STRATA.value_counts()
cross_validator = lambda: StratifiedGroupKFold(
    n_splits=N_SPLITS, shuffle=True, random_state=SEED
).split(X=data, y=STRATA, groups=labels.speaker_id)
# Out:
# merge passes performed: 0
# only 1: 49
# only 2: 34
# only 3: 30
# only 4: 15
# only 5: 26
# only 6: 12
# merge passes performed: 1
# only 1: 37
# only 2: 8
# only 3: 15
# only 4: 0
# only 5: 0
# only 6: 0
# merge passes performed: 2
# only 1: 22
# only 2: 0
# only 3: 0
# only 4: 19
# only 5: 0
# only 6: 0
# merge passes performed: 3
# only 1: 3
# only 2: 0
# only 3: 0
# only 4: 0
# only 5: 19
# only 6: 0
# merge passes performed: 4
# only 1: 0
# only 2: 0
# only 3: 0
# only 4: 0
# only 5: 16
# only 6: 3
# merge passes performed: 5
# only 1: 0
# only 2: 0
# only 3: 0
# only 4: 0
# only 5: 13
# only 6: 0
# merge passes performed: 6
# only 1: 0
# only 2: 0
# only 3: 0
# only 4: 0
# only 5: 1
# only 6: 0
# merge passes performed: 7
# only 1: 0
# only 2: 0
# only 3: 0
# only 4: 0
# only 5: 0
# only 6: 0
# MELDmneu1engmedium               2905
# MELDfneu1engmedium               2452
# esdfneu1engmedium                1750
# esdfhap2engmedium                1750
# esdmneu1cmnmedium                1750
# esdmhap2cmnmedium                1750
# esdmang0cmnmedium                1750
# esdfneu1cmnmedium                1749
# esdfhap2cmnmedium                1749
# esdfang0engmedium                1748
# esdmneu1engmedium                1747
# esdfang0cmnmedium                1747
# esdmang0engmedium                1746
# esdmhap2engmedium                1744
# esdfsad0engmedium                1744
# esdmsad0engmedium                1735
# esdmsad0cmnmedium                1713
# LEGOv2fneu1engmedium             1673
# esdfsad0cmnmedium                1474
# LEGOv2mneu1engmedium             1309
# MELDfhap2engmedium                931
# MELDmhap2engmedium                908
# EmoV-DB_sortedmneu1engmedium      782
# EmoV-DB_sortedfang0engmedium      722
# EmoV-DB_sortedfneu1engmedium      671
# CREMA-Dmdis0engmedium             660
# MELDfang0engmedium                655
# CREMA-Dmhap2engmedium             649
# MELDmang0engmedium                643
# CREMA-Dmang0engmedium             641
# CREMA-Dfhap2engmedium             596
# CREMA-Dfdis0engmedium             593
# CREMA-Dfang0engmedium             586
# CREMA-Dffea0engmedium             583
# CREMA-Dmfea0engmedium             582
# CREMA-Dmneu1engmedium             575
# ShEMOmneu1pesmedium               546
# CREMA-Dfneu1engmedium             512
# LEGOv2fang0engmedium              509
# ShEMOmang0pesmedium               499
# CREMA-Dfsad0engmedium             484
# EmoV-DB_sortedmang0engmedium      447
# MELDmneu1englong                  427
# MELDfsad0engmedium                417
# CREMA-Dmsad0engmedium             411
# EmoV-DB_sortedfamu2engmedium      410
# tessfdis0engmedium                400
# tessfsad0engmedium                400
# tessfhap2engmedium                400
# tessfneu1engmedium                400
# tessfang0engmedium                400
# tessfsur2engmedium                400
# tessffea0engmedium                400
# EmoV-DB_sortedmamu2englong        399
# EmoV-DB_sortedmamu2engmedium      396
# MELDmsur0engmedium                383
# ShEMOfang0pesmedium               378
# MELDfsur0engmedium                369
# EmoV-DB_sortedmdis0englong        368
# MELDfsur2engmedium                365
# MELDfneu1englong                  355
# LEGOv2mang0engmedium              346
# MELDmsad0engmedium                346
# EmoV-DB_sortedfdis0engmedium      302
# MELDmsur2engmedium                287
# esdfsad0cmnlong                   276
# ekorpusfang0estmedium             244
# MESSmang0engmedium                225
# MESSfsad0engmedium                225
# MESSmsad0engmedium                225
# MESSmhap2engmedium                225
# MESSfhap2engmedium                225
# MESSfang0engmedium                225
# EmoV-DB_sortedfdis0englong        220
# ekorpusfhap2estmedium             210
# ShEMOfsad0pesmedium               203
# EmoReact_V_1.0funk2engmedium      202
# LEGOv2uneu1engmedium              199
# vivaefple2___medium               196
# ravdessmhap2engmedium             192
# ravdessmfea0engmedium             192
# MESSfcal2engmedium                192
# ravdessmang0engmedium             192
# ravdessmsad0engmedium             191
# ravdessmcal1engmedium             190
# ravdessfhap2engmedium             184
# ravdessfsad0engmedium             184
# ravdessfang0engmedium             184
# ravdessffea0engmedium             184
# ekorpusfsad0estmedium             183
# ravdessfcal1engmedium             182
# ShEMOfneu1pesmedium               178
# MELDmhap2englong                  170
# enterface_dbmang0engmedium        169
# MESSmcal2engmedium                167
# MELDmfea0engmedium                167
# enterface_dbmhap2engmedium        167
# enterface_dbmdis0engmedium        167
# enterface_dbmfea0engmedium        167
# vivaefpai0___medium               166
# enterface_dbmsad0engmedium        164
# vivaefsur2___medium               164
# ShEMOmneu1peslong                 163
# vivaefang0___medium               157
# EmoReact_V_1.0munk2engmedium      154
# MELDfhap2englong                  153
# MELDfdis0engmedium                146
# vivaefach2___medium               143
# vivaeffea0___medium               139
# MELDffea0engmedium                129
# EmoV-DB_sortedmdis0engmedium      128
# MELDmdis0engmedium                123
# MELDfsad0englong                  122
# jl-corpusfanx0engmedium           120
# jl-corpusfapo0engmedium           120
# jl-corpusmsad0engmedium           120
# jl-corpusfang0engmedium           120
# jl-corpusfhap2engmedium           120
# jl-corpusfexc2engmedium           120
# jl-corpusmapo0engmedium           120
# jl-corpusfsad0engmedium           120
# jl-corpusmneu1engmedium           120
# jl-corpusmanx0engmedium           120
# jl-corpusfneu1engmedium           120
# jl-corpusmhap2engmedium           120
# jl-corpusmexc2engmedium           120
# MELDfang0englong                  120
# jl-corpusmang0engmedium           120
# ekorpusfneu1estmedium             115
# saveemneu1engmedium               113
# MELDmang0englong                  113
# EmoReact_V_1.0funk0engmedium      111
# EmoV-DB_sortedfamu2englong        108
# ShEMOmsad0pesmedium               104
# Emotional_EMAfang0engmedium       104
# EmoV-DB_sortedfneu1englong        103
# urdumang0urdmedium                100
# Emotional_EMAfhap2engmedium        97
# ravdessfdis0engmedium              96
# urdumneu1urdmedium                 96
# ravdessmdis0engmedium              96
# ravdessmneu1engmedium              96
# EmoReact_V_1.0munk0engmedium       95
# Emotional_EMAfneu1engmedium        94
# urdumsad0urdmedium                 94
# ShEMOfhap2pesmedium                93
# ravdessfneu1engmedium              92
# EYASEmneu1arzmedium                88
# EYASEmang0arzmedium                88
# ShEMOmang0peslong                  86
# EYASEmsad0arzmedium                86
# BAUM1fsad0turmedium                85
# Emotional_EMAfsad0engmedium        83
# MELDmsad0englong                   79
# BAUM1fhap2turmedium                78
# BAUM1fneu1turmedium                78
# EmoV-DB_sortedfang0englong         78
# ShEMOmhap2pesmedium                74
# EmoReact_V_1.0funk2englong         73
# EYASEmhap2arzmedium                72
# cafefhap2framedium                 71
# ShEMOfneu1peslong                  71
# cafemang0framedium                 71
# ShEMOfang0peslong                  71
# cafemfea0framedium                 69
# MELDmneu1engshort                  69
# cafemhap2framedium                 69
# cafefang0framedium                 69
# EmoDBfang0deumedium                67
# cafemdis0framedium                 66
# ShEMOmsad0peslong                  66
# cafeffea0framedium                 66
# cafemsad0framedium                 65
# EYASEfneu1arzmedium                60
# EYASEfsad0arzmedium                60
# EYASEfang0arzmedium                60
# EmoDBmang0deumedium                60
# EYASEfhap2arzmedium                60
# aesddfang0ellmedium                60
# BAUM1func0turmedium                60
# aesddffea0ellmedium                59
# saveemfea0engmedium                58
# MESSmcal1engmedium                 58
# aesddfsad0ellmedium                58
# BAUM1mneu1turmedium                56
# saveemang0engmedium                56
# BAUM1mhap2turmedium                56
# aesddfhap2ellmedium                55
# cafefsad0framedium                 55
# saveemhap2engmedium                54
# urdumhap2urdmedium                 54
# MELDfneu1engshort                  54
# oreau2mneu1framedium               52
# aesddfdis0ellmedium                51
# saveemdis0engmedium                51
# EmoReact_V_1.0funk0englong         50
# oreau2mang0framedium               50
# ShEMOfsad0peslong                  49
# aesddmfea0ellmedium                48
# MELDfsur2englong                   48
# aesddmang0ellmedium                47
# oreau2mdis0framedium               47
# BAUM1fbot0turmedium                46
# EmoDBfbor0deumedium                46
# urdufhap2urdmedium                 46
# BAUM1mang0turmedium                46
# BAUM1mdis0turmedium                46
# EmoReact_V_1.0munk2englong         46
# aesddmdis0ellmedium                46
# enterface_dbfsad0engmedium         45
# enterface_dbffea0engmedium         45
# enterface_dbfang0engmedium         45
# BAUM1munc0turmedium                45
# Emotional_EMAmneu1engmedium        45
# enterface_dbfhap2engmedium         45
# EmoDBfhap2deumedium                44
# oreau2mhap2framedium               44
# cafefdis0framedium                 44
# enterface_dbfdis0engmedium         44
# BAUM1fdis0turmedium                42
# saveemsad0engmedium                42
# MELDmsur2englong                   41
# oreau2msad0framedium               41
# MELDmdis0englong                   41
# aesddmhap2ellmedium                41
# EmoDBfneu1deumedium                40
# BAUM2mang0engmedium                40
# Emotional_EMAmsad0englong          40
# ekorpusfang0estlong                40
# EmoReact_V_1.0munk0englong         39
# oreau2mfea0framedium               39
# EmoDBmneu1deumedium                39
# BAUM1fang0turmedium                38
# aesddmsad0ellmedium                38
# esdmsad0cmnlong                    37
# vivaeffea0___short                 37
# BAUM1msad0turmedium                36
# cafefneu1framedium                 36
# EmoDBmfea0deumedium                36
# MELDfdis0englong                   35
# EmoDBmbor0deumedium                35
# cafemneu1framedium                 33
# LEGOv2uang0engmedium               33
# Emotional_EMAmang0engmedium        33
# EmoDBfdis0deumedium                33
# MESSfcal1engmedium                 33
# EmoDBffea0deumedium                33
# BAUM2fang0engmedium                32
# Emotional_EMAmhap2engmedium        32
# MELDmsur0englong                   32
# LEGOv2fneu1engshort                30
# EmoDBfsad0deumedium                29
# LEGOv2mneu1engshort                29
# BAUM1munc0turlong                  29
# MELDmhap2engshort                  29
# MELDfhap2engshort                  29
# MELDfsur0englong                   28
# cafefdis0fralong                   28
# LEGOv2fang0englong                 27
# EmoDBmhap2deumedium                27
# BAUM1ffea0turmedium                27
# ekorpusfneu1estlong                26
# Emotional_EMAmsad0engmedium        26
# MELDffea0englong                   25
# MELDmfea0englong                   25
# BAUM1fsad0turlong                  25
# BAUM1mfea0turmedium                25
# LEGOv2fneu1englong                 25
# BAUM1fbor0turmedium                25
# BAUM1mcon0turmedium                24
# BAUM2fhap2engmedium                24
# LEGOv2mneu1englong                 24
# BAUM2fhap2turmedium                23
# BAUM2mhap2engmedium                23
# ekorpusfsad0estlong                23
# BAUM2mang0turmedium                23
# vivaefsur2___short                 23
# BAUM1mneu1turlong                  22
# Emotional_EMAfsad0englong          21
# EmoV-DB_sortedmang0englong         21
# BAUM1mcon0turlong                  21
# MELDuneu1engmedium                 21
# BAUM1msad0turlong                  21
# BAUM1fneu1turlong                  21
# ekorpusfhap2estlong                20
# aesddmsad0elllong                  20
# MELDfang0engshort                  20
# EmoDBmsad0deumedium                20
# ShEMOffea0pesmedium                19
# BAUM1mbor0turmedium                19
# BAUM1mhap2turlong                  19
# BAUM1func0turlong                  19
# vivaefpai0___short                 19
# BAUM1fcon0turmedium                19
# oreau2fhap2framedium               18
# oreau2fneu1framedium               18
# BAUM2fang0turmedium                18
# aesddmhap2elllong                  18
# vivaefach2___short                 18
# saveemsad0englong                  18
# BAUM1mbot0turmedium                17
# cafefsad0fralong                   17
# vivaefang0___short                 17
# oreau2fang0framedium               17
# oreau2fdis0framedium               16
# EmoReact_V_1.0mneu1engmedium       16
# EmoReact_V_1.0fdis0engmedium       16
# ShEMOfhap2peslong                  15
# esdmsad0englong                    15
# ShEMOmhap2peslong                  15
# MELDuhap2engmedium                 15
# BAUM1mcur2turmedium                14
# MELDfsur0engshort                  14
# oreau2fsad0framedium               14
# ShEMOmfea0pesmedium                14
# aesddmdis0elllong                  14
# BAUM2mhap2turmedium                13
# Emotional_EMAfang0englong          13
# aesddmang0elllong                  13
# Emotional_EMAmang0englong          13
# BAUM1mfea0turlong                  13
# EmoV-DB_sortedmneu1englong         12
# BAUM2fsad0turmedium                12
# stratum_group_103                  12
# BAUM1fcur2turmedium                12
# BAUM1fbot0turlong                  11
# stratum_group_95                   11
# aesddmfea0elllong                  11
# aesddfdis0elllong                  11
# stratum_group_96                   11
# oreau2ffea0framedium               11
# EmoReact_V_1.0fneu1engmedium       11
# stratum_group_94                   11
# EmoReact_V_1.0mdis0engmedium       11
# BAUM1mdis0turlong                  11
# MELDmsur2engshort                  11
# BAUM1mang0turlong                  10
# stratum_group_102                  10
# stratum_group_97                   10
# stratum_group_98                   10
# stratum_group_100                  10
# MELDmang0engshort                  10
# stratum_group_101                  10
# stratum_group_99                   10
# BAUM2fsad0engmedium                10
# EmoReact_V_1.0mcur2engmedium       10
# LimaCastroScottmple2___medium      10
# EmoDBmdis0deumedium                10
# Emotional_EMAmhap2englong           9
# EmoReact_V_1.0mneu1englong          9
# LimaCastroScottmsad0___medium       9
# LEGOv2uneu1englong                  9
# MELDmsur0engshort                   9
# BAUM2msad0engmedium                 9
# Emotional_EMAfhap2englong           9
# LimaCastroScottmdis0___medium       9
# saveemdis0englong                   9
# EmoReact_V_1.0fcur2engmedium        8
# EmoDBfsad0deulong                   8
# LimaCastroScottfach2___medium       8
# saveemneu1englong                   8
# LimaCastroScottmang0___medium       8
# BAUM1fdis0turlong                   8
# LimaCastroScottfamu2___medium       8
# BAUM2mneu1engmedium                 8
# BAUM2fcon0engmedium                 8
# BAUM2fdis0engmedium                 8
# BAUM1mbot0turlong                   8
# stratum_group_28                    7
# stratum_group_42                    7
# stratum_group_34                    7
# stratum_group_49                    7
# stratum_group_12                    7
# stratum_group_32                    7
# stratum_group_48                    7
# stratum_group_16                    7
# stratum_group_39                    7
# stratum_group_13                    7
# stratum_group_2                     7
# stratum_group_3                     7
# stratum_group_41                    7
# stratum_group_46                    7
# stratum_group_4                     7
# stratum_group_20                    7
# stratum_group_15                    7
# stratum_group_31                    7
# stratum_group_47                    7
# stratum_group_14                    7
# BAUM1fhap2turlong                   7
# stratum_group_8                     7
# stratum_group_40                    7
# stratum_group_7                     7
# stratum_group_17                    7
# stratum_group_18                    7
# stratum_group_19                    7
# stratum_group_33                    7
# cafemsad0fralong                    7
# stratum_group_21                    7
# stratum_group_6                     7
# stratum_group_22                    7
# stratum_group_27                    7
# stratum_group_23                    7
# stratum_group_24                    7
# LimaCastroScottfsad0___medium       7
# stratum_group_37                    7
# stratum_group_26                    7
# LimaCastroScottmrel2___medium       7
# LimaCastroScottfple2___medium       7
# stratum_group_1                     7
# stratum_group_52                    7
# stratum_group_29                    7
# stratum_group_25                    7
# LimaCastroScottfdis0___medium       7
# stratum_group_38                    7
# stratum_group_5                     7
# stratum_group_9                     7
# stratum_group_35                    7
# BAUM1fcon0turlong                   7
# LimaCastroScottmamu2___medium       7
# saveemhap2englong                   7
# stratum_group_0                     7
# stratum_group_36                    7
# stratum_group_51                    7
# stratum_group_44                    7
# stratum_group_30                    7
# stratum_group_10                    7
# stratum_group_43                    7
# stratum_group_45                    7
# stratum_group_11                    7
# dtype: int64
# time: 1.61 s

# %% [markdown]
# # Hyperparameters

# %%
model = RandomizedSearchCV(
    estimator=CalibratedClassifierCV(
        base_estimator=RidgeClassifier(random_state=SEED),
        method="isotonic",
        n_jobs=-1,
    ),
    param_distributions={
        "base_estimator__alpha": loguniform(1e-3, 1e3),
        "base_estimator__class_weight": ["balanced", None],
    },
    n_iter=10,
    scoring="neg_log_loss",
    n_jobs=-1,
    cv=list(cross_validator()),
    verbose=1,
    random_state=SEED + 1,
    error_score="raise",
).fit(data, labels.valence)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# time: 15.8 s

# %%
print(model.best_score_)
print(model.best_params_)
results_df = (
    pd.DataFrame(model.cv_results_)
    .sort_values(by="param_base_estimator__alpha", ascending=True)
    .loc[:, ["param_base_estimator__alpha", "mean_test_score"]]
)
results_df.plot(x="param_base_estimator__alpha", y="mean_test_score")
plt.show()
# Out:
# -0.7484894848301957
# {'base_estimator__alpha': 2.4393756512674267, 'base_estimator__class_weight': None}
# <AxesSubplot:xlabel='param_base_estimator__alpha'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 211 ms

# %%
df = pd.DataFrame(model.cv_results_)
df.param_base_estimator__class_weight = df.param_base_estimator__class_weight.astype(
    str
)
df.groupby("param_base_estimator__class_weight").mean()
# Out:
#                                     mean_fit_time  std_fit_time  \
# param_base_estimator__class_weight
# None                                     0.875759      0.071242
# balanced                                 0.957302      0.126302
#
#                                     mean_score_time  std_score_time  \
# param_base_estimator__class_weight
# None                                       0.116763        0.047053
# balanced                                   0.119950        0.051322
#
#                                     split0_test_score  split1_test_score  \
# param_base_estimator__class_weight
# None                                        -0.725115          -0.722108
# balanced                                    -0.725205          -0.719937
#
#                                     split2_test_score  split3_test_score  \
# param_base_estimator__class_weight
# None                                        -0.883914          -0.768143
# balanced                                    -0.887761          -0.768557
#
#                                     split4_test_score  split5_test_score  \
# param_base_estimator__class_weight
# None                                        -0.666875          -0.713444
# balanced                                    -0.667003          -0.717115
#
#                                     split6_test_score  mean_test_score  \
# param_base_estimator__class_weight
# None                                        -0.760281        -0.748554
# balanced                                    -0.762326        -0.749700
#
#                                     std_test_score  rank_test_score
# param_base_estimator__class_weight
# None                                      0.063242              2.0
# balanced                                  0.064323              7.0
# time: 17.1 ms

# %%
def tune(alpha: Sequence, results_df: pd.DataFrame, n_iter: int = 10) -> pd.DataFrame:
    """Run tuning procedure"""
    model = RandomizedSearchCV(
        estimator=CalibratedClassifierCV(
            base_estimator=RidgeClassifier(random_state=SEED + 1, class_weight=None),
            method="isotonic",
            n_jobs=-1,
        ),
        param_distributions={"base_estimator__alpha": alpha},
        n_iter=n_iter,
        scoring="neg_log_loss",
        n_jobs=-1,
        cv=list(cross_validator()),
        verbose=1,
        random_state=SEED + 2,
        error_score="raise",
    ).fit(data, labels.valence)

    print("best score:", model.best_score_)
    print("best params:", model.best_params_)
    df = (
        pd.DataFrame(model.cv_results_)
        .sort_values(by="param_base_estimator__alpha", ascending=True)
        .loc[:, ["param_base_estimator__alpha", "mean_test_score"]]
    )
    df.plot(x="param_base_estimator__alpha", y="mean_test_score")
    plt.show()
    return pd.concat(
        [results_df.loc[:, ["param_base_estimator__alpha", "mean_test_score"]], df],
        axis="rows",
    )


_ = gc_collect()
# Out:
# time: 115 ms

# %%
df = tune(alpha=loguniform(1e-3, 1e3), results_df=df, n_iter=10)
df = tune(alpha=uniform(1e-3, 1e3), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7482096455562861
# best params: {'base_estimator__alpha': 23.090900086512427}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7479331311372367
# best params: {'base_estimator__alpha': 106.06387447626572}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 24.3 s

# %%
df = tune(alpha=loguniform(1e-2, 1e2), results_df=df, n_iter=10)
df = tune(alpha=uniform(1e-2, 1e2), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7483398909498266
# best params: {'base_estimator__alpha': 8.108874421334596}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7479628284319686
# best params: {'base_estimator__alpha': 67.95005235251416}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 23.8 s

# %%
df = tune(alpha=loguniform(1e-2, 10), results_df=df, n_iter=10)
df = tune(alpha=uniform(1e-2, 10), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485070143600716
# best params: {'base_estimator__alpha': 1.5195690206934473}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7483624817842333
# best params: {'base_estimator__alpha': 7.282401436844547}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 24 s

# %%
df = tune(alpha=loguniform(0.1, 1), results_df=df, n_iter=10)
df = tune(alpha=uniform(0.1, 1), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485533269137427
# best params: {'base_estimator__alpha': 0.4779698731533934}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485353251202483
# best params: {'base_estimator__alpha': 0.8272401436844548}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 23.2 s

# %%
df = tune(alpha=loguniform(0.5, 1.5), results_df=df, n_iter=10)
df = tune(alpha=uniform(0.5, 1.5), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485177342113908
# best params: {'base_estimator__alpha': 1.0777788260091068}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485061792213156
# best params: {'base_estimator__alpha': 1.5908602155266822}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 23.4 s

# %%
df = tune(alpha=loguniform(0.8, 1.0), results_df=df, n_iter=10)
df = tune(alpha=uniform(0.8, 1.0), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485261523342663
# best params: {'base_estimator__alpha': 0.9121672629709177}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485074117591649
# best params: {'base_estimator__alpha': 1.527240143684455}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 24.1 s

# %%
df = tune(alpha=loguniform(0.9, 1.1), results_df=df, n_iter=10)
df = tune(alpha=uniform(0.9, 1.1), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7485205262932855
# best params: {'base_estimator__alpha': 1.0414096933928414}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.748506769316334
# best params: {'base_estimator__alpha': 1.6999641580529004}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 23.4 s

# %%
df = tune(alpha=loguniform(0.1, 1e5), results_df=df, n_iter=10)
df = tune(alpha=uniform(0.1, 1e5), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.747837107006799
# best params: {'base_estimator__alpha': 2309.0900086512424}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7450099265337663
# best params: {'base_estimator__alpha': 72724.11436844549}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 24.2 s

# %%
df = tune(alpha=loguniform(10, 1e10), results_df=df, n_iter=10)
df = tune(alpha=uniform(10, 1e10), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7449947264142354
# best params: {'base_estimator__alpha': 108308.46985724186}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7941555970678416
# best params: {'base_estimator__alpha': 438085647.46864814}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 24.2 s

# %%
df = tune(alpha=loguniform(100, 1e7), results_df=df, n_iter=10)
df = tune(alpha=uniform(100, 1e7), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7446622256249226
# best params: {'base_estimator__alpha': 87110.91880089794}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7464393718494151
# best params: {'base_estimator__alpha': 438185.63746864814}
# C:\Users\michen\miniconda3\envs\capstone_pyspark_38\lib\site-packages\pandas\plotting\_matplotlib\core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 24.5 s

# %%
df = tune(alpha=loguniform(1000, 1e6), results_df=df, n_iter=10)
df = tune(alpha=uniform(1000, 1e6), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7450113552180457
# best params: {'base_estimator__alpha': 109194.70279424937}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7449657158018119
# best params: {'base_estimator__alpha': 107062.87447626573}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 24.2 s

# %%
df = tune(alpha=loguniform(1e5, 1e6), results_df=df, n_iter=10)
df = tune(alpha=uniform(1e5, 1e6), results_df=df, n_iter=10)
# Out:
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7449931816384663
# best params: {'base_estimator__alpha': 110613.60936306213}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 10 candidates, totalling 70 fits
# best score: -0.7456099529375668
# best params: {'base_estimator__alpha': 206062.87447626574}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 23.9 s

# %%
df = tune(alpha=loguniform(50000, 250000), results_df=df, n_iter=50)
df = tune(alpha=uniform(50000, 250000), results_df=df, n_iter=50)
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.7446244720518457
# best params: {'base_estimator__alpha': 92412.89396609525}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.744629817626055
# best params: {'base_estimator__alpha': 106338.54079817388}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 1min 44s

# %%
df = tune(alpha=loguniform(75000, 125000), results_df=df, n_iter=50)
df = tune(alpha=uniform(75000, 125000), results_df=df, n_iter=50)
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.744616600614086
# best params: {'base_estimator__alpha': 93792.7514477731}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.7446235126406056
# best params: {'base_estimator__alpha': 104873.35405446612}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 1min 40s

# %%
df = tune(alpha=loguniform(0.1, 10), results_df=df, n_iter=15)
df = tune(alpha=uniform(0.1, 10), results_df=df, n_iter=15)
# Out:
# Fitting 7 folds for each of 15 candidates, totalling 105 fits
# best score: -0.7483405328868938
# best params: {'base_estimator__alpha': 8.38600564896727}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 15 candidates, totalling 105 fits
# best score: -0.7483312382550853
# best params: {'base_estimator__alpha': 9.717775753081897}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 33.8 s

# %%
df = tune(alpha=loguniform(90000, 110000), results_df=df, n_iter=15)
df = tune(alpha=uniform(90000, 110000), results_df=df, n_iter=15)
# Out:
# Fitting 7 folds for each of 15 candidates, totalling 105 fits
# best score: -0.7446080398595489
# best params: {'base_estimator__alpha': 93463.05784920669}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 15 candidates, totalling 105 fits
# best score: -0.7446302087446198
# best params: {'base_estimator__alpha': 92101.76426597126}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 34.4 s

# %%
df = tune(alpha=loguniform(95000, 105000), results_df=df, n_iter=50)
df = tune(alpha=uniform(95000, 5000), results_df=df, n_iter=50)
# I forgot the API goes center, scale for uniform and start, stop for loguniform
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.7446237464578481
# best params: {'base_estimator__alpha': 95613.9406752829}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.7446151696869742
# best params: {'base_estimator__alpha': 96126.77081596348}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 1min 44s

# %%
df = tune(alpha=loguniform(99000, 101000), results_df=df, n_iter=50)
df = tune(alpha=uniform(99000, 2000), results_df=df, n_iter=50)
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.7446324652710493
# best params: {'base_estimator__alpha': 100765.01412038332}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# best score: -0.7446329343344142
# best params: {'base_estimator__alpha': 100767.07740555317}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 1min 43s

# %%
df = tune(alpha=loguniform(95000, 105000), results_df=df, n_iter=30)
df = tune(alpha=uniform(95000, 10000), results_df=df, n_iter=30)
# Out:
# Fitting 7 folds for each of 30 candidates, totalling 210 fits
# best score: -0.7446241829842017
# best params: {'base_estimator__alpha': 95417.44316821704}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 30 candidates, totalling 210 fits
# best score: -0.7446212503500717
# best params: {'base_estimator__alpha': 95438.08563746864}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 1min 3s

# %%
df = tune(alpha=loguniform(100700, 100800), results_df=df, n_iter=25)
df = tune(alpha=uniform(100700, 100), results_df=df, n_iter=25)
# Out:
# Fitting 7 folds for each of 25 candidates, totalling 175 fits
# best score: -0.7446324127876327
# best params: {'base_estimator__alpha': 100758.78942903526}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Fitting 7 folds for each of 25 candidates, totalling 175 fits
# best score: -0.7446324128010667
# best params: {'base_estimator__alpha': 100758.80145188954}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 53.7 s

# %%
results_df = df
results_df.columns = results_df.columns.astype(str)
results_df.reset_index(drop=True).to_csv(f"{DATA_OUT_FOLDER}/ridge_results.csv")
# Out:
# time: 11 ms

# %%
results_df = results_df.sort_values(by="param_base_estimator__alpha", ascending=True)
results_df.plot(x="param_base_estimator__alpha", y="mean_test_score")
df.sort_values(by="mean_test_score", ascending=False).head(100)
# Out:
# <AxesSubplot:xlabel='param_base_estimator__alpha'>
#    param_base_estimator__alpha  mean_test_score
# 2                 93463.057849        -0.744608
# 17                96126.770816        -0.744615
# 24                96410.825597        -0.744615
# 23                96258.836434        -0.744615
# 4                 93779.939271        -0.744616
# 48                96279.604657        -0.744616
# 39                96128.843838        -0.744616
# 30                96429.136942        -0.744616
# 20                 96289.97819        -0.744616
# 33                93792.751448        -0.744617
# 32                96194.934162        -0.744617
# 35                96446.405702        -0.744617
# 40                92952.165131        -0.744619
# 38                92842.414985        -0.744621
# 3                 95438.085637        -0.744621
# 10                95095.534739        -0.744622
# 5                 96060.628745        -0.744623
# 8                 95539.582738        -0.744623
# 32               104873.354054        -0.744624
# 21                95477.710769        -0.744624
# 41                95613.940675        -0.744624
# 3                 95417.443168        -0.744624
# 3                 95417.443168        -0.744624
# 4                 96025.094762        -0.744624
# 29                92412.893966        -0.744624
# 5                 95530.314372        -0.744625
# 14                105305.39393        -0.744625
# 10                95181.841307        -0.744626
# 10                95181.841307        -0.744626
# 11               104672.256521        -0.744626
# 5                 96013.809579        -0.744626
# 5                 96013.809579        -0.744626
# 2                 96805.885252        -0.744627
# 2                 96805.885252        -0.744627
# 10                95191.069479        -0.744627
# 45                96002.637219        -0.744627
# 21                95912.765035        -0.744627
# 21                95912.765035        -0.744627
# 2                   95940.7598        -0.744627
# 28                 92570.19074        -0.744628
# 21                95955.421539        -0.744628
# 18               105618.159007        -0.744628
# 23               106470.910846        -0.744628
# 3                 95219.042819        -0.744629
# 41                95321.818454        -0.744629
# 17               106338.540798        -0.744630
# 10                92101.764266        -0.744630
# 13               104617.775753        -0.744630
# 5                 91936.064201        -0.744631
# 7                106117.111504        -0.744631
# 2                   96881.5196        -0.744631
# 3                 94818.942012        -0.744631
# 22               104609.097422        -0.744631
# 13               104599.096895        -0.744632
# 13               104599.096895        -0.744632
# 22               104590.012258        -0.744632
# 22               104590.012258        -0.744632
# 0                 100758.58603        -0.744632
# 0                 100758.58603        -0.744632
# 0                100758.789429        -0.744632
# 0                100758.801452        -0.744632
# 39               106442.191899        -0.744632
# 34                100765.01412        -0.744632
# 15               100760.651119        -0.744633
# 15               100760.662962        -0.744633
# 12               100760.232967        -0.744633
# 12               100760.244854        -0.744633
# 8                 100747.38457        -0.744633
# 8                100747.372197        -0.744633
# 29                96908.254751        -0.744633
# 16               100744.915131        -0.744633
# 7                100767.940052        -0.744633
# 7                100767.929242        -0.744633
# 16               100744.902853        -0.744633
# 9                100744.829582        -0.744633
# 9                100744.817308        -0.744633
# 34               100767.077406        -0.744633
# 18                100767.01743        -0.744633
# 18               100767.006459        -0.744633
# 9                 94300.746677        -0.744633
# 19               100773.576659        -0.744633
# 19                100773.56701        -0.744633
# 18               100335.922649        -0.744633
# 36               102759.679274        -0.744633
# 6                100772.724014        -0.744633
# 6                100772.714169        -0.744633
# 14               100766.436865        -0.744634
# 44               100784.972773        -0.744634
# 1                100769.910875        -0.744634
# 1                100769.900435        -0.744634
# 14               100766.425798        -0.744634
# 11               100775.250593        -0.744634
# 11               100775.259834        -0.744634
# 14               100324.272633        -0.744634
# 44               100783.048604        -0.744634
# 28                96913.538153        -0.744634
# 2                  97037.99001        -0.744634
# 47                100788.88523        -0.744634
# 47               100790.763689        -0.744634
# 18               100340.348594        -0.744634
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 211 ms

# %%
max_score = results_df.mean_test_score.max()
results_df.loc[results_df.mean_test_score == max_score]
results_df.loc[
    results_df.mean_test_score == max_score
].param_base_estimator__alpha.iloc[0]
# Out:
#   param_base_estimator__alpha  mean_test_score
# 2                93463.057849        -0.744608
# 93463.05784920669
# time: 15.6 ms

# %%
df = results_df.loc[results_df.param_base_estimator__alpha < 400000]
df.plot(x="param_base_estimator__alpha", y="mean_test_score")
plt.show()
# Out:
# <AxesSubplot:xlabel='param_base_estimator__alpha'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 160 ms

# %%
df = results_df.loc[results_df.param_base_estimator__alpha < 1e9]
df = df.loc[df.param_base_estimator__alpha > 75000]
df.plot(x="param_base_estimator__alpha", y="mean_test_score")
plt.show()
# Out:
# <AxesSubplot:xlabel='param_base_estimator__alpha'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# time: 126 ms

# %% [markdown]
# # Discussion

# %% [markdown]
# There are so many more possibilities for feature engineering. Upstream augmentation of the raw audio would probably be helpful as would resampling.
#
# It's important to be disciplined now and focus on deployment. Although there are numerous points of interest where tweaking is likely to yield better results, we are only deviating slightly from the feature engineering pathway we already established.

# %%
print(f"Time elapsed since notebook_begin_time: {time() - notebook_begin_time} s")
_ = gc_collect()
# Out:
# Time elapsed since notebook_begin_time: 924.9536650180817 s
# time: 183 ms

# %% [markdown]
# [^top](#Contents)
