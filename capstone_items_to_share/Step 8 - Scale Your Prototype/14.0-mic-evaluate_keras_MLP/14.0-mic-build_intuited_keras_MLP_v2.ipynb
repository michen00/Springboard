# %% [markdown]
# # Contents
# * [Introduction](#Introduction)
# * [Imports and configuration](#Imports-and-configuration)
# * [Setup](#Setup)
# * [Models](#Models)
# * [Test harness](#Test-harness)
# * [Results](#Results)
# * [Discussion](#Discussion)

# %% [markdown]
# # Introduction
#
# In this notebook, we build and test a `keras` dense net using intuited configurations.

# %% [markdown]
# # Imports and configuration

# %%
from time import time

notebook_begin_time = time()

# set random seeds

from os import environ
from random import seed as random_seed
from numpy.random import seed as np_seed
from tensorflow.random import set_seed


def reset_seeds(seed: int) -> None:
    """Utility function for resetting random seeds"""
    environ["PYTHONHASHSEED"] = str(seed)
    random_seed(seed)
    np_seed(seed)
    set_seed(seed)


reset_seeds(SEED := 2021)

# %%
# extensions
# %load_ext autotime
# %load_ext lab_black
# %load_ext nb_black
# %load_ext tensorboard

# %%
# core
import numpy as np
import pandas as pd

# utility
from collections import namedtuple
from gc import collect as gc_collect

# typing
from typing import Callable, Dict, List

# faster pandas & sklearn
import swifter
from sklearnex import patch_sklearn

patch_sklearn()
del patch_sklearn

# metrics
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    roc_auc_score,
)

# keras & tensorflow
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import AlphaDropout, Dense

# visualization
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context("notebook")
sns.set_style("ticks")
# %matplotlib inline

# display outputs w/o print calls
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
del InteractiveShell

# hide warnings
import warnings

warnings.filterwarnings("ignore")
del warnings
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# time: 2.95 s

# %%
# Location of cross validation .feather files
FRILL_FEATHERS_FOLDER = "../10.0-mic-prepare_train-test_splits_on_full_data"

# Location where this notebook will output
DATA_OUT_FOLDER = "."

_ = gc_collect()
# Out:
# time: 99.1 ms

# %% [markdown]
# # Setup
#
# In this section, we define some structures to keep track of models and scores.
#
# The next cell defines a Python dictionary to record the results of cross validation such that the results may be easily cast to a `pandas` dataframe.

# %%
ALL_CASES = {"negative", "neutral", "ternary", "ternary_negneu"}

METRICS = (
    "accuracy",
    "adjusted_balanced_accuracy",
    "f1",
    "geometric_mean",
    "roc_auc",
    "fit_time",
    "predict_time",
)

# to be cast to pd.DataFrame
make_results = lambda: {key: [] for key in {"model_name", "case", *METRICS}}
results_ = make_results()

AvgScores = namedtuple("AvgScores", METRICS)


def store_result(
    where: Dict[str, List],
    case: str,
    model_name: str,
    avg_scores: AvgScores,
) -> None:
    "Appends a model's scores and fit/predict times to the results dict."
    for attribute, value in {
        "model_name": model_name,
        "case": case,
        **avg_scores._asdict(),
    }.items():
        where[attribute].append(value)


def create_results_df(results_dict: Dict[str, List]) -> pd.DataFrame:
    """Create a results dataframe from the results dictionary"""
    df = (
        pd.DataFrame(results_)
        .sort_values(by=["model_name"], ascending=True)
        .sort_values(by=["fit_time", "predict_time"], ascending=True)
        .sort_values(
            by=[
                "accuracy",
                "adjusted_balanced_accuracy",
                "f1",
                "geometric_mean",
                "roc_auc",
            ],
            ascending=False,
        )
        .sort_values(by=["case"], ascending=True)
        .reset_index(drop=True)
    )[
        [  # selection order
            "model_name",
            "case",
            "accuracy",
            "adjusted_balanced_accuracy",
            "f1",
            "geometric_mean",
            "roc_auc",
            "fit_time",
            "predict_time",
        ]
    ]
    df.loc[:, "case"] = df.loc[:, "case"].astype("category")
    return df


_ = gc_collect()
# Out:
# time: 109 ms

# %%
predictions_ = {key: [] for key in {"model", "case", "fold", "y_pred"}}

Prediction = namedtuple("Prediction", predictions_.keys())


def store_prediction(where: Dict[str, List], prediction: Prediction) -> None:
    "Records the y_pred of a classifier on a fold"
    for k, v in prediction._asdict().items():
        where[k].append(v)


_ = gc_collect()
# Out:
# time: 115 ms

# %% [markdown]
# # Model
#
# In this section, we set up the MLP.

# %%
def make_MLP(case: str, output_bias: float, print_summary: bool = True) -> Sequential:
    """Return a prepared keras MLP"""
    if "ternary" in case:
        out_nodes, final_activation, loss, accuracy = (
            3,
            "softmax",
            "sparse_categorical_crossentropy",
            "sparse_categorical_accuracy",
        )
    else:
        out_nodes, final_activation, loss, accuracy = (
            1,
            "sigmoid",
            "binary_crossentropy",
            "binary_accuracy",
        )

    model = Sequential(
        [
            Dense(
                1024,
                input_dim=2048,
                kernel_initializer="lecun_normal",
                activation="selu",
            ),
            AlphaDropout(0.1, seed=SEED),
            Dense(
                out_nodes,
                activation=final_activation,
                bias_initializer=output_bias,
            ),
        ]
    )
    model.compile(
        loss=loss,
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
        metrics=accuracy,
    )
    if print_summary:
        model.summary()
    return model


_ = gc_collect()
# Out:
# time: 110 ms

# %% [markdown]
# # Test harness
#
# This section defines functions for evaluating models.

# %%
recode_y: Dict[str, Callable] = {
    "negative": lambda y: ((y - 1) // 2) * (-1),
    "neutral": lambda y: y % 2,
    "positive": lambda y: y // 2,
    "ternary": lambda y: y,
}


def evaluate_model(
    model_base: str, case: str, track_fold_time: bool = True
) -> AvgScores:
    """Evaluate a model with cross validation on prepared folds."""
    (
        fit_times,
        predict_times,
        accuracy,
        adjusted_balanced_accuracy,
        f1,
        geometric_mean,
        roc_auc,
    ) = ([] for _ in range(7))
    fold_num = 0
    while True:
        if track_fold_time:
            fold_begin = time()

        def read_feather_cv(xy_set: str) -> pd.DataFrame:
            """Helper function for reading split data"""
            path_prefix = f"{FRILL_FEATHERS_FOLDER}/cv_{fold_num}/{xy_set}"
            if "train" in xy_set:
                return pd.read_feather(f"{path_prefix}_untransformed.feather")
            else:
                return pd.read_feather(f"{path_prefix}_untransformed.feather")

        # load training data
        try:
            X_train: pd.DataFrame = read_feather_cv("X_train")
            y_train: np.ndarray = read_feather_cv("y_train").iloc[:, 0]
        except FileNotFoundError:
            break

        # recode/reformat y_train
        recoder = recode_y[case]
        y_train = recoder(y_train)

        # load testing data
        X_test = read_feather_cv("X_test")
        y_test = read_feather_cv("y_test").iloc[:, 0].astype(np.int8)

        # initialize model with output layer bias
        if multiclass := "ternary" in case:
            zeros, ones, twos = np.bincount(y_test)
            init_bias = tf.keras.initializers.Constant(
                np.squeeze(
                    [
                        np.log([zeros / (ones + twos)]),
                        np.log([ones / (zeros + twos)]),
                        np.log([twos / (zeros + ones)]),
                    ]
                )
            )
            del twos
        else:
            # recode y_test
            y_test = recoder(y_test)
            del recoder
            _ = gc_collect()
            zeros, ones = np.bincount(y_test)
            init_bias = tf.keras.initializers.Constant(np.log([ones / zeros]))
        del ones
        del zeros
        _ = gc_collect()

        model = make_MLP(case, output_bias=init_bias)
        del init_bias
        _ = gc_collect()

        # fit
        reset_seeds(SEED)
        begin = time()
        history = model.fit(
            X_train,
            y_train,
            batch_size=16,
            epochs=1000,
            validation_split=0.1,
            callbacks=EarlyStopping(patience=20, restore_best_weights=True),
        )
        end = time()
        del X_train
        del y_train
        _ = gc_collect()
        fit_times.append(end - begin)
        print(f"fitted in {end - begin:.2f} s")

        pd.DataFrame(history.history).plot(
            cmap=ListedColormap(sns.color_palette("colorblind").as_hex())
        )
        plt.title("accuracy and loss by epochs")
        plt.legend(frameon=False)
        sns.despine(**dict.fromkeys(("right", "top"), True))
        plt.show()

        # predict
        begin = time()
        predicted = model.predict(X_test)
        end = time()
        del X_test
        del model
        _ = gc_collect()
        predict_times.append(end - begin)
        print(f"predicted in {end - begin:.2f} s")
        del end
        del begin
        _ = gc_collect()
        y_pred = (
            predicted.argmax(axis=1)
            if multiclass
            else pd.Series(np.squeeze(predicted)).swifter.apply(round)
        ).astype(np.int8)
        store_prediction(
            where=predictions_,
            prediction=Prediction(
                model=model_base,
                case=case,
                fold=fold_num,
                y_pred=y_pred,
            ),
        )

        # score
        score_params = {
            "y_true": y_test,
            "y_pred": y_pred,
        }
        accuracy.append(accuracy_score(**score_params))
        adjusted_balanced_accuracy.append(
            balanced_accuracy_score(**score_params, adjusted=True)
        )
        f1.append(f1_score(**score_params, average="weighted"))
        geometric_mean.append(geometric_mean_score(**score_params))
        del y_pred
        score_params = {
            "y_true": y_test,
            "y_score": predicted,
            "average": "weighted",
            "multi_class": "ovo",
        }
        roc_auc.append(roc_auc_score(**score_params))
        del score_params
        del predicted
        del y_test
        _ = gc_collect()

        if track_fold_time:
            print(
                f"{model_base} fold {fold_num + 1} completed in {time() - fold_begin:.2f} s"
            )
            del fold_begin

        fold_num += 1
        _ = gc_collect()

    return AvgScores(
        *[
            np.mean(_)
            for _ in (
                accuracy,
                adjusted_balanced_accuracy,
                f1,
                geometric_mean,
                roc_auc,
                fit_times,
                predict_times,
            )
        ]
    )


_ = gc_collect()
# Out:
# time: 122 ms

# %% [markdown]
# The next few cells evaluate models.

# %%
case = "negative"
model = "keras_MLP_14v2"

eval_begin = time()

print(f"evaluating {model}...")
_ = gc_collect()
store_result(
    where=results_,
    case=case,
    model_name=model,
    avg_scores=evaluate_model(model, case),
)
print(f"stored {model} for {case} classification in {time() - eval_begin:.2f} s")

del case
del model
del eval_begin
_ = gc_collect()

create_results_df(results_)
# Out:
# evaluating keras_MLP_14v2...
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout (AlphaDropout) (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.6725 - binary_accuracy: 0.6055 - val_loss: 0.6910 - val_binary_accuracy: 0.5773
# Epoch 2/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.6304 - binary_accuracy: 0.6544 - val_loss: 0.7234 - val_binary_accuracy: 0.5748
# Epoch 3/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.6171 - binary_accuracy: 0.6698 - val_loss: 0.7495 - val_binary_accuracy: 0.5744
# Epoch 4/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.6055 - binary_accuracy: 0.6786 - val_loss: 0.7490 - val_binary_accuracy: 0.5722
# Epoch 5/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.5991 - binary_accuracy: 0.6839 - val_loss: 0.7513 - val_binary_accuracy: 0.5721
# Epoch 6/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5940 - binary_accuracy: 0.6883 - val_loss: 0.7534 - val_binary_accuracy: 0.5753
# Epoch 7/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5911 - binary_accuracy: 0.6898 - val_loss: 0.7469 - val_binary_accuracy: 0.5749
# Epoch 8/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5880 - binary_accuracy: 0.6918 - val_loss: 0.7527 - val_binary_accuracy: 0.5751
# Epoch 9/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5847 - binary_accuracy: 0.6976 - val_loss: 0.7541 - val_binary_accuracy: 0.5766
# Epoch 10/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5823 - binary_accuracy: 0.6993 - val_loss: 0.7575 - val_binary_accuracy: 0.5788
# Epoch 11/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5790 - binary_accuracy: 0.7021 - val_loss: 0.7558 - val_binary_accuracy: 0.5768
# Epoch 12/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.5778 - binary_accuracy: 0.7006 - val_loss: 0.7592 - val_binary_accuracy: 0.5777
# Epoch 13/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.5733 - binary_accuracy: 0.7078 - val_loss: 0.7546 - val_binary_accuracy: 0.5790
# Epoch 14/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.5725 - binary_accuracy: 0.7025 - val_loss: 0.7551 - val_binary_accuracy: 0.5786
# Epoch 15/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5693 - binary_accuracy: 0.7090 - val_loss: 0.7508 - val_binary_accuracy: 0.5788
# Epoch 16/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.5681 - binary_accuracy: 0.7091 - val_loss: 0.7571 - val_binary_accuracy: 0.5774
# Epoch 17/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5649 - binary_accuracy: 0.7118 - val_loss: 0.7600 - val_binary_accuracy: 0.5786
# Epoch 18/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.5644 - binary_accuracy: 0.7111 - val_loss: 0.7701 - val_binary_accuracy: 0.5789
# Epoch 19/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.5628 - binary_accuracy: 0.7128 - val_loss: 0.7629 - val_binary_accuracy: 0.5738
# Epoch 20/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5614 - binary_accuracy: 0.7137 - val_loss: 0.7635 - val_binary_accuracy: 0.5824
# Epoch 21/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.5604 - binary_accuracy: 0.7171 - val_loss: 0.7635 - val_binary_accuracy: 0.5781
# fitted in 655.92 s
# predicted in 1.57 s
# keras_MLP_14v2 fold 1 completed in 660.27 s
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_1 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.6725 - binary_accuracy: 0.6045 - val_loss: 0.6814 - val_binary_accuracy: 0.5858
# Epoch 2/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.6290 - binary_accuracy: 0.6539 - val_loss: 0.6947 - val_binary_accuracy: 0.5788
# Epoch 3/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.6200 - binary_accuracy: 0.6654 - val_loss: 0.7015 - val_binary_accuracy: 0.5754
# Epoch 4/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.6108 - binary_accuracy: 0.6720 - val_loss: 0.7137 - val_binary_accuracy: 0.5720
# Epoch 5/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.6033 - binary_accuracy: 0.6798 - val_loss: 0.7126 - val_binary_accuracy: 0.5700
# Epoch 6/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.5975 - binary_accuracy: 0.6827 - val_loss: 0.7096 - val_binary_accuracy: 0.5776
# Epoch 7/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.5945 - binary_accuracy: 0.6869 - val_loss: 0.7104 - val_binary_accuracy: 0.5741
# Epoch 8/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.5909 - binary_accuracy: 0.6888 - val_loss: 0.7177 - val_binary_accuracy: 0.5710
# Epoch 9/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.5874 - binary_accuracy: 0.6909 - val_loss: 0.7129 - val_binary_accuracy: 0.5744
# Epoch 10/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.5855 - binary_accuracy: 0.6940 - val_loss: 0.7164 - val_binary_accuracy: 0.5706
# Epoch 11/1000
# 4232/4232 [==============================] - 35s 8ms/step - loss: 0.5819 - binary_accuracy: 0.6982 - val_loss: 0.7204 - val_binary_accuracy: 0.5665
# Epoch 12/1000
# 4232/4232 [==============================] - 35s 8ms/step - loss: 0.5786 - binary_accuracy: 0.6991 - val_loss: 0.7184 - val_binary_accuracy: 0.5708
# Epoch 13/1000
# 4232/4232 [==============================] - 35s 8ms/step - loss: 0.5759 - binary_accuracy: 0.6999 - val_loss: 0.7246 - val_binary_accuracy: 0.5671
# Epoch 14/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.5748 - binary_accuracy: 0.7021 - val_loss: 0.7218 - val_binary_accuracy: 0.5683
# Epoch 15/1000
# 4232/4232 [==============================] - 35s 8ms/step - loss: 0.5740 - binary_accuracy: 0.7031 - val_loss: 0.7255 - val_binary_accuracy: 0.5655
# Epoch 16/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.5728 - binary_accuracy: 0.7033 - val_loss: 0.7273 - val_binary_accuracy: 0.5651
# Epoch 17/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.5707 - binary_accuracy: 0.7061 - val_loss: 0.7252 - val_binary_accuracy: 0.5663
# Epoch 18/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.5684 - binary_accuracy: 0.7075 - val_loss: 0.7279 - val_binary_accuracy: 0.5644
# Epoch 19/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.5691 - binary_accuracy: 0.7079 - val_loss: 0.7249 - val_binary_accuracy: 0.5676
# Epoch 20/1000
# 4232/4232 [==============================] - 35s 8ms/step - loss: 0.5660 - binary_accuracy: 0.7084 - val_loss: 0.7250 - val_binary_accuracy: 0.5681
# Epoch 21/1000
# 4232/4232 [==============================] - 35s 8ms/step - loss: 0.5650 - binary_accuracy: 0.7100 - val_loss: 0.7265 - val_binary_accuracy: 0.5675
# fitted in 703.51 s
# predicted in 1.30 s
# keras_MLP_14v2 fold 2 completed in 706.75 s
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_2 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3794/3794 [==============================] - 32s 8ms/step - loss: 0.6726 - binary_accuracy: 0.6031 - val_loss: 0.6959 - val_binary_accuracy: 0.5667
# Epoch 2/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.6310 - binary_accuracy: 0.6538 - val_loss: 0.7192 - val_binary_accuracy: 0.5645
# Epoch 3/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.6169 - binary_accuracy: 0.6678 - val_loss: 0.7401 - val_binary_accuracy: 0.5621
# Epoch 4/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.6067 - binary_accuracy: 0.6769 - val_loss: 0.7379 - val_binary_accuracy: 0.5589
# Epoch 5/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5977 - binary_accuracy: 0.6832 - val_loss: 0.7417 - val_binary_accuracy: 0.5605
# Epoch 6/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.5945 - binary_accuracy: 0.6878 - val_loss: 0.7536 - val_binary_accuracy: 0.5592
# Epoch 7/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5906 - binary_accuracy: 0.6905 - val_loss: 0.7526 - val_binary_accuracy: 0.5592
# Epoch 8/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5862 - binary_accuracy: 0.6937 - val_loss: 0.7502 - val_binary_accuracy: 0.5635
# Epoch 9/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5823 - binary_accuracy: 0.6972 - val_loss: 0.7586 - val_binary_accuracy: 0.5621
# Epoch 10/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5795 - binary_accuracy: 0.6996 - val_loss: 0.7616 - val_binary_accuracy: 0.5589
# Epoch 11/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5785 - binary_accuracy: 0.6989 - val_loss: 0.7685 - val_binary_accuracy: 0.5565
# Epoch 12/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5746 - binary_accuracy: 0.7025 - val_loss: 0.7672 - val_binary_accuracy: 0.5606
# Epoch 13/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5738 - binary_accuracy: 0.7022 - val_loss: 0.7861 - val_binary_accuracy: 0.5574
# Epoch 14/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5718 - binary_accuracy: 0.7052 - val_loss: 0.7703 - val_binary_accuracy: 0.5535
# Epoch 15/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5706 - binary_accuracy: 0.7055 - val_loss: 0.7762 - val_binary_accuracy: 0.5568
# Epoch 16/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5656 - binary_accuracy: 0.7092 - val_loss: 0.7758 - val_binary_accuracy: 0.5578
# Epoch 17/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5651 - binary_accuracy: 0.7108 - val_loss: 0.7793 - val_binary_accuracy: 0.5575
# Epoch 18/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5645 - binary_accuracy: 0.7105 - val_loss: 0.7758 - val_binary_accuracy: 0.5547
# Epoch 19/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5637 - binary_accuracy: 0.7110 - val_loss: 0.7866 - val_binary_accuracy: 0.5580
# Epoch 20/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5628 - binary_accuracy: 0.7120 - val_loss: 0.7819 - val_binary_accuracy: 0.5555
# Epoch 21/1000
# 3794/3794 [==============================] - 31s 8ms/step - loss: 0.5581 - binary_accuracy: 0.7151 - val_loss: 0.7846 - val_binary_accuracy: 0.5559
# fitted in 646.92 s
# predicted in 2.11 s
# keras_MLP_14v2 fold 3 completed in 650.94 s
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_3 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3424/3424 [==============================] - 29s 8ms/step - loss: 0.6667 - binary_accuracy: 0.6102 - val_loss: 0.7036 - val_binary_accuracy: 0.5743
# Epoch 2/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.6248 - binary_accuracy: 0.6587 - val_loss: 0.7293 - val_binary_accuracy: 0.5673
# Epoch 3/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.6053 - binary_accuracy: 0.6779 - val_loss: 0.7465 - val_binary_accuracy: 0.5674
# Epoch 4/1000
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.5998 - binary_accuracy: 0.6841 - val_loss: 0.7528 - val_binary_accuracy: 0.5715
# Epoch 5/1000
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.5900 - binary_accuracy: 0.6920 - val_loss: 0.7636 - val_binary_accuracy: 0.5684
# Epoch 6/1000
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.5855 - binary_accuracy: 0.6955 - val_loss: 0.7613 - val_binary_accuracy: 0.5696
# Epoch 7/1000
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.5812 - binary_accuracy: 0.6989 - val_loss: 0.7658 - val_binary_accuracy: 0.5711
# Epoch 8/1000
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.5801 - binary_accuracy: 0.6992 - val_loss: 0.7683 - val_binary_accuracy: 0.5665
# Epoch 9/1000
# 3424/3424 [==============================] - 28s 8ms/step - loss: 0.5748 - binary_accuracy: 0.7032 - val_loss: 0.7731 - val_binary_accuracy: 0.5658
# Epoch 10/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5738 - binary_accuracy: 0.7027 - val_loss: 0.7758 - val_binary_accuracy: 0.5617
# Epoch 11/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5676 - binary_accuracy: 0.7093 - val_loss: 0.7729 - val_binary_accuracy: 0.5666
# Epoch 12/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5668 - binary_accuracy: 0.7084 - val_loss: 0.7752 - val_binary_accuracy: 0.5689
# Epoch 13/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5648 - binary_accuracy: 0.7123 - val_loss: 0.7761 - val_binary_accuracy: 0.5660
# Epoch 14/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5624 - binary_accuracy: 0.7136 - val_loss: 0.7888 - val_binary_accuracy: 0.5679
# Epoch 15/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5591 - binary_accuracy: 0.7164 - val_loss: 0.7829 - val_binary_accuracy: 0.5653
# Epoch 16/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5569 - binary_accuracy: 0.7171 - val_loss: 0.7824 - val_binary_accuracy: 0.5692
# Epoch 17/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5561 - binary_accuracy: 0.7182 - val_loss: 0.7836 - val_binary_accuracy: 0.5712
# Epoch 18/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5554 - binary_accuracy: 0.7183 - val_loss: 0.7871 - val_binary_accuracy: 0.5684
# Epoch 19/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5533 - binary_accuracy: 0.7232 - val_loss: 0.7873 - val_binary_accuracy: 0.5642
# Epoch 20/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5531 - binary_accuracy: 0.7197 - val_loss: 0.7886 - val_binary_accuracy: 0.5669
# Epoch 21/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.5494 - binary_accuracy: 0.7230 - val_loss: 0.7836 - val_binary_accuracy: 0.5686
# fitted in 581.09 s
# predicted in 2.82 s
# keras_MLP_14v2 fold 4 completed in 586.36 s
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_4 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3950/3950 [==============================] - 33s 8ms/step - loss: 0.6670 - binary_accuracy: 0.6091 - val_loss: 0.6938 - val_binary_accuracy: 0.5773
# Epoch 2/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.6280 - binary_accuracy: 0.6573 - val_loss: 0.7244 - val_binary_accuracy: 0.5769
# Epoch 3/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.6124 - binary_accuracy: 0.6721 - val_loss: 0.7319 - val_binary_accuracy: 0.5755
# Epoch 4/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.6045 - binary_accuracy: 0.6782 - val_loss: 0.7409 - val_binary_accuracy: 0.5792
# Epoch 5/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5970 - binary_accuracy: 0.6834 - val_loss: 0.7508 - val_binary_accuracy: 0.5806
# Epoch 6/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5878 - binary_accuracy: 0.6908 - val_loss: 0.7554 - val_binary_accuracy: 0.5736
# Epoch 7/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5860 - binary_accuracy: 0.6929 - val_loss: 0.7712 - val_binary_accuracy: 0.5746
# Epoch 8/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5814 - binary_accuracy: 0.6948 - val_loss: 0.7622 - val_binary_accuracy: 0.5729
# Epoch 9/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5778 - binary_accuracy: 0.7010 - val_loss: 0.7627 - val_binary_accuracy: 0.5725
# Epoch 10/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5766 - binary_accuracy: 0.7018 - val_loss: 0.7632 - val_binary_accuracy: 0.5685
# Epoch 11/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5717 - binary_accuracy: 0.7059 - val_loss: 0.7669 - val_binary_accuracy: 0.5708
# Epoch 12/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5705 - binary_accuracy: 0.7073 - val_loss: 0.7693 - val_binary_accuracy: 0.5746
# Epoch 13/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5695 - binary_accuracy: 0.7052 - val_loss: 0.7728 - val_binary_accuracy: 0.5694
# Epoch 14/1000
# 3950/3950 [==============================] - 32s 8ms/step - loss: 0.5667 - binary_accuracy: 0.7098 - val_loss: 0.7805 - val_binary_accuracy: 0.5702
# Epoch 15/1000
# 3950/3950 [==============================] - 33s 8ms/step - loss: 0.5633 - binary_accuracy: 0.7109 - val_loss: 0.7793 - val_binary_accuracy: 0.5654
# Epoch 16/1000
# 3950/3950 [==============================] - 33s 8ms/step - loss: 0.5612 - binary_accuracy: 0.7121 - val_loss: 0.7879 - val_binary_accuracy: 0.5698
# Epoch 17/1000
# 3950/3950 [==============================] - 33s 8ms/step - loss: 0.5602 - binary_accuracy: 0.7156 - val_loss: 0.7891 - val_binary_accuracy: 0.5682
# Epoch 18/1000
# 3950/3950 [==============================] - 32s 8ms/step - loss: 0.5584 - binary_accuracy: 0.7158 - val_loss: 0.7912 - val_binary_accuracy: 0.5709
# Epoch 19/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5581 - binary_accuracy: 0.7151 - val_loss: 0.7981 - val_binary_accuracy: 0.5701
# Epoch 20/1000
# 3950/3950 [==============================] - 32s 8ms/step - loss: 0.5561 - binary_accuracy: 0.7164 - val_loss: 0.7839 - val_binary_accuracy: 0.5648
# Epoch 21/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.5551 - binary_accuracy: 0.7168 - val_loss: 0.7886 - val_binary_accuracy: 0.5654
# fitted in 658.38 s
# predicted in 1.80 s
# keras_MLP_14v2 fold 5 completed in 662.60 s
# stored keras_MLP_14v2 for negative classification in 3267.70 s
#        model_name      case  accuracy  adjusted_balanced_accuracy        f1  \
# 0  keras_MLP_14v2  negative  0.641524                    0.259782  0.636525
#
#    geometric_mean   roc_auc    fit_time  predict_time
# 0        0.618926  0.687496  649.164802      1.918022
# time: 54min 27s

# %%
case = "neutral"
model = "keras_MLP_14v2"

eval_begin = time()

print(f"evaluating {model}...")
_ = gc_collect()
store_result(
    where=results_,
    case=case,
    model_name=model,
    avg_scores=evaluate_model(model, case),
)
print(f"stored {model} for {case} classification in {time() - eval_begin:.2f} s")

del case
del model
del eval_begin
_ = gc_collect()

create_results_df(results_)
# Out:
# evaluating keras_MLP_14v2...
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_5 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.4933 - binary_accuracy: 0.7611 - val_loss: 0.6202 - val_binary_accuracy: 0.7562
# Epoch 2/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.4380 - binary_accuracy: 0.7873 - val_loss: 0.6648 - val_binary_accuracy: 0.7484
# Epoch 3/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.4209 - binary_accuracy: 0.7962 - val_loss: 0.7007 - val_binary_accuracy: 0.7497
# Epoch 4/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.4123 - binary_accuracy: 0.7999 - val_loss: 0.6970 - val_binary_accuracy: 0.7483
# Epoch 5/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.4073 - binary_accuracy: 0.8036 - val_loss: 0.7075 - val_binary_accuracy: 0.7484
# Epoch 6/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.4025 - binary_accuracy: 0.8063 - val_loss: 0.7125 - val_binary_accuracy: 0.7486
# Epoch 7/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3977 - binary_accuracy: 0.8097 - val_loss: 0.7043 - val_binary_accuracy: 0.7505
# Epoch 8/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3940 - binary_accuracy: 0.8114 - val_loss: 0.7165 - val_binary_accuracy: 0.7505
# Epoch 9/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3922 - binary_accuracy: 0.8121 - val_loss: 0.7031 - val_binary_accuracy: 0.7494
# Epoch 10/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3902 - binary_accuracy: 0.8134 - val_loss: 0.7202 - val_binary_accuracy: 0.7516
# Epoch 11/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3881 - binary_accuracy: 0.8156 - val_loss: 0.7089 - val_binary_accuracy: 0.7517
# Epoch 12/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3848 - binary_accuracy: 0.8174 - val_loss: 0.7168 - val_binary_accuracy: 0.7512
# Epoch 13/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3847 - binary_accuracy: 0.8178 - val_loss: 0.7250 - val_binary_accuracy: 0.7510
# Epoch 14/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3820 - binary_accuracy: 0.8197 - val_loss: 0.7167 - val_binary_accuracy: 0.7520
# Epoch 15/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3816 - binary_accuracy: 0.8193 - val_loss: 0.7161 - val_binary_accuracy: 0.7512
# Epoch 16/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3793 - binary_accuracy: 0.8207 - val_loss: 0.7231 - val_binary_accuracy: 0.7516
# Epoch 17/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3786 - binary_accuracy: 0.8193 - val_loss: 0.7216 - val_binary_accuracy: 0.7508
# Epoch 18/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3779 - binary_accuracy: 0.8201 - val_loss: 0.7342 - val_binary_accuracy: 0.7512
# Epoch 19/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3755 - binary_accuracy: 0.8206 - val_loss: 0.7285 - val_binary_accuracy: 0.7502
# Epoch 20/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3744 - binary_accuracy: 0.8222 - val_loss: 0.7387 - val_binary_accuracy: 0.7509
# Epoch 21/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.3726 - binary_accuracy: 0.8232 - val_loss: 0.7338 - val_binary_accuracy: 0.7513
# fitted in 659.70 s
# predicted in 1.48 s
# keras_MLP_14v2 fold 1 completed in 663.11 s
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_6 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.4984 - binary_accuracy: 0.7574 - val_loss: 0.5162 - val_binary_accuracy: 0.7942
# Epoch 2/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.4484 - binary_accuracy: 0.7810 - val_loss: 0.5435 - val_binary_accuracy: 0.7920
# Epoch 3/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.4311 - binary_accuracy: 0.7906 - val_loss: 0.5574 - val_binary_accuracy: 0.7867
# Epoch 4/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.4226 - binary_accuracy: 0.7954 - val_loss: 0.5664 - val_binary_accuracy: 0.7856
# Epoch 5/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.4165 - binary_accuracy: 0.8001 - val_loss: 0.5710 - val_binary_accuracy: 0.7836
# Epoch 6/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.4127 - binary_accuracy: 0.8028 - val_loss: 0.5666 - val_binary_accuracy: 0.7853
# Epoch 7/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.4083 - binary_accuracy: 0.8051 - val_loss: 0.5721 - val_binary_accuracy: 0.7851
# Epoch 8/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.4056 - binary_accuracy: 0.8059 - val_loss: 0.5706 - val_binary_accuracy: 0.7836
# Epoch 9/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.4023 - binary_accuracy: 0.8077 - val_loss: 0.5732 - val_binary_accuracy: 0.7825
# Epoch 10/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3987 - binary_accuracy: 0.8101 - val_loss: 0.5777 - val_binary_accuracy: 0.7840
# Epoch 11/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3986 - binary_accuracy: 0.8094 - val_loss: 0.5811 - val_binary_accuracy: 0.7839
# Epoch 12/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3974 - binary_accuracy: 0.8119 - val_loss: 0.5784 - val_binary_accuracy: 0.7844
# Epoch 13/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3965 - binary_accuracy: 0.8105 - val_loss: 0.5784 - val_binary_accuracy: 0.7836
# Epoch 14/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3941 - binary_accuracy: 0.8115 - val_loss: 0.5823 - val_binary_accuracy: 0.7828
# Epoch 15/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3899 - binary_accuracy: 0.8149 - val_loss: 0.5836 - val_binary_accuracy: 0.7836
# Epoch 16/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3897 - binary_accuracy: 0.8148 - val_loss: 0.5841 - val_binary_accuracy: 0.7812
# Epoch 17/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3886 - binary_accuracy: 0.8148 - val_loss: 0.5897 - val_binary_accuracy: 0.7829
# Epoch 18/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.3874 - binary_accuracy: 0.8162 - val_loss: 0.5949 - val_binary_accuracy: 0.7821
# Epoch 19/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.3855 - binary_accuracy: 0.8171 - val_loss: 0.5971 - val_binary_accuracy: 0.7823
# Epoch 20/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.3845 - binary_accuracy: 0.8167 - val_loss: 0.6017 - val_binary_accuracy: 0.7828
# Epoch 21/1000
# 4232/4232 [==============================] - 34s 8ms/step - loss: 0.3834 - binary_accuracy: 0.8169 - val_loss: 0.5935 - val_binary_accuracy: 0.7821
# fitted in 685.89 s
# predicted in 1.26 s
# keras_MLP_14v2 fold 2 completed in 688.95 s
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_7 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.4826 - binary_accuracy: 0.7698 - val_loss: 0.5404 - val_binary_accuracy: 0.7893
# Epoch 2/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.4281 - binary_accuracy: 0.7953 - val_loss: 0.5727 - val_binary_accuracy: 0.7896
# Epoch 3/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.4103 - binary_accuracy: 0.8040 - val_loss: 0.5747 - val_binary_accuracy: 0.7877
# Epoch 4/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.4016 - binary_accuracy: 0.8102 - val_loss: 0.5919 - val_binary_accuracy: 0.7880
# Epoch 5/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3951 - binary_accuracy: 0.8146 - val_loss: 0.5986 - val_binary_accuracy: 0.7869
# Epoch 6/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3908 - binary_accuracy: 0.8163 - val_loss: 0.5971 - val_binary_accuracy: 0.7863
# Epoch 7/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3859 - binary_accuracy: 0.8185 - val_loss: 0.5994 - val_binary_accuracy: 0.7851
# Epoch 8/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3832 - binary_accuracy: 0.8185 - val_loss: 0.6047 - val_binary_accuracy: 0.7854
# Epoch 9/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3817 - binary_accuracy: 0.8202 - val_loss: 0.6202 - val_binary_accuracy: 0.7840
# Epoch 10/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3789 - binary_accuracy: 0.8225 - val_loss: 0.6075 - val_binary_accuracy: 0.7851
# Epoch 11/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3764 - binary_accuracy: 0.8242 - val_loss: 0.6078 - val_binary_accuracy: 0.7834
# Epoch 12/1000
# 3794/3794 [==============================] - 30s 8ms/step - loss: 0.3745 - binary_accuracy: 0.8242 - val_loss: 0.5991 - val_binary_accuracy: 0.7828
# Epoch 13/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3721 - binary_accuracy: 0.8259 - val_loss: 0.6203 - val_binary_accuracy: 0.7837
# Epoch 14/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3705 - binary_accuracy: 0.8272 - val_loss: 0.5996 - val_binary_accuracy: 0.7835
# Epoch 15/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3682 - binary_accuracy: 0.8273 - val_loss: 0.6149 - val_binary_accuracy: 0.7843
# Epoch 16/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3695 - binary_accuracy: 0.8283 - val_loss: 0.6068 - val_binary_accuracy: 0.7832
# Epoch 17/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3674 - binary_accuracy: 0.8294 - val_loss: 0.6203 - val_binary_accuracy: 0.7831
# Epoch 18/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3649 - binary_accuracy: 0.8295 - val_loss: 0.6201 - val_binary_accuracy: 0.7829
# Epoch 19/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3639 - binary_accuracy: 0.8307 - val_loss: 0.6254 - val_binary_accuracy: 0.7832
# Epoch 20/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3624 - binary_accuracy: 0.8323 - val_loss: 0.6092 - val_binary_accuracy: 0.7822
# Epoch 21/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.3619 - binary_accuracy: 0.8310 - val_loss: 0.6190 - val_binary_accuracy: 0.7810
# fitted in 616.99 s
# predicted in 2.10 s
# keras_MLP_14v2 fold 3 completed in 620.92 s
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_8 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3424/3424 [==============================] - 27s 8ms/step - loss: 0.4903 - binary_accuracy: 0.7631 - val_loss: 0.5717 - val_binary_accuracy: 0.7792
# Epoch 2/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.4327 - binary_accuracy: 0.7901 - val_loss: 0.6043 - val_binary_accuracy: 0.7684
# Epoch 3/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.4152 - binary_accuracy: 0.7987 - val_loss: 0.6286 - val_binary_accuracy: 0.7684
# Epoch 4/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.4052 - binary_accuracy: 0.8038 - val_loss: 0.6318 - val_binary_accuracy: 0.7654
# Epoch 5/1000
# 3424/3424 [==============================] - 26s 7ms/step - loss: 0.4023 - binary_accuracy: 0.8067 - val_loss: 0.6318 - val_binary_accuracy: 0.7621
# Epoch 6/1000
# 3424/3424 [==============================] - 26s 7ms/step - loss: 0.3965 - binary_accuracy: 0.8095 - val_loss: 0.6357 - val_binary_accuracy: 0.7620
# Epoch 7/1000
# 3424/3424 [==============================] - 26s 7ms/step - loss: 0.3924 - binary_accuracy: 0.8111 - val_loss: 0.6419 - val_binary_accuracy: 0.7652
# Epoch 8/1000
# 3424/3424 [==============================] - 26s 7ms/step - loss: 0.3882 - binary_accuracy: 0.8141 - val_loss: 0.6373 - val_binary_accuracy: 0.7666
# Epoch 9/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3859 - binary_accuracy: 0.8160 - val_loss: 0.6342 - val_binary_accuracy: 0.7685
# Epoch 10/1000
# 3424/3424 [==============================] - 26s 7ms/step - loss: 0.3847 - binary_accuracy: 0.8156 - val_loss: 0.6448 - val_binary_accuracy: 0.7661
# Epoch 11/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3817 - binary_accuracy: 0.8188 - val_loss: 0.6445 - val_binary_accuracy: 0.7679
# Epoch 12/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3796 - binary_accuracy: 0.8190 - val_loss: 0.6343 - val_binary_accuracy: 0.7654
# Epoch 13/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3782 - binary_accuracy: 0.8207 - val_loss: 0.6311 - val_binary_accuracy: 0.7657
# Epoch 14/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3770 - binary_accuracy: 0.8209 - val_loss: 0.6456 - val_binary_accuracy: 0.7682
# Epoch 15/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3763 - binary_accuracy: 0.8213 - val_loss: 0.6413 - val_binary_accuracy: 0.7693
# Epoch 16/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3737 - binary_accuracy: 0.8207 - val_loss: 0.6503 - val_binary_accuracy: 0.7693
# Epoch 17/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3737 - binary_accuracy: 0.8211 - val_loss: 0.6482 - val_binary_accuracy: 0.7679
# Epoch 18/1000
# 3424/3424 [==============================] - 26s 7ms/step - loss: 0.3710 - binary_accuracy: 0.8246 - val_loss: 0.6459 - val_binary_accuracy: 0.7680
# Epoch 19/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3704 - binary_accuracy: 0.8234 - val_loss: 0.6379 - val_binary_accuracy: 0.7693
# Epoch 20/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3676 - binary_accuracy: 0.8255 - val_loss: 0.6549 - val_binary_accuracy: 0.7693
# Epoch 21/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.3676 - binary_accuracy: 0.8254 - val_loss: 0.6515 - val_binary_accuracy: 0.7695
# fitted in 543.65 s
# predicted in 2.76 s
# keras_MLP_14v2 fold 4 completed in 548.27 s
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_9 (AlphaDropou (None, 1024)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 2,099,201
# Trainable params: 2,099,201
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3950/3950 [==============================] - 32s 8ms/step - loss: 0.4644 - binary_accuracy: 0.7833 - val_loss: 0.5366 - val_binary_accuracy: 0.7872
# Epoch 2/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.4016 - binary_accuracy: 0.8115 - val_loss: 0.5884 - val_binary_accuracy: 0.7823
# Epoch 3/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3850 - binary_accuracy: 0.8204 - val_loss: 0.5822 - val_binary_accuracy: 0.7808
# Epoch 4/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3746 - binary_accuracy: 0.8279 - val_loss: 0.6051 - val_binary_accuracy: 0.7813
# Epoch 5/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.3689 - binary_accuracy: 0.8306 - val_loss: 0.6130 - val_binary_accuracy: 0.7828
# Epoch 6/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3648 - binary_accuracy: 0.8321 - val_loss: 0.6159 - val_binary_accuracy: 0.7807
# Epoch 7/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3612 - binary_accuracy: 0.8323 - val_loss: 0.6337 - val_binary_accuracy: 0.7797
# Epoch 8/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3575 - binary_accuracy: 0.8362 - val_loss: 0.6278 - val_binary_accuracy: 0.7801
# Epoch 9/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3551 - binary_accuracy: 0.8360 - val_loss: 0.6201 - val_binary_accuracy: 0.7791
# Epoch 10/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3504 - binary_accuracy: 0.8383 - val_loss: 0.6260 - val_binary_accuracy: 0.7790
# Epoch 11/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.3511 - binary_accuracy: 0.8383 - val_loss: 0.6372 - val_binary_accuracy: 0.7791
# Epoch 12/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.3486 - binary_accuracy: 0.8388 - val_loss: 0.6402 - val_binary_accuracy: 0.7794
# Epoch 13/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3448 - binary_accuracy: 0.8422 - val_loss: 0.6239 - val_binary_accuracy: 0.7793
# Epoch 14/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3449 - binary_accuracy: 0.8427 - val_loss: 0.6405 - val_binary_accuracy: 0.7797
# Epoch 15/1000
# 3950/3950 [==============================] - 31s 8ms/step - loss: 0.3426 - binary_accuracy: 0.8426 - val_loss: 0.6432 - val_binary_accuracy: 0.7787
# Epoch 16/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3411 - binary_accuracy: 0.8444 - val_loss: 0.6407 - val_binary_accuracy: 0.7788
# Epoch 17/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.3403 - binary_accuracy: 0.8443 - val_loss: 0.6381 - val_binary_accuracy: 0.7794
# Epoch 18/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.3389 - binary_accuracy: 0.8460 - val_loss: 0.6380 - val_binary_accuracy: 0.7810
# Epoch 19/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.3376 - binary_accuracy: 0.8466 - val_loss: 0.6469 - val_binary_accuracy: 0.7807
# Epoch 20/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.3350 - binary_accuracy: 0.8457 - val_loss: 0.6540 - val_binary_accuracy: 0.7795
# Epoch 21/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.3343 - binary_accuracy: 0.8475 - val_loss: 0.6406 - val_binary_accuracy: 0.7800
# fitted in 633.02 s
# predicted in 1.78 s
# keras_MLP_14v2 fold 5 completed in 636.64 s
# stored keras_MLP_14v2 for neutral classification in 3158.66 s
#        model_name      case  accuracy  adjusted_balanced_accuracy        f1  \
# 0  keras_MLP_14v2  negative  0.641524                    0.259782  0.636525
# 1  keras_MLP_14v2   neutral  0.782254                    0.295087  0.761256
#
#    geometric_mean   roc_auc    fit_time  predict_time
# 0        0.618926  0.687496  649.164802      1.918022
# 1        0.584846  0.804373  627.849798      1.874852
# time: 52min 38s

# %%
case = "ternary"
model = "keras_MLP_14v2"

eval_begin = time()

print(f"evaluating {model}...")
_ = gc_collect()
store_result(
    where=results_,
    case=case,
    model_name=model,
    avg_scores=evaluate_model(model, case),
)
print(f"stored {model} for {case} classification in {time() - eval_begin:.2f} s")

del case
del model
del eval_begin
_ = gc_collect()

create_results_df(results_)
# Out:
# evaluating keras_MLP_14v2...
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_10 (AlphaDropo (None, 1024)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 3075
# =================================================================
# Total params: 2,101,251
# Trainable params: 2,101,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4121/4121 [==============================] - 31s 8ms/step - loss: 0.9748 - sparse_categorical_accuracy: 0.5448 - val_loss: 1.0241 - val_sparse_categorical_accuracy: 0.5400
# Epoch 2/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.8803 - sparse_categorical_accuracy: 0.5916 - val_loss: 1.0927 - val_sparse_categorical_accuracy: 0.5295
# Epoch 3/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.8476 - sparse_categorical_accuracy: 0.6098 - val_loss: 1.1416 - val_sparse_categorical_accuracy: 0.5283
# Epoch 4/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.8290 - sparse_categorical_accuracy: 0.6217 - val_loss: 1.1440 - val_sparse_categorical_accuracy: 0.5250
# Epoch 5/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.8133 - sparse_categorical_accuracy: 0.6306 - val_loss: 1.1517 - val_sparse_categorical_accuracy: 0.5229
# Epoch 6/1000
# 4121/4121 [==============================] - 32s 8ms/step - loss: 0.8052 - sparse_categorical_accuracy: 0.6323 - val_loss: 1.1598 - val_sparse_categorical_accuracy: 0.5270
# Epoch 7/1000
# 4121/4121 [==============================] - 34s 8ms/step - loss: 0.7922 - sparse_categorical_accuracy: 0.6399 - val_loss: 1.1616 - val_sparse_categorical_accuracy: 0.5212
# Epoch 8/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7849 - sparse_categorical_accuracy: 0.6443 - val_loss: 1.1700 - val_sparse_categorical_accuracy: 0.5179
# Epoch 9/1000
# 4121/4121 [==============================] - 30s 7ms/step - loss: 0.7812 - sparse_categorical_accuracy: 0.6456 - val_loss: 1.1642 - val_sparse_categorical_accuracy: 0.5222
# Epoch 10/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7732 - sparse_categorical_accuracy: 0.6498 - val_loss: 1.1728 - val_sparse_categorical_accuracy: 0.5243
# Epoch 11/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7705 - sparse_categorical_accuracy: 0.6525 - val_loss: 1.1656 - val_sparse_categorical_accuracy: 0.5227
# Epoch 12/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7645 - sparse_categorical_accuracy: 0.6576 - val_loss: 1.1716 - val_sparse_categorical_accuracy: 0.5242
# Epoch 13/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7625 - sparse_categorical_accuracy: 0.6559 - val_loss: 1.1736 - val_sparse_categorical_accuracy: 0.5199
# Epoch 14/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7598 - sparse_categorical_accuracy: 0.6565 - val_loss: 1.1757 - val_sparse_categorical_accuracy: 0.5195
# Epoch 15/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7548 - sparse_categorical_accuracy: 0.6605 - val_loss: 1.1731 - val_sparse_categorical_accuracy: 0.5195
# Epoch 16/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7534 - sparse_categorical_accuracy: 0.6620 - val_loss: 1.1791 - val_sparse_categorical_accuracy: 0.5173
# Epoch 17/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7502 - sparse_categorical_accuracy: 0.6637 - val_loss: 1.1828 - val_sparse_categorical_accuracy: 0.5188
# Epoch 18/1000
# 4121/4121 [==============================] - 30s 7ms/step - loss: 0.7438 - sparse_categorical_accuracy: 0.6648 - val_loss: 1.1958 - val_sparse_categorical_accuracy: 0.5168
# Epoch 19/1000
# 4121/4121 [==============================] - 30s 7ms/step - loss: 0.7439 - sparse_categorical_accuracy: 0.6662 - val_loss: 1.1866 - val_sparse_categorical_accuracy: 0.5176
# Epoch 20/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7423 - sparse_categorical_accuracy: 0.6679 - val_loss: 1.1912 - val_sparse_categorical_accuracy: 0.5224
# Epoch 21/1000
# 4121/4121 [==============================] - 31s 7ms/step - loss: 0.7368 - sparse_categorical_accuracy: 0.6694 - val_loss: 1.1924 - val_sparse_categorical_accuracy: 0.5186
# fitted in 654.96 s
# predicted in 1.52 s
# keras_MLP_14v2 fold 1 completed in 658.32 s
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_11 (AlphaDropo (None, 1024)              0
# _________________________________________________________________
# dense_23 (Dense)             (None, 3)                 3075
# =================================================================
# Total params: 2,101,251
# Trainable params: 2,101,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 4232/4232 [==============================] - 33s 8ms/step - loss: 0.9798 - sparse_categorical_accuracy: 0.5399 - val_loss: 0.9594 - val_sparse_categorical_accuracy: 0.5629
# Epoch 2/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.8906 - sparse_categorical_accuracy: 0.5886 - val_loss: 0.9959 - val_sparse_categorical_accuracy: 0.5402
# Epoch 3/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.8550 - sparse_categorical_accuracy: 0.6078 - val_loss: 1.0193 - val_sparse_categorical_accuracy: 0.5362
# Epoch 4/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.8396 - sparse_categorical_accuracy: 0.6157 - val_loss: 1.0271 - val_sparse_categorical_accuracy: 0.5370
# Epoch 5/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.8265 - sparse_categorical_accuracy: 0.6226 - val_loss: 1.0403 - val_sparse_categorical_accuracy: 0.5336
# Epoch 6/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.8166 - sparse_categorical_accuracy: 0.6289 - val_loss: 1.0348 - val_sparse_categorical_accuracy: 0.5369
# Epoch 7/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.8081 - sparse_categorical_accuracy: 0.6326 - val_loss: 1.0392 - val_sparse_categorical_accuracy: 0.5325
# Epoch 8/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7985 - sparse_categorical_accuracy: 0.6359 - val_loss: 1.0426 - val_sparse_categorical_accuracy: 0.5312
# Epoch 9/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.7917 - sparse_categorical_accuracy: 0.6409 - val_loss: 1.0405 - val_sparse_categorical_accuracy: 0.5313
# Epoch 10/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7860 - sparse_categorical_accuracy: 0.6443 - val_loss: 1.0415 - val_sparse_categorical_accuracy: 0.5340
# Epoch 11/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7807 - sparse_categorical_accuracy: 0.6456 - val_loss: 1.0495 - val_sparse_categorical_accuracy: 0.5298
# Epoch 12/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7774 - sparse_categorical_accuracy: 0.6490 - val_loss: 1.0446 - val_sparse_categorical_accuracy: 0.5350
# Epoch 13/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7741 - sparse_categorical_accuracy: 0.6506 - val_loss: 1.0450 - val_sparse_categorical_accuracy: 0.5342
# Epoch 14/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7696 - sparse_categorical_accuracy: 0.6522 - val_loss: 1.0491 - val_sparse_categorical_accuracy: 0.5297
# Epoch 15/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7662 - sparse_categorical_accuracy: 0.6541 - val_loss: 1.0548 - val_sparse_categorical_accuracy: 0.5305
# Epoch 16/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7631 - sparse_categorical_accuracy: 0.6547 - val_loss: 1.0523 - val_sparse_categorical_accuracy: 0.5290
# Epoch 17/1000
# 4232/4232 [==============================] - 31s 7ms/step - loss: 0.7587 - sparse_categorical_accuracy: 0.6600 - val_loss: 1.0518 - val_sparse_categorical_accuracy: 0.5309
# Epoch 18/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.7562 - sparse_categorical_accuracy: 0.6575 - val_loss: 1.0659 - val_sparse_categorical_accuracy: 0.5284
# Epoch 19/1000
# 4232/4232 [==============================] - 32s 7ms/step - loss: 0.7538 - sparse_categorical_accuracy: 0.6608 - val_loss: 1.0632 - val_sparse_categorical_accuracy: 0.5280
# Epoch 20/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.7501 - sparse_categorical_accuracy: 0.6627 - val_loss: 1.0634 - val_sparse_categorical_accuracy: 0.5278
# Epoch 21/1000
# 4232/4232 [==============================] - 32s 8ms/step - loss: 0.7486 - sparse_categorical_accuracy: 0.6648 - val_loss: 1.0584 - val_sparse_categorical_accuracy: 0.5325
# fitted in 664.84 s
# predicted in 1.26 s
# keras_MLP_14v2 fold 2 completed in 667.80 s
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_12 (AlphaDropo (None, 1024)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 3)                 3075
# =================================================================
# Total params: 2,101,251
# Trainable params: 2,101,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.9710 - sparse_categorical_accuracy: 0.5496 - val_loss: 0.9795 - val_sparse_categorical_accuracy: 0.5565
# Epoch 2/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.8756 - sparse_categorical_accuracy: 0.5985 - val_loss: 1.0256 - val_sparse_categorical_accuracy: 0.5350
# Epoch 3/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.8416 - sparse_categorical_accuracy: 0.6145 - val_loss: 1.0467 - val_sparse_categorical_accuracy: 0.5393
# Epoch 4/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.8228 - sparse_categorical_accuracy: 0.6259 - val_loss: 1.0631 - val_sparse_categorical_accuracy: 0.5264
# Epoch 5/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.8046 - sparse_categorical_accuracy: 0.6354 - val_loss: 1.0775 - val_sparse_categorical_accuracy: 0.5249
# Epoch 6/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7945 - sparse_categorical_accuracy: 0.6396 - val_loss: 1.0891 - val_sparse_categorical_accuracy: 0.5222
# Epoch 7/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7880 - sparse_categorical_accuracy: 0.6454 - val_loss: 1.0874 - val_sparse_categorical_accuracy: 0.5231
# Epoch 8/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7785 - sparse_categorical_accuracy: 0.6497 - val_loss: 1.0970 - val_sparse_categorical_accuracy: 0.5216
# Epoch 9/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7717 - sparse_categorical_accuracy: 0.6524 - val_loss: 1.1143 - val_sparse_categorical_accuracy: 0.5209
# Epoch 10/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7646 - sparse_categorical_accuracy: 0.6545 - val_loss: 1.1042 - val_sparse_categorical_accuracy: 0.5190
# Epoch 11/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7592 - sparse_categorical_accuracy: 0.6591 - val_loss: 1.1062 - val_sparse_categorical_accuracy: 0.5249
# Epoch 12/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7551 - sparse_categorical_accuracy: 0.6600 - val_loss: 1.1024 - val_sparse_categorical_accuracy: 0.5193
# Epoch 13/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7509 - sparse_categorical_accuracy: 0.6635 - val_loss: 1.1235 - val_sparse_categorical_accuracy: 0.5182
# Epoch 14/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7485 - sparse_categorical_accuracy: 0.6647 - val_loss: 1.1031 - val_sparse_categorical_accuracy: 0.5150
# Epoch 15/1000
# 3794/3794 [==============================] - 29s 8ms/step - loss: 0.7438 - sparse_categorical_accuracy: 0.6683 - val_loss: 1.1103 - val_sparse_categorical_accuracy: 0.5193
# Epoch 16/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7397 - sparse_categorical_accuracy: 0.6683 - val_loss: 1.1010 - val_sparse_categorical_accuracy: 0.5237
# Epoch 17/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7375 - sparse_categorical_accuracy: 0.6701 - val_loss: 1.1172 - val_sparse_categorical_accuracy: 0.5176
# Epoch 18/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7341 - sparse_categorical_accuracy: 0.6731 - val_loss: 1.1211 - val_sparse_categorical_accuracy: 0.5160
# Epoch 19/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7332 - sparse_categorical_accuracy: 0.6743 - val_loss: 1.1290 - val_sparse_categorical_accuracy: 0.5185
# Epoch 20/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7303 - sparse_categorical_accuracy: 0.6762 - val_loss: 1.1123 - val_sparse_categorical_accuracy: 0.5168
# Epoch 21/1000
# 3794/3794 [==============================] - 28s 7ms/step - loss: 0.7288 - sparse_categorical_accuracy: 0.6760 - val_loss: 1.1224 - val_sparse_categorical_accuracy: 0.5148
# fitted in 597.50 s
# predicted in 2.13 s
# keras_MLP_14v2 fold 3 completed in 601.36 s
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_26 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_13 (AlphaDropo (None, 1024)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 3)                 3075
# =================================================================
# Total params: 2,101,251
# Trainable params: 2,101,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.9672 - sparse_categorical_accuracy: 0.5481 - val_loss: 0.9925 - val_sparse_categorical_accuracy: 0.5765
# Epoch 2/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.8712 - sparse_categorical_accuracy: 0.5984 - val_loss: 1.0436 - val_sparse_categorical_accuracy: 0.5571
# Epoch 3/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.8352 - sparse_categorical_accuracy: 0.6202 - val_loss: 1.0685 - val_sparse_categorical_accuracy: 0.5543
# Epoch 4/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.8189 - sparse_categorical_accuracy: 0.6296 - val_loss: 1.0772 - val_sparse_categorical_accuracy: 0.5502
# Epoch 5/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.8010 - sparse_categorical_accuracy: 0.6390 - val_loss: 1.0818 - val_sparse_categorical_accuracy: 0.5499
# Epoch 6/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7916 - sparse_categorical_accuracy: 0.6436 - val_loss: 1.0875 - val_sparse_categorical_accuracy: 0.5469
# Epoch 7/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7834 - sparse_categorical_accuracy: 0.6477 - val_loss: 1.0999 - val_sparse_categorical_accuracy: 0.5474
# Epoch 8/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7738 - sparse_categorical_accuracy: 0.6534 - val_loss: 1.0928 - val_sparse_categorical_accuracy: 0.5481
# Epoch 9/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7695 - sparse_categorical_accuracy: 0.6550 - val_loss: 1.0970 - val_sparse_categorical_accuracy: 0.5466
# Epoch 10/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7634 - sparse_categorical_accuracy: 0.6567 - val_loss: 1.0999 - val_sparse_categorical_accuracy: 0.5438
# Epoch 11/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7599 - sparse_categorical_accuracy: 0.6596 - val_loss: 1.1044 - val_sparse_categorical_accuracy: 0.5439
# Epoch 12/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7548 - sparse_categorical_accuracy: 0.6641 - val_loss: 1.0947 - val_sparse_categorical_accuracy: 0.5435
# Epoch 13/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.7494 - sparse_categorical_accuracy: 0.6637 - val_loss: 1.0960 - val_sparse_categorical_accuracy: 0.5418
# Epoch 14/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.7480 - sparse_categorical_accuracy: 0.6660 - val_loss: 1.1032 - val_sparse_categorical_accuracy: 0.5471
# Epoch 15/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7422 - sparse_categorical_accuracy: 0.6677 - val_loss: 1.0958 - val_sparse_categorical_accuracy: 0.5462
# Epoch 16/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7401 - sparse_categorical_accuracy: 0.6705 - val_loss: 1.1027 - val_sparse_categorical_accuracy: 0.5454
# Epoch 17/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7371 - sparse_categorical_accuracy: 0.6728 - val_loss: 1.0972 - val_sparse_categorical_accuracy: 0.5461
# Epoch 18/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7354 - sparse_categorical_accuracy: 0.6710 - val_loss: 1.1003 - val_sparse_categorical_accuracy: 0.5441
# Epoch 19/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7313 - sparse_categorical_accuracy: 0.6733 - val_loss: 1.1005 - val_sparse_categorical_accuracy: 0.5415
# Epoch 20/1000
# 3424/3424 [==============================] - 26s 8ms/step - loss: 0.7302 - sparse_categorical_accuracy: 0.6748 - val_loss: 1.1110 - val_sparse_categorical_accuracy: 0.5431
# Epoch 21/1000
# 3424/3424 [==============================] - 25s 7ms/step - loss: 0.7249 - sparse_categorical_accuracy: 0.6765 - val_loss: 1.1108 - val_sparse_categorical_accuracy: 0.5421
# fitted in 535.97 s
# predicted in 2.85 s
# keras_MLP_14v2 fold 4 completed in 540.57 s
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# alpha_dropout_14 (AlphaDropo (None, 1024)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 3)                 3075
# =================================================================
# Total params: 2,101,251
# Trainable params: 2,101,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.9459 - sparse_categorical_accuracy: 0.5632 - val_loss: 0.9780 - val_sparse_categorical_accuracy: 0.5689
# Epoch 2/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.8489 - sparse_categorical_accuracy: 0.6130 - val_loss: 1.0385 - val_sparse_categorical_accuracy: 0.5558
# Epoch 3/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.8132 - sparse_categorical_accuracy: 0.6295 - val_loss: 1.0562 - val_sparse_categorical_accuracy: 0.5473
# Epoch 4/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7924 - sparse_categorical_accuracy: 0.6434 - val_loss: 1.0806 - val_sparse_categorical_accuracy: 0.5478
# Epoch 5/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.7760 - sparse_categorical_accuracy: 0.6503 - val_loss: 1.0948 - val_sparse_categorical_accuracy: 0.5404
# Epoch 6/1000
# 3950/3950 [==============================] - 30s 8ms/step - loss: 0.7672 - sparse_categorical_accuracy: 0.6537 - val_loss: 1.0986 - val_sparse_categorical_accuracy: 0.5422
# Epoch 7/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7580 - sparse_categorical_accuracy: 0.6591 - val_loss: 1.1216 - val_sparse_categorical_accuracy: 0.5430
# Epoch 8/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7500 - sparse_categorical_accuracy: 0.6645 - val_loss: 1.1169 - val_sparse_categorical_accuracy: 0.5389
# Epoch 9/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7433 - sparse_categorical_accuracy: 0.6679 - val_loss: 1.1067 - val_sparse_categorical_accuracy: 0.5436
# Epoch 10/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.7397 - sparse_categorical_accuracy: 0.6686 - val_loss: 1.1151 - val_sparse_categorical_accuracy: 0.5377
# Epoch 11/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.7330 - sparse_categorical_accuracy: 0.6730 - val_loss: 1.1299 - val_sparse_categorical_accuracy: 0.5377
# Epoch 12/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7302 - sparse_categorical_accuracy: 0.6744 - val_loss: 1.1266 - val_sparse_categorical_accuracy: 0.5389
# Epoch 13/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7231 - sparse_categorical_accuracy: 0.6763 - val_loss: 1.1205 - val_sparse_categorical_accuracy: 0.5396
# Epoch 14/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7211 - sparse_categorical_accuracy: 0.6777 - val_loss: 1.1317 - val_sparse_categorical_accuracy: 0.5379
# Epoch 15/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7149 - sparse_categorical_accuracy: 0.6819 - val_loss: 1.1393 - val_sparse_categorical_accuracy: 0.5365
# Epoch 16/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7145 - sparse_categorical_accuracy: 0.6837 - val_loss: 1.1384 - val_sparse_categorical_accuracy: 0.5393
# Epoch 17/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7084 - sparse_categorical_accuracy: 0.6853 - val_loss: 1.1371 - val_sparse_categorical_accuracy: 0.5382
# Epoch 18/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7071 - sparse_categorical_accuracy: 0.6868 - val_loss: 1.1397 - val_sparse_categorical_accuracy: 0.5392
# Epoch 19/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.7057 - sparse_categorical_accuracy: 0.6876 - val_loss: 1.1466 - val_sparse_categorical_accuracy: 0.5355
# Epoch 20/1000
# 3950/3950 [==============================] - 30s 7ms/step - loss: 0.7027 - sparse_categorical_accuracy: 0.6884 - val_loss: 1.1430 - val_sparse_categorical_accuracy: 0.5343
# Epoch 21/1000
# 3950/3950 [==============================] - 29s 7ms/step - loss: 0.6990 - sparse_categorical_accuracy: 0.6920 - val_loss: 1.1434 - val_sparse_categorical_accuracy: 0.5376
# fitted in 621.87 s
# predicted in 1.82 s
# keras_MLP_14v2 fold 5 completed in 625.44 s
# stored keras_MLP_14v2 for ternary classification in 3094.21 s
#        model_name      case  accuracy  adjusted_balanced_accuracy        f1  \
# 0  keras_MLP_14v2  negative  0.641524                    0.259782  0.636525
# 1  keras_MLP_14v2   neutral  0.782254                    0.295087  0.761256
# 2  keras_MLP_14v2   ternary  0.597679                    0.230980  0.561375
#
#    geometric_mean   roc_auc    fit_time  predict_time
# 0        0.618926  0.687496  649.164802      1.918022
# 1        0.584846  0.804373  627.849798      1.874852
# 2        0.388399  0.727528  615.027259      1.913936
# time: 51min 34s

# %%
# save predictions
predictions_df = pd.DataFrame(predictions_)[["model", "case", "fold", "y_pred"]]
predictions_df.case = predictions_df.case.astype("category")
predictions_df.fold = predictions_df.fold.astype(np.uint8)
predictions_df.to_pickle(f"{DATA_OUT_FOLDER}/keras_MLPv2_14_predictions_CV5.pkl")
del predictions_df
_ = gc_collect()
# Out:
# time: 140 ms

# %% [markdown]
# Let's peek at the results.

# %%
results_df = create_results_df(results_)
results_df
# Out:
#        model_name      case  accuracy  adjusted_balanced_accuracy        f1  \
# 0  keras_MLP_14v2  negative  0.641524                    0.259782  0.636525
# 1  keras_MLP_14v2   neutral  0.782254                    0.295087  0.761256
# 2  keras_MLP_14v2   ternary  0.597679                    0.230980  0.561375
#
#    geometric_mean   roc_auc    fit_time  predict_time
# 0        0.618926  0.687496  649.164802      1.918022
# 1        0.584846  0.804373  627.849798      1.874852
# 2        0.388399  0.727528  615.027259      1.913936
# time: 28 ms

# %% [markdown]
# # Metaclassifier

# %%
def prep_y_pred(label: int) -> np.ndarray:
    """Prepares ternary labels for AUROC scoring"""
    _ = [0, 0, 0]
    _[label] = 1
    return np.asarray(_, dtype=np.int8)


model_name = "keras_MLP_14v2+keras_MLP_14v2"
pred_df = pd.DataFrame(predictions_).query(f"case != 'ternary'")[
    ["case", "fold", "y_pred"]
]
accuracy, adjusted_balanced_accuracy, f1, geometric_mean, roc_auc = (
    [] for _ in range(5)
)
for fold_num in np.unique(pred_df.fold):
    fold_df = pred_df.query(f"fold == {fold_num}").drop(columns="fold")
    query_fold = lambda case: fold_df.query(f"case == '{case}'").y_pred.item()
    df = pd.DataFrame(
        {
            "neutral_prediction": query_fold("neutral"),
            "negative_prediction": query_fold("negative"),
        }
    )
    del fold_df
    del query_fold
    _ = gc_collect()

    # "predict" 0: negative, 1: neutral, 2: positive
    df["hybrid_prediction"] = df.loc[:, "neutral_prediction"]
    df.loc[df["hybrid_prediction"] == 0, "hybrid_prediction"] = (-1) * df.loc[
        df["hybrid_prediction"] == 0, "negative_prediction"
    ] + 2
    y_pred: pd.Series = df.hybrid_prediction.astype(np.int8)
    del df
    _ = gc_collect()

    # record y_pred
    store_prediction(
        where=predictions_,
        prediction=Prediction(
            model=model_name,
            case="ternary_negneu",
            fold=fold_num,
            y_pred=y_pred,
        ),
    )

    # score
    score_params = {
        "y_true": pd.read_feather(
            f"{FRILL_FEATHERS_FOLDER}/cv_{fold_num}/y_test_ter.feather"
        ).iloc[:, 0],
        "y_pred": y_pred,
    }
    accuracy.append(accuracy_score(**score_params))
    adjusted_balanced_accuracy.append(
        balanced_accuracy_score(**score_params, adjusted=True)
    )
    f1.append(f1_score(**score_params, average="weighted"))
    geometric_mean.append(geometric_mean_score(**score_params))
    score_params = {
        "y_true": score_params["y_true"],
        "y_score": np.stack(y_pred.swifter.apply(prep_y_pred).values),
        "average": "weighted",
        "multi_class": "ovo",
    }
    roc_auc.append(roc_auc_score(**score_params))
    del score_params
    del y_pred
    _ = gc_collect()
del pred_df
_ = gc_collect()

# helper functions
get_time = lambda case, fit_predict: results_df.query(
    f"case == '{case}' & model_name == 'keras_MLP_14v2'"
)[f"{fit_predict}_time"].item()
sum_times = lambda time_metric: get_time("negative", time_metric) + get_time(
    "neutral", time_metric
)

store_result(
    where=results_,
    case="ternary_negneu",
    model_name=model_name,
    avg_scores=AvgScores(
        np.mean(accuracy),
        np.mean(adjusted_balanced_accuracy),
        np.mean(f1),
        np.mean(geometric_mean),
        np.mean(roc_auc),
        sum_times("fit"),
        sum_times("predict"),
    ),
)

print(f"stored hybrid ternary classification results for {model_name}")

del accuracy
del adjusted_balanced_accuracy
del f1
del geometric_mean
del roc_auc
del model_name
del get_time
del sum_times
_ = gc_collect()
# Out:
# Pandas Apply: 100%|██████████| 13494/13494 [00:00<00:00, 151611.50it/s]
# Pandas Apply: 100%|██████████| 11524/11524 [00:00<00:00, 205761.21it/s]
# Pandas Apply: 100%|██████████| 19319/19319 [00:00<00:00, 250954.70it/s]
# Pandas Apply: 100%|██████████| 25883/25883 [00:00<00:00, 241965.95it/s]
# Pandas Apply: 100%|██████████| 16532/16532 [00:00<00:00, 250435.15it/s]
# stored hybrid ternary classification results for keras_MLP_14v2+keras_MLP_14v2
# time: 3.08 s

# %% [markdown]
# # Results

# %%
results_df = create_results_df(results_)
results_df
# Out:
#                       model_name            case  accuracy  \
# 0                 keras_MLP_14v2        negative  0.641524
# 1                 keras_MLP_14v2         neutral  0.782254
# 2                 keras_MLP_14v2         ternary  0.597679
# 3  keras_MLP_14v2+keras_MLP_14v2  ternary_negneu  0.245509
#
#    adjusted_balanced_accuracy        f1  geometric_mean   roc_auc  \
# 0                    0.259782  0.636525        0.618926  0.687496
# 1                    0.295087  0.761256        0.584846  0.804373
# 2                    0.230980  0.561375        0.388399  0.727528
# 3                    0.012639  0.152383        0.000000  0.504675
#
#       fit_time  predict_time
# 0   649.164802      1.918022
# 1   627.849798      1.874852
# 2   615.027259      1.913936
# 3  1277.014600      3.792873
# time: 23 ms

# %%
# save table of results
results_df.to_csv(f"{DATA_OUT_FOLDER}/initial_MLPv2_results_CV5.csv")
# Out:
# time: 7.97 ms

# %% [markdown]
# # Discussion
#
# hopefully good performance

# %%
print(f"Time elapsed since notebook_begin_time: {time() - notebook_begin_time} s")
_ = gc_collect()
# Out:
# Time elapsed since notebook_begin_time: 9533.056864976883 s
# time: 120 ms

# %% [markdown]
# [^top](#Contents)
