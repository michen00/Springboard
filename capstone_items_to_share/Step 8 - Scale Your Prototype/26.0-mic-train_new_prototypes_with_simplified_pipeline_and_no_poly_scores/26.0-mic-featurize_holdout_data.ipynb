# %% [markdown]
# # Contents
# * [Introduction](#Introduction)
# * [Imports and configuration](#Imports-and-configuration)
# * [Data loading](#Data-loading)
# * [Setup](#Setup)
# * [Select FRILL columns](#Select-FRILL-columns)
# * [Linear discriminant analysis of FRILL embeddings](#Linear-discriminant-analysis-of-FRILL-embeddings)
# * [One-class linear discriminant analysis of FRILL embeddings](#One-class-linear-discriminant-analysis-of-FRILL-embeddings)
# * [Local outlier factor of LDA components of FRILL embeddings](#Local-outlier-factor-of-LDA-components-of-FRILL-embeddings)
# * [One-class SVM scores of the LDA components of the FRILL embeddings](One-class-SVM-scores-of-the-LDA-components-of-the-FRILL-embeddings)
# * [SGDOneClassSVM scores of FRILL embeddings and resultant LDA components](#SGDOneClassSVM-scores-of-FRILL-embeddings-and-resultant-LDA-components)
# * [Spherical coordinates](#Spherical-coordinates)
# * [LDA components of spherical FRILL-based features](#LDA-components-of-spherical-FRILL-based-features)
# * [One-class LDA components of spherical FRILL-based features](#One-class-LDA-components-of-spherical-FRILL-based-features)
# * [Aggregate and scale](#Aggregate-and-scale)
# * [Spot check](#Spot-check)
# * [Discussion](#Discussion)

# %% [markdown]
# # Introduction
#
# Three holdout datasets have been identified. This notebook featurizes them.

# %% [markdown]
# # Imports and configuration

# %%
from time import time

notebook_begin_time = time()

# set random seeds

from os import environ
from random import seed as random_seed
from numpy.random import seed as np_seed
from tensorflow.random import set_seed


def reset_seeds(seed: int) -> None:
    """Utility function for resetting random seeds"""
    environ["PYTHONHASHSEED"] = str(seed)
    random_seed(seed)
    np_seed(seed)
    set_seed(seed)


reset_seeds(SEED := 2022)
del environ
del random_seed
del np_seed
del set_seed
del reset_seeds

# %%
# extensions
# %load_ext autotime
# %load_ext lab_black
# %load_ext nb_black

# %%
# core
import numpy as np
import pandas as pd

# utility
from copy import deepcopy
from joblib import load as joblib_load
from gc import collect as gc_collect
from tqdm.notebook import tqdm

# faster
import swifter
from sklearnex import patch_sklearn

patch_sklearn()
del patch_sklearn

# spherical coordinates
from numpy import arctan2, sqrt

# other sklearn
from sklearn.linear_model import SGDOneClassSVM
from sklearn.svm import OneClassSVM

# typing
from typing import Callable, List

# visualization
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %matplotlib widget
sns.set_theme(context="notebook", style="ticks", palette="colorblind")

# display outputs w/o print calls
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
del InteractiveShell
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# time: 3.66 s

# %%
# Location of exported feature extractors
FEATURE_EXTRACTORS = "./feature_extractors"

# Location of holdout labels and FRILL columns
HOLDOUT = "../21.0-mic-prepare_holdout_datasets_for_evaluation"

# Location where this notebook will output
OUT_FOLDER = "."

_ = gc_collect()
# Out:
# time: 118 ms

# %% [markdown]
# # Setup

# %%
# valence label codes
VALENCE = {"neg": 0, "neu": 1, "pos": 2}
VALENCES = ("neg", "neu", "pos")
NEIGHBORS = (10, 20, 30)
OC_SVM = ("sgdlinear", "rbf", "sigmoid")

feature_trio = lambda prefix, suffix: [
    f"{f'{prefix}_' if prefix else ''}{valence}{f'_{suffix}' if suffix else ''}"
    for valence in VALENCES
]

load_extractor = lambda feature_file: joblib_load(
    f"{FEATURE_EXTRACTORS}/{feature_file}.joblib"
)


def spot_check(
    data: pd.DataFrame, labels: pd.DataFrame, expected_columns: List[str] = []
) -> None:
    """Spot check feature extraction process"""
    assert all(data.index == labels.index)
    assert not data.isnull().values.any()
    if expected_columns:
        assert list(data.columns) == expected_columns
    print(data.info())
    print(data.head())


_ = gc_collect()
# Out:
# time: 125 ms

# %%
def plot1d(data: pd.DataFrame, labels: pd.DataFrame, x: str) -> None:
    sns.displot(
        x=data[x],
        hue=labels.valence,
        palette="viridis",
        linewidth=0,
        alpha=0.75,
        legend=False,
    )
    sns.despine(top=True, right=True)
    plt.tight_layout()
    plt.show()


_ = -gc_collect()
# Out:
# time: 139 ms

# %%
def plot2d(data: pd.DataFrame, labels: pd.DataFrame, x: str, y: str) -> None:
    """Scatterplot of two variables"""
    _ = sns.histplot(
        x=data[x],
        y=data[y],
        cmap="RdPu",
        linewidth=0,
        alpha=0.2,
        legend=False,
        kde=True,
    )
    _ = sns.scatterplot(
        x=data[x],
        y=data[y],
        hue=labels.valence,
        palette="viridis",
        linewidth=0,
        alpha=0.75,
        legend=False,
        s=10,
    )
    sns.despine(**dict.fromkeys("top right left bottom".split(), True))
    plt.show()


_ = gc_collect()
# Out:
# time: 143 ms

# %%
def plot3d(data: pd.DataFrame, labels: pd.DataFrame, x: str, y: str, z: str) -> None:
    """Scatterplot of three variables"""
    fig = plt.figure(figsize=(7, 7))
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(
        data[x],
        data[y],
        data[z],
        alpha=0.5,
        linewidth=0,
        cmap="viridis",
        c=labels.valence,
    )
    ax.grid(False)
    plt.show()


_ = gc_collect()
# Out:
# time: 132 ms

# %%
def checkpoint_features(df: pd.DataFrame, features: List[str]) -> None:
    """Save features to disk as a .feather dataframe"""
    df = df.loc[:, features]
    df.columns = df.columns.astype(str)
    try:
        df.to_feather(
            _ := f"{OUT_FOLDER}/holdout_{'_-_'.join(features) if len(features) > 1 else features[0]}.feather"
        )
    except ValueError:
        df.reset_index().to_feather(_)


_ = gc_collect()
# Out:
# time: 124 ms

# %% [markdown]
# # Load data

# %%
frill = pd.read_feather(f"{HOLDOUT}/holdout_FRILL.feather")
labels = pd.read_feather(f"{HOLDOUT}/holdout_labels.feather").drop(columns="id")
spot_check(frill, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Columns: 2048 entries, 0 to 2047
# dtypes: float32(2048)
# memory usage: 15.3 MB
# None
#           0         1         2         3         4         5         6  \
# 0 -0.035624  0.148898 -0.109508 -0.016199 -0.084427 -0.067872  0.174007
# 1 -0.103035  0.082011  0.110948 -0.060209 -0.073397  0.009772 -0.020830
# 2 -0.065101  0.038458 -0.029423  0.005429 -0.023002  0.152135  0.053979
# 3  0.083481  0.138969 -0.030347  0.062699  0.073357 -0.039354 -0.089715
# 4  0.019141  0.170539 -0.056348  0.032532 -0.089482  0.079703  0.037175
#
#           7         8         9  ...      2038      2039      2040      2041  \
# 0 -0.033383 -0.017896 -0.024012  ... -0.153698  0.041551 -0.003445 -0.059062
# 1  0.044276  0.046892 -0.115516  ...  0.065289  0.075569 -0.089013 -0.161597
# 2 -0.039011  0.017791 -0.077413  ... -0.042246 -0.004320 -0.040200 -0.049798
# 3  0.113456  0.039636 -0.041954  ...  0.022920 -0.181787  0.011134 -0.073927
# 4  0.046567 -0.053409 -0.061816  ...  0.078809 -0.044437 -0.086229  0.048539
#
#        2042      2043      2044      2045      2046      2047
# 0 -0.028037 -0.026091  0.101007 -0.078234  0.112814  0.098813
# 1  0.017945  0.073644  0.058319  0.030772  0.066552  0.088602
# 2 -0.081791 -0.091844  0.164188  0.060485 -0.003494  0.048290
# 3 -0.014689  0.049779  0.044533 -0.063511  0.020476 -0.018876
# 4  0.104972 -0.050087  0.052254  0.117372  0.042914  0.049517
#
# [5 rows x 2048 columns]
# time: 233 ms

# %%
labels.reset_index(drop=True).to_feather(f"{OUT_FOLDER}/holdout_labels.feather")
# Out:
# time: 16 ms

# %% [markdown]
# # Select FRILL columns

# %%
# selector = load_extractor("frill_column_selector")
# selected_frill_columns = selector.get_feature_names_out(frill.columns)
with open(
    "../23.0-mic-train_new_prototypes_with_simplified_pipeline/selected_frill_columns.txt",
    "r",
) as f:
    selected_frill_columns = f.readlines()
selected_frill_columns = [line.strip() for line in selected_frill_columns]
# frill = pd.DataFrame(selector.transform(frill), columns=selected_frill_columns)
frill = frill.loc[:, selected_frill_columns]
spot_check(frill, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Columns: 1024 entries, 0 to 2047
# dtypes: float32(1024)
# memory usage: 7.6 MB
# None
#           0         7        15        16        18        20        21  \
# 0 -0.035624 -0.033383  0.043033 -0.041507  0.226673  0.008828  0.176655
# 1 -0.103035  0.044276  0.059442 -0.119909  0.345795  0.045072  0.067420
# 2 -0.065101 -0.039011  0.028183 -0.048056  0.059421 -0.064515  0.084881
# 3  0.083481  0.113456  0.039784 -0.049637  0.207155  0.128711  0.013286
# 4  0.019141  0.046567  0.015699 -0.064816  0.255913  0.091518  0.044819
#
#          22        30        32  ...      2023      2024      2026      2028  \
# 0 -0.029301  0.070888  0.012144  ...  0.040793  0.047765 -0.024035 -0.051325
# 1  0.050928 -0.068873  0.043356  ...  0.049300 -0.069195  0.022934  0.004956
# 2 -0.066782  0.055454 -0.004342  ... -0.026597 -0.028739  0.078741  0.086177
# 3  0.136444  0.035383 -0.020022  ... -0.000103  0.099276  0.011584 -0.039387
# 4 -0.034101  0.015374 -0.023901  ... -0.010310  0.017890  0.022961  0.050722
#
#        2033      2036      2042      2043      2044      2047
# 0  0.396450 -0.090019 -0.028037 -0.026091  0.101007  0.098813
# 1  0.691531 -0.082789  0.017945  0.073644  0.058319  0.088602
# 2  0.533408 -0.121286 -0.081791 -0.091844  0.164188  0.048290
# 3  0.743194 -0.160314 -0.014689  0.049779  0.044533 -0.018876
# 4  0.585126  0.014135  0.104972 -0.050087  0.052254  0.049517
#
# [5 rows x 1024 columns]
# time: 82 ms

# %% [markdown]
# # Linear discriminant analysis components of FRILL embeddings

# %%
features = ["LDA1", "LDA2"]
data = pd.DataFrame(load_extractor("LDA1_-_LDA2").transform(frill), columns=features)
spot_check(data, labels)
plot2d(data, labels, *features)
checkpoint_features(data, features)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LDA1    1957 non-null   float64
#  1   LDA2    1957 non-null   float64
# dtypes: float64(2)
# memory usage: 30.7 KB
# None
#        LDA1      LDA2
# 0 -1.506022  0.724455
# 1 -2.012732  0.636784
# 2 -1.592665  1.856882
# 3 -0.224248  2.123781
# 4 -1.645159  1.678552
# time: 1.18 s

# %% [markdown]
# # One-class linear discriminant analysis of FRILL embeddings

# %%
df = deepcopy(frill)
features = []
for valence in VALENCES:
    feature = f"ocLDA_{valence}"
    df[feature] = np.squeeze(
        load_extractor(feature).transform(df.loc[:, frill.columns])
    )
    features.append(feature)
    del feature
    _ = gc_collect()
data = pd.concat(
    [data, df.loc[:, feature_trio("ocLDA", "")]],
    axis="columns",
)
spot_check(data, labels)
plot3d(data, labels, *features)
checkpoint_features(data, features)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LDA1       1957 non-null   float64
#  1   LDA2       1957 non-null   float64
#  2   ocLDA_neg  1957 non-null   float64
#  3   ocLDA_neu  1957 non-null   float64
#  4   ocLDA_pos  1957 non-null   float64
# dtypes: float64(5)
# memory usage: 76.6 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069
# time: 987 ms

# %%
del df
_ = gc_collect()
# Out:
# time: 169 ms

# %% [markdown]
# # Local outlier factor of LDA components of FRILL embeddings

# %%
n_neighbors = 20
features = []
for valence in tqdm(VALENCES):
    feature = f"LDA-LOF_{valence}_{n_neighbors}"
    data[feature] = load_extractor(feature).score_samples(data.loc[:, ["LDA1", "LDA2"]])
    features.append(feature)
    del feature
    _ = gc_collect()

spot_check(data, labels)
plot3d(data, labels, *features)
checkpoint_features(data, features)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LDA1            1957 non-null   float64
#  1   LDA2            1957 non-null   float64
#  2   ocLDA_neg       1957 non-null   float64
#  3   ocLDA_neu       1957 non-null   float64
#  4   ocLDA_pos       1957 non-null   float64
#  5   LDA-LOF_neg_20  1957 non-null   float64
#  6   LDA-LOF_neu_20  1957 non-null   float64
#  7   LDA-LOF_pos_20  1957 non-null   float64
# dtypes: float64(8)
# memory usage: 122.4 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LDA-LOF_neg_20  \
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790       -1.007432
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870       -1.032912
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155       -1.024155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857       -1.023477
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069       -1.136594
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20
# 0       -1.303784       -1.024339
# 1       -1.466157       -1.028627
# 2       -1.156847       -1.042566
# 3       -1.029984       -1.056383
# 4       -1.149785       -0.986925
# time: 919 ms

# %% [markdown]
# # One-class SVM scores of the LDA components of the FRILL embeddings

# %%
def extract_ocsvm_features(
    df: pd.DataFrame, labels: pd.DataFrame, descriptor: str
) -> pd.DataFrame:
    """Extract features using the given one-class SVM base"""
    prefix = f"ocSVM_{descriptor}"
    assert all(df.index == labels.index)

    # one-class scores of LDA components of FRILL embeddings
    print("extracting one-class scores of LDA components of FRILL embeddings...")
    for valence in VALENCE.keys():
        feature = f"LDA-{prefix}_{valence}"
        df[feature] = load_extractor(feature).score_samples(df.loc[:, ["LDA1", "LDA2"]])
        del feature
        _ = gc_collect()
    assert all(df.index == labels.index)
    features = [f"LDA-{prefix}_neg", f"LDA-{prefix}_neu", f"LDA-{prefix}_pos"]
    plot3d(df, labels, *features)
    checkpoint_features(df, features)

    return df


_ = gc_collect()
# Out:
# time: 157 ms

# %%
for oc_svm in tqdm(OC_SVM):
    data = extract_ocsvm_features(data, labels, oc_svm)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# extracting one-class scores of LDA components of FRILL embeddings...
# extracting one-class scores of LDA components of FRILL embeddings...
# extracting one-class scores of LDA components of FRILL embeddings...
# time: 18.5 s

# %% [markdown]
# # SGDOneClassSVM scores of FRILL embeddings and resultant LDA components

# %%
prefix = f"ocSVM_sgdlinear"
for valence in VALENCE.keys():
    feature = f"{prefix}_{valence}"
    data[feature] = load_extractor(feature).score_samples(frill)
    _ = gc_collect()
features = [f"{prefix}_neg", f"{prefix}_neu", f"{prefix}_pos"]
plot3d(data, labels, *features)
checkpoint_features(data, features)
# Out:
# time: 773 ms

# %%
prefix = "ocSVM_sgdlinear"
features = [f"{prefix}_neg", f"{prefix}_neu", f"{prefix}_pos"]
features_ = ["ocSVM_sgdlinear_LDA1", "ocSVM_sgdlinear_LDA2"]
df = pd.DataFrame(
    load_extractor("_-_".join(features_)).transform(data.loc[:, features]),
    columns=features_,
)
df.index = labels.index
data = pd.concat([data, df], axis="columns")
_ = gc_collect()
assert not data.isnull().values.any()
plot2d(data, labels, *features_)
checkpoint_features(data, features_)
spot_check(data, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LDA-LOF_neg_20           1957 non-null   float64
#  6   LDA-LOF_neu_20           1957 non-null   float64
#  7   LDA-LOF_pos_20           1957 non-null   float64
#  8   LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  9   LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  10  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  11  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  12  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  13  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  14  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  15  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  16  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  17  ocSVM_sgdlinear_neg      1957 non-null   float64
#  18  ocSVM_sgdlinear_neu      1957 non-null   float64
#  19  ocSVM_sgdlinear_pos      1957 non-null   float64
#  20  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  21  ocSVM_sgdlinear_LDA2     1957 non-null   float64
# dtypes: float64(22)
# memory usage: 336.5 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LDA-LOF_neg_20  \
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790       -1.007432
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870       -1.032912
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155       -1.024155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857       -1.023477
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069       -1.136594
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-ocSVM_sgdlinear_neg  \
# 0       -1.303784       -1.024339                 0.000024
# 1       -1.466157       -1.028627                 0.000043
# 2       -1.156847       -1.042566                -0.000012
# 3       -1.029984       -1.056383                -0.000066
# 4       -1.149785       -0.986925                -0.000005
#
#    LDA-ocSVM_sgdlinear_neu  ...  LDA-ocSVM_rbf_neu  LDA-ocSVM_rbf_pos  \
# 0                -1.227730  ...        1399.276540        3074.378286
# 1                -1.658688  ...         800.647701        2682.760615
# 2                -1.239510  ...         779.603486        2985.152651
# 3                -0.074041  ...        1866.978207        2937.395574
# 4                -1.293288  ...         821.903183        2987.907751
#
#    LDA-ocSVM_sigmoid_neg  LDA-ocSVM_sigmoid_neu  LDA-ocSVM_sigmoid_pos  \
# 0             466.966951           -2343.215860             355.020465
# 1            1240.242370           -3062.004229             371.990003
# 2           -1630.198504           -1838.923682             647.316050
# 3            -526.845307            -106.282423             452.851925
# 4           -1383.087456           -1998.107976             609.712642
#
#    ocSVM_sgdlinear_neg  ocSVM_sgdlinear_neu  ocSVM_sgdlinear_pos  \
# 0             3.417572             2.436841             3.226402
# 1             3.308467             2.405594             3.073622
# 2             3.644656             2.723918             3.426827
# 3             4.418438             3.100843             4.021740
# 4             3.865552             2.653630             3.644224
#
#    ocSVM_sgdlinear_LDA1  ocSVM_sgdlinear_LDA2
# 0             -1.757707              0.836712
# 1             -1.379038              0.543510
# 2             -1.324523              1.011726
# 3             -1.819398              0.548173
# 4             -2.290966              0.971280
#
# [5 rows x 22 columns]
# time: 530 ms

# %% [markdown]
# # Spherical coordinates

# %%
features_ = [
    ["LDA1", "LDA2"],
    ["ocLDA_neg", "ocLDA_neu", "ocLDA_pos"],
    ["ocSVM_sgdlinear_LDA1", "ocSVM_sgdlinear_LDA2"],
    ["ocSVM_sgdlinear_neg", "ocSVM_sgdlinear_neu", "ocSVM_sgdlinear_pos"],
    ["LDA-LOF_neg_20", "LDA-LOF_neu_20", "LDA-LOF_pos_20"],
]

for descriptor in OC_SVM:
    features_.extend(
        [
            [
                f"LDA-ocSVM_{descriptor}_neg",
                f"LDA-ocSVM_{descriptor}_neu",
                f"LDA-ocSVM_{descriptor}_pos",
            ],
        ]
    )

all_features = []
for feature_set in features_:
    all_features.extend(feature_set)

_ = gc_collect()
# Out:
# time: 180 ms

# %%
sphericals = {}
new_features = []
for features in features_:
    combo = "+".join(features)
    df = data.loc[:, features]
    x, y = df[features[0]], df[features[1]]
    theta, phi = f"theta_{combo}", f"phi_{combo}"
    sphericals[theta] = arctan2(y, x)
    all_features.append(theta)
    # convert to polar
    if len(features) == 3:
        sphericals[phi] = arctan2(sqrt(x ** 2 + y ** 2), df[features[2]])
        all_features.append(phi)
        plot2d(
            df := pd.DataFrame({theta: sphericals[theta], phi: sphericals[phi]}),
            labels,
            theta,
            phi,
        )
        assert not df.isnull().values.any()
        new_features.append([theta, phi])
    else:
        plot1d(df := pd.DataFrame({theta: sphericals[theta]}), labels, theta)
        assert not df.isnull().values.any()
        new_features.append([theta])
    del df
    del x
    del y
    del combo
    _ = gc_collect()
features_.extend(new_features)

sphericals = pd.DataFrame(sphericals)
sphericals.head()
sphericals.info()
# Out:
#    theta_LDA1+LDA2  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0         2.693229                            -1.283814
# 1         2.835179                            -1.175759
# 2         2.279749                            -1.806892
# 3         1.675996                            -3.077901
# 4         2.346148                            -1.692780
#
#    phi_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0                           0.859377
# 1                           0.971149
# 2                           0.573046
# 3                           0.628227
# 4                           0.610215
#
#    theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2  \
# 0                                         2.697309
# 1                                         2.766163
# 2                                         2.489292
# 3                                         2.848950
# 4                                         2.740602
#
#    theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                           0.619419
# 1                                           0.628685
# 2                                           0.641818
# 3                                           0.611930
# 4                                           0.601595
#
#    phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                           0.915453
# 1                                           0.926406
# 2                                           0.925292
# 3                                           0.930471
# 4                                           0.910095
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          -2.228667
# 1                                          -2.184538
# 2                                          -2.295430
# 3                                          -2.353026
# 4                                          -2.350425
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          2.127015
# 1                                          2.091534
# 2                                          2.164393
# 3                                          2.199758
# 4                                          2.118858
#
#    theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                          -1.570777
# 1                                          -1.570770
# 2                                          -1.570806
# 3                                          -1.571681
# 4                                          -1.570800
#
#    phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                           1.359783
# 1                                           1.390989
# 2                                           1.227865
# 3                                           0.212554
# 4                                           1.256069
#
#    theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                           0.249481
# 1                                           0.169691
# 2                                           0.240725
# 3                                           0.534888
# 4                                           0.229105
#
#    phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                           1.073752
# 1                                           1.055853
# 2                                           0.830913
# 3                                           0.894835
# 4                                           0.880633
#
#    theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos  \
# 0                                          -1.374089
# 1                                          -1.185950
# 2                                          -2.296100
# 3                                          -2.942531
# 4                                          -2.176267
#
#    phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos
# 0                                           1.423287
# 1                                           1.458669
# 2                                           1.313240
# 3                                           0.870626
# 4                                           1.324970
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 14 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   theta_LDA1+LDA2                                                                1957 non-null   float64
#  1   theta_ocLDA_neg+ocLDA_neu+ocLDA_pos                                            1957 non-null   float64
#  2   phi_ocLDA_neg+ocLDA_neu+ocLDA_pos                                              1957 non-null   float64
#  3   theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2                                1957 non-null   float64
#  4   theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos              1957 non-null   float64
#  5   phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos                1957 non-null   float64
#  6   theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                             1957 non-null   float64
#  7   phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                               1957 non-null   float64
#  8   theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  9   phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos    1957 non-null   float64
#  10  theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                    1957 non-null   float64
#  11  phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                      1957 non-null   float64
#  12  theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos        1957 non-null   float64
#  13  phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos          1957 non-null   float64
# dtypes: float64(14)
# memory usage: 214.2 KB
# time: 3.83 s

# %%
assert all(sphericals.index == labels.index)
assert all(sphericals.index == data.index)
spot_check(data, labels)
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LDA-LOF_neg_20           1957 non-null   float64
#  6   LDA-LOF_neu_20           1957 non-null   float64
#  7   LDA-LOF_pos_20           1957 non-null   float64
#  8   LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  9   LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  10  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  11  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  12  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  13  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  14  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  15  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  16  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  17  ocSVM_sgdlinear_neg      1957 non-null   float64
#  18  ocSVM_sgdlinear_neu      1957 non-null   float64
#  19  ocSVM_sgdlinear_pos      1957 non-null   float64
#  20  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  21  ocSVM_sgdlinear_LDA2     1957 non-null   float64
# dtypes: float64(22)
# memory usage: 336.5 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LDA-LOF_neg_20  \
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790       -1.007432
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870       -1.032912
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155       -1.024155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857       -1.023477
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069       -1.136594
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-ocSVM_sgdlinear_neg  \
# 0       -1.303784       -1.024339                 0.000024
# 1       -1.466157       -1.028627                 0.000043
# 2       -1.156847       -1.042566                -0.000012
# 3       -1.029984       -1.056383                -0.000066
# 4       -1.149785       -0.986925                -0.000005
#
#    LDA-ocSVM_sgdlinear_neu  ...  LDA-ocSVM_rbf_neu  LDA-ocSVM_rbf_pos  \
# 0                -1.227730  ...        1399.276540        3074.378286
# 1                -1.658688  ...         800.647701        2682.760615
# 2                -1.239510  ...         779.603486        2985.152651
# 3                -0.074041  ...        1866.978207        2937.395574
# 4                -1.293288  ...         821.903183        2987.907751
#
#    LDA-ocSVM_sigmoid_neg  LDA-ocSVM_sigmoid_neu  LDA-ocSVM_sigmoid_pos  \
# 0             466.966951           -2343.215860             355.020465
# 1            1240.242370           -3062.004229             371.990003
# 2           -1630.198504           -1838.923682             647.316050
# 3            -526.845307            -106.282423             452.851925
# 4           -1383.087456           -1998.107976             609.712642
#
#    ocSVM_sgdlinear_neg  ocSVM_sgdlinear_neu  ocSVM_sgdlinear_pos  \
# 0             3.417572             2.436841             3.226402
# 1             3.308467             2.405594             3.073622
# 2             3.644656             2.723918             3.426827
# 3             4.418438             3.100843             4.021740
# 4             3.865552             2.653630             3.644224
#
#    ocSVM_sgdlinear_LDA1  ocSVM_sgdlinear_LDA2
# 0             -1.757707              0.836712
# 1             -1.379038              0.543510
# 2             -1.324523              1.011726
# 3             -1.819398              0.548173
# 4             -2.290966              0.971280
#
# [5 rows x 22 columns]
# time: 141 ms

# %%
sphericals.columns = sphericals.columns.astype(str)
spot_check(sphericals, labels)
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 14 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   theta_LDA1+LDA2                                                                1957 non-null   float64
#  1   theta_ocLDA_neg+ocLDA_neu+ocLDA_pos                                            1957 non-null   float64
#  2   phi_ocLDA_neg+ocLDA_neu+ocLDA_pos                                              1957 non-null   float64
#  3   theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2                                1957 non-null   float64
#  4   theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos              1957 non-null   float64
#  5   phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos                1957 non-null   float64
#  6   theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                             1957 non-null   float64
#  7   phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                               1957 non-null   float64
#  8   theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  9   phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos    1957 non-null   float64
#  10  theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                    1957 non-null   float64
#  11  phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                      1957 non-null   float64
#  12  theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos        1957 non-null   float64
#  13  phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos          1957 non-null   float64
# dtypes: float64(14)
# memory usage: 214.2 KB
# None
#    theta_LDA1+LDA2  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0         2.693229                            -1.283814
# 1         2.835179                            -1.175759
# 2         2.279749                            -1.806892
# 3         1.675996                            -3.077901
# 4         2.346148                            -1.692780
#
#    phi_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0                           0.859377
# 1                           0.971149
# 2                           0.573046
# 3                           0.628227
# 4                           0.610215
#
#    theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2  \
# 0                                         2.697309
# 1                                         2.766163
# 2                                         2.489292
# 3                                         2.848950
# 4                                         2.740602
#
#    theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                           0.619419
# 1                                           0.628685
# 2                                           0.641818
# 3                                           0.611930
# 4                                           0.601595
#
#    phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                           0.915453
# 1                                           0.926406
# 2                                           0.925292
# 3                                           0.930471
# 4                                           0.910095
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          -2.228667
# 1                                          -2.184538
# 2                                          -2.295430
# 3                                          -2.353026
# 4                                          -2.350425
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          2.127015
# 1                                          2.091534
# 2                                          2.164393
# 3                                          2.199758
# 4                                          2.118858
#
#    theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                          -1.570777
# 1                                          -1.570770
# 2                                          -1.570806
# 3                                          -1.571681
# 4                                          -1.570800
#
#    phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                           1.359783
# 1                                           1.390989
# 2                                           1.227865
# 3                                           0.212554
# 4                                           1.256069
#
#    theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                           0.249481
# 1                                           0.169691
# 2                                           0.240725
# 3                                           0.534888
# 4                                           0.229105
#
#    phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                           1.073752
# 1                                           1.055853
# 2                                           0.830913
# 3                                           0.894835
# 4                                           0.880633
#
#    theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos  \
# 0                                          -1.374089
# 1                                          -1.185950
# 2                                          -2.296100
# 3                                          -2.942531
# 4                                          -2.176267
#
#    phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos
# 0                                           1.423287
# 1                                           1.458669
# 2                                           1.313240
# 3                                           0.870626
# 4                                           1.324970
# time: 132 ms

# %%
for oc_svm in tqdm(OC_SVM):
    data = extract_ocsvm_features(data, labels, oc_svm)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# extracting one-class scores of LDA components of FRILL embeddings...
# extracting one-class scores of LDA components of FRILL embeddings...
# extracting one-class scores of LDA components of FRILL embeddings...
# time: 15.8 s

# %% [markdown]
# # LDA components of spherical FRILL-based features

# %%
features = ["spherical-LDA1", "spherical-LDA2"]
df = pd.DataFrame(
    load_extractor("_-_".join(features)).transform(sphericals), columns=features
)
all_features.extend(features)
assert all(df.index == labels.index)
assert all(df.index == data.index)
_ = gc_collect()
# Out:
# time: 144 ms

# %%
df_ = pd.concat(
    [
        data,
        df,
    ],
    axis="columns",
)
spot_check(df_, labels)
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LDA-LOF_neg_20           1957 non-null   float64
#  6   LDA-LOF_neu_20           1957 non-null   float64
#  7   LDA-LOF_pos_20           1957 non-null   float64
#  8   LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  9   LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  10  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  11  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  12  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  13  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  14  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  15  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  16  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  17  ocSVM_sgdlinear_neg      1957 non-null   float64
#  18  ocSVM_sgdlinear_neu      1957 non-null   float64
#  19  ocSVM_sgdlinear_pos      1957 non-null   float64
#  20  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  21  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  22  spherical-LDA1           1957 non-null   float64
#  23  spherical-LDA2           1957 non-null   float64
# dtypes: float64(24)
# memory usage: 367.1 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LDA-LOF_neg_20  \
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790       -1.007432
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870       -1.032912
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155       -1.024155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857       -1.023477
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069       -1.136594
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-ocSVM_sgdlinear_neg  \
# 0       -1.303784       -1.024339                 0.000024
# 1       -1.466157       -1.028627                 0.000043
# 2       -1.156847       -1.042566                -0.000012
# 3       -1.029984       -1.056383                -0.000066
# 4       -1.149785       -0.986925                -0.000005
#
#    LDA-ocSVM_sgdlinear_neu  ...  LDA-ocSVM_sigmoid_neg  LDA-ocSVM_sigmoid_neu  \
# 0                -1.227730  ...             466.966951           -2343.215860
# 1                -1.658688  ...            1240.242370           -3062.004229
# 2                -1.239510  ...           -1630.198504           -1838.923682
# 3                -0.074041  ...            -526.845307            -106.282423
# 4                -1.293288  ...           -1383.087456           -1998.107976
#
#    LDA-ocSVM_sigmoid_pos  ocSVM_sgdlinear_neg  ocSVM_sgdlinear_neu  \
# 0             355.020465             3.417572             2.436841
# 1             371.990003             3.308467             2.405594
# 2             647.316050             3.644656             2.723918
# 3             452.851925             4.418438             3.100843
# 4             609.712642             3.865552             2.653630
#
#    ocSVM_sgdlinear_pos  ocSVM_sgdlinear_LDA1  ocSVM_sgdlinear_LDA2  \
# 0             3.226402             -1.757707              0.836712
# 1             3.073622             -1.379038              0.543510
# 2             3.426827             -1.324523              1.011726
# 3             4.021740             -1.819398              0.548173
# 4             3.644224             -2.290966              0.971280
#
#    spherical-LDA1  spherical-LDA2
# 0       -1.309162        0.426750
# 1       -1.456495        0.317191
# 2       -2.103103        1.831085
# 3       -1.124492        2.317019
# 4       -2.077637        1.481306
#
# [5 rows x 24 columns]
# time: 143 ms

# %%
data = deepcopy(df_)
spot_check(data, labels)
del df
del df_
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LDA-LOF_neg_20           1957 non-null   float64
#  6   LDA-LOF_neu_20           1957 non-null   float64
#  7   LDA-LOF_pos_20           1957 non-null   float64
#  8   LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  9   LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  10  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  11  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  12  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  13  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  14  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  15  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  16  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  17  ocSVM_sgdlinear_neg      1957 non-null   float64
#  18  ocSVM_sgdlinear_neu      1957 non-null   float64
#  19  ocSVM_sgdlinear_pos      1957 non-null   float64
#  20  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  21  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  22  spherical-LDA1           1957 non-null   float64
#  23  spherical-LDA2           1957 non-null   float64
# dtypes: float64(24)
# memory usage: 367.1 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LDA-LOF_neg_20  \
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790       -1.007432
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870       -1.032912
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155       -1.024155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857       -1.023477
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069       -1.136594
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-ocSVM_sgdlinear_neg  \
# 0       -1.303784       -1.024339                 0.000024
# 1       -1.466157       -1.028627                 0.000043
# 2       -1.156847       -1.042566                -0.000012
# 3       -1.029984       -1.056383                -0.000066
# 4       -1.149785       -0.986925                -0.000005
#
#    LDA-ocSVM_sgdlinear_neu  ...  LDA-ocSVM_sigmoid_neg  LDA-ocSVM_sigmoid_neu  \
# 0                -1.227730  ...             466.966951           -2343.215860
# 1                -1.658688  ...            1240.242370           -3062.004229
# 2                -1.239510  ...           -1630.198504           -1838.923682
# 3                -0.074041  ...            -526.845307            -106.282423
# 4                -1.293288  ...           -1383.087456           -1998.107976
#
#    LDA-ocSVM_sigmoid_pos  ocSVM_sgdlinear_neg  ocSVM_sgdlinear_neu  \
# 0             355.020465             3.417572             2.436841
# 1             371.990003             3.308467             2.405594
# 2             647.316050             3.644656             2.723918
# 3             452.851925             4.418438             3.100843
# 4             609.712642             3.865552             2.653630
#
#    ocSVM_sgdlinear_pos  ocSVM_sgdlinear_LDA1  ocSVM_sgdlinear_LDA2  \
# 0             3.226402             -1.757707              0.836712
# 1             3.073622             -1.379038              0.543510
# 2             3.426827             -1.324523              1.011726
# 3             4.021740             -1.819398              0.548173
# 4             3.644224             -2.290966              0.971280
#
#    spherical-LDA1  spherical-LDA2
# 0       -1.309162        0.426750
# 1       -1.456495        0.317191
# 2       -2.103103        1.831085
# 3       -1.124492        2.317019
# 4       -2.077637        1.481306
#
# [5 rows x 24 columns]
# time: 144 ms

# %%
plot2d(data, labels, *features)
checkpoint_features(data, features)
# Out:
# time: 179 ms

# %% [markdown]
# # One-class LDA components of spherical FRILL-based features

# %%
df = pd.concat(
    [
        data,
        pd.DataFrame(
            {
                feature: np.squeeze(load_extractor(feature).transform(sphericals))
                for feature in feature_trio("spherical-ocLDA", "")
            }
        ),
    ],
    axis="columns",
)
spot_check(df, labels)
all_features.extend(feature_trio("spherical-ocLDA", ""))
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LDA-LOF_neg_20           1957 non-null   float64
#  6   LDA-LOF_neu_20           1957 non-null   float64
#  7   LDA-LOF_pos_20           1957 non-null   float64
#  8   LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  9   LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  10  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  11  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  12  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  13  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  14  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  15  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  16  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  17  ocSVM_sgdlinear_neg      1957 non-null   float64
#  18  ocSVM_sgdlinear_neu      1957 non-null   float64
#  19  ocSVM_sgdlinear_pos      1957 non-null   float64
#  20  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  21  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  22  spherical-LDA1           1957 non-null   float64
#  23  spherical-LDA2           1957 non-null   float64
#  24  spherical-ocLDA_neg      1957 non-null   float64
#  25  spherical-ocLDA_neu      1957 non-null   float64
#  26  spherical-ocLDA_pos      1957 non-null   float64
# dtypes: float64(27)
# memory usage: 412.9 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LDA-LOF_neg_20  \
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790       -1.007432
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870       -1.032912
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155       -1.024155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857       -1.023477
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069       -1.136594
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-ocSVM_sgdlinear_neg  \
# 0       -1.303784       -1.024339                 0.000024
# 1       -1.466157       -1.028627                 0.000043
# 2       -1.156847       -1.042566                -0.000012
# 3       -1.029984       -1.056383                -0.000066
# 4       -1.149785       -0.986925                -0.000005
#
#    LDA-ocSVM_sgdlinear_neu  ...  ocSVM_sgdlinear_neg  ocSVM_sgdlinear_neu  \
# 0                -1.227730  ...             3.417572             2.436841
# 1                -1.658688  ...             3.308467             2.405594
# 2                -1.239510  ...             3.644656             2.723918
# 3                -0.074041  ...             4.418438             3.100843
# 4                -1.293288  ...             3.865552             2.653630
#
#    ocSVM_sgdlinear_pos  ocSVM_sgdlinear_LDA1  ocSVM_sgdlinear_LDA2  \
# 0             3.226402             -1.757707              0.836712
# 1             3.073622             -1.379038              0.543510
# 2             3.426827             -1.324523              1.011726
# 3             4.021740             -1.819398              0.548173
# 4             3.644224             -2.290966              0.971280
#
#    spherical-LDA1  spherical-LDA2  spherical-ocLDA_neg  spherical-ocLDA_neu  \
# 0       -1.309162        0.426750            -0.414390            -1.244975
# 1       -1.456495        0.317191            -0.586872            -1.404476
# 2       -2.103103        1.831085             0.249117            -1.859022
# 3       -1.124492        2.317019             1.201692            -0.829339
# 4       -2.077637        1.481306            -0.015523            -1.876827
#
#    spherical-ocLDA_pos
# 0            -1.025249
# 1            -1.007076
# 2            -2.617862
# 3            -2.533668
# 4            -2.308513
#
# [5 rows x 27 columns]
# time: 171 ms

# %%
data = pd.concat([df, sphericals], axis="columns")
spot_check(data, labels)
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 41 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   LDA1                                                                           1957 non-null   float64
#  1   LDA2                                                                           1957 non-null   float64
#  2   ocLDA_neg                                                                      1957 non-null   float64
#  3   ocLDA_neu                                                                      1957 non-null   float64
#  4   ocLDA_pos                                                                      1957 non-null   float64
#  5   LDA-LOF_neg_20                                                                 1957 non-null   float64
#  6   LDA-LOF_neu_20                                                                 1957 non-null   float64
#  7   LDA-LOF_pos_20                                                                 1957 non-null   float64
#  8   LDA-ocSVM_sgdlinear_neg                                                        1957 non-null   float64
#  9   LDA-ocSVM_sgdlinear_neu                                                        1957 non-null   float64
#  10  LDA-ocSVM_sgdlinear_pos                                                        1957 non-null   float64
#  11  LDA-ocSVM_rbf_neg                                                              1957 non-null   float64
#  12  LDA-ocSVM_rbf_neu                                                              1957 non-null   float64
#  13  LDA-ocSVM_rbf_pos                                                              1957 non-null   float64
#  14  LDA-ocSVM_sigmoid_neg                                                          1957 non-null   float64
#  15  LDA-ocSVM_sigmoid_neu                                                          1957 non-null   float64
#  16  LDA-ocSVM_sigmoid_pos                                                          1957 non-null   float64
#  17  ocSVM_sgdlinear_neg                                                            1957 non-null   float64
#  18  ocSVM_sgdlinear_neu                                                            1957 non-null   float64
#  19  ocSVM_sgdlinear_pos                                                            1957 non-null   float64
#  20  ocSVM_sgdlinear_LDA1                                                           1957 non-null   float64
#  21  ocSVM_sgdlinear_LDA2                                                           1957 non-null   float64
#  22  spherical-LDA1                                                                 1957 non-null   float64
#  23  spherical-LDA2                                                                 1957 non-null   float64
#  24  spherical-ocLDA_neg                                                            1957 non-null   float64
#  25  spherical-ocLDA_neu                                                            1957 non-null   float64
#  26  spherical-ocLDA_pos                                                            1957 non-null   float64
#  27  theta_LDA1+LDA2                                                                1957 non-null   float64
#  28  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos                                            1957 non-null   float64
#  29  phi_ocLDA_neg+ocLDA_neu+ocLDA_pos                                              1957 non-null   float64
#  30  theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2                                1957 non-null   float64
#  31  theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos              1957 non-null   float64
#  32  phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos                1957 non-null   float64
#  33  theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                             1957 non-null   float64
#  34  phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                               1957 non-null   float64
#  35  theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  36  phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos    1957 non-null   float64
#  37  theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                    1957 non-null   float64
#  38  phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                      1957 non-null   float64
#  39  theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos        1957 non-null   float64
#  40  phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos          1957 non-null   float64
# dtypes: float64(41)
# memory usage: 627.0 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LDA-LOF_neg_20  \
# 0 -1.506022  0.724455   0.430103  -1.457336   1.309790       -1.007432
# 1 -2.012732  0.636784   0.820705  -1.968329   1.457870       -1.032912
# 2 -1.592665  1.856882  -0.354419  -1.473169   2.348155       -1.024155
# 3 -0.224248  2.123781  -1.431634  -0.091306   1.974857       -1.023477
# 4 -1.645159  1.678552  -0.188382  -1.536660   2.214069       -1.136594
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-ocSVM_sgdlinear_neg  \
# 0       -1.303784       -1.024339                 0.000024
# 1       -1.466157       -1.028627                 0.000043
# 2       -1.156847       -1.042566                -0.000012
# 3       -1.029984       -1.056383                -0.000066
# 4       -1.149785       -0.986925                -0.000005
#
#    LDA-ocSVM_sgdlinear_neu  ...  \
# 0                -1.227730  ...
# 1                -1.658688  ...
# 2                -1.239510  ...
# 3                -0.074041  ...
# 4                -1.293288  ...
#
#    theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                           0.619419
# 1                                           0.628685
# 2                                           0.641818
# 3                                           0.611930
# 4                                           0.601595
#
#    phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                           0.915453
# 1                                           0.926406
# 2                                           0.925292
# 3                                           0.930471
# 4                                           0.910095
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          -2.228667
# 1                                          -2.184538
# 2                                          -2.295430
# 3                                          -2.353026
# 4                                          -2.350425
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          2.127015
# 1                                          2.091534
# 2                                          2.164393
# 3                                          2.199758
# 4                                          2.118858
#
#    theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                          -1.570777
# 1                                          -1.570770
# 2                                          -1.570806
# 3                                          -1.571681
# 4                                          -1.570800
#
#    phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                           1.359783
# 1                                           1.390989
# 2                                           1.227865
# 3                                           0.212554
# 4                                           1.256069
#
#    theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                           0.249481
# 1                                           0.169691
# 2                                           0.240725
# 3                                           0.534888
# 4                                           0.229105
#
#    phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                           1.073752
# 1                                           1.055853
# 2                                           0.830913
# 3                                           0.894835
# 4                                           0.880633
#
#    theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos  \
# 0                                          -1.374089
# 1                                          -1.185950
# 2                                          -2.296100
# 3                                          -2.942531
# 4                                          -2.176267
#
#    phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos
# 0                                           1.423287
# 1                                           1.458669
# 2                                           1.313240
# 3                                           0.870626
# 4                                           1.324970
#
# [5 rows x 41 columns]
# time: 145 ms

# %%
training_data = (
    pd.read_feather(f"./scaled_features_ready_for_selection.feather")
    .set_index("id")
    .head(1)
)
assert sorted(all_features) == sorted(list(data.columns))
assert set(training_data.columns) - set(all_features) == set()
assert set(training_data.columns) - set(data.columns) == set()
assert len(data.columns) == len(training_data.columns)
assert set(data.columns) == set(training_data.columns)
data = data.loc[
    :, training_data.columns
]  # with the guarantee of the preceding assertion, ensure congruent column order
assert all(data.columns == training_data.columns)
del sphericals
del training_data
_ = gc_collect()
# Out:
# time: 272 ms

# %% [markdown]
# # Robust scaling

# %%
scaler = load_extractor("robust_scaler")
data = pd.DataFrame(scaler.transform(data), columns=scaler.feature_names_in_)
del scaler
_ = gc_collect()
spot_check(data, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 41 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   LDA1                                                                           1957 non-null   float64
#  1   LDA2                                                                           1957 non-null   float64
#  2   ocLDA_neg                                                                      1957 non-null   float64
#  3   ocLDA_neu                                                                      1957 non-null   float64
#  4   ocLDA_pos                                                                      1957 non-null   float64
#  5   ocSVM_sgdlinear_LDA1                                                           1957 non-null   float64
#  6   ocSVM_sgdlinear_LDA2                                                           1957 non-null   float64
#  7   ocSVM_sgdlinear_neg                                                            1957 non-null   float64
#  8   ocSVM_sgdlinear_neu                                                            1957 non-null   float64
#  9   ocSVM_sgdlinear_pos                                                            1957 non-null   float64
#  10  LDA-LOF_neg_20                                                                 1957 non-null   float64
#  11  LDA-LOF_neu_20                                                                 1957 non-null   float64
#  12  LDA-LOF_pos_20                                                                 1957 non-null   float64
#  13  LDA-ocSVM_sgdlinear_neg                                                        1957 non-null   float64
#  14  LDA-ocSVM_sgdlinear_neu                                                        1957 non-null   float64
#  15  LDA-ocSVM_sgdlinear_pos                                                        1957 non-null   float64
#  16  LDA-ocSVM_rbf_neg                                                              1957 non-null   float64
#  17  LDA-ocSVM_rbf_neu                                                              1957 non-null   float64
#  18  LDA-ocSVM_rbf_pos                                                              1957 non-null   float64
#  19  LDA-ocSVM_sigmoid_neg                                                          1957 non-null   float64
#  20  LDA-ocSVM_sigmoid_neu                                                          1957 non-null   float64
#  21  LDA-ocSVM_sigmoid_pos                                                          1957 non-null   float64
#  22  spherical-LDA1                                                                 1957 non-null   float64
#  23  spherical-LDA2                                                                 1957 non-null   float64
#  24  spherical-ocLDA_neg                                                            1957 non-null   float64
#  25  spherical-ocLDA_neu                                                            1957 non-null   float64
#  26  spherical-ocLDA_pos                                                            1957 non-null   float64
#  27  theta_LDA1+LDA2                                                                1957 non-null   float64
#  28  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos                                            1957 non-null   float64
#  29  phi_ocLDA_neg+ocLDA_neu+ocLDA_pos                                              1957 non-null   float64
#  30  theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2                                1957 non-null   float64
#  31  theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos              1957 non-null   float64
#  32  phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos                1957 non-null   float64
#  33  theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                             1957 non-null   float64
#  34  phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                               1957 non-null   float64
#  35  theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  36  phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos    1957 non-null   float64
#  37  theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                    1957 non-null   float64
#  38  phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                      1957 non-null   float64
#  39  theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos        1957 non-null   float64
#  40  phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos          1957 non-null   float64
# dtypes: float64(41)
# memory usage: 627.0 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  ocSVM_sgdlinear_LDA1  \
# 0 -1.093794  0.716794   0.359546  -1.050666   1.313265             -1.713079
# 1 -1.495297  0.634760   0.689889  -1.455015   1.452485             -1.358674
# 2 -1.162448  1.776413  -0.303944  -1.063195   2.289499             -1.307652
# 3 -0.078153  2.026152  -1.214974   0.030274   1.938538             -1.770817
# 4 -1.204043  1.609548  -0.163523  -1.113435   2.163436             -2.212166
#
#    ocSVM_sgdlinear_LDA2  ocSVM_sgdlinear_neg  ocSVM_sgdlinear_neu  \
# 0              1.043159            -0.066793            -0.371055
# 1              0.725619            -0.156481            -0.411990
# 2              1.232700             0.119876             0.005031
# 3              0.730669             0.755949             0.498820
# 4              1.188897             0.301460            -0.087051
#
#    ocSVM_sgdlinear_pos  ...  \
# 0             0.161404  ...
# 1             0.011212  ...
# 2             0.358435  ...
# 3             0.943271  ...
# 4             0.572149  ...
#
#    theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                          -0.838690
# 1                                          -0.681846
# 2                                          -0.459528
# 3                                          -0.965463
# 4                                          -1.140414
#
#    phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                          -1.684763
# 1                                          -1.326493
# 2                                          -1.362937
# 3                                          -1.193533
# 4                                          -1.860018
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                           3.922299
# 1                                           5.372276
# 2                                           1.728630
# 3                                          -0.163847
# 4                                          -0.078408
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                         -2.359325
# 1                                         -3.833649
# 2                                         -0.806233
# 3                                          0.663235
# 4                                         -2.698287
#
#    theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                          -0.000069
# 1                                          -0.000066
# 2                                          -0.000082
# 3                                          -0.000458
# 4                                          -0.000079
#
#    phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                          -0.843274
# 1                                          -0.729811
# 2                                          -1.322914
# 3                                          -5.014475
# 4                                          -1.220368
#
#    theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                          -1.363317
# 1                                          -1.790280
# 2                                          -1.410170
# 3                                           0.163934
# 4                                          -1.472351
#
#    phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                          -1.073870
# 1                                          -1.290961
# 2                                          -4.019192
# 3                                          -3.243898
# 4                                          -3.416148
#
#    theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos  \
# 0                                          -0.328495
# 1                                          -0.251212
# 2                                          -0.707235
# 3                                          -0.972772
# 4                                          -0.658010
#
#    phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos
# 0                                          -1.005927
# 1                                          -0.780120
# 2                                          -1.708261
# 3                                          -4.533063
# 4                                          -1.633397
#
# [5 rows x 41 columns]
# time: 173 ms

# %%
data.columns = data.columns.astype(str)
data.to_feather(f"{OUT_FOLDER}/holdout_featurized.feather")
data = pd.read_feather(f"{OUT_FOLDER}/holdout_featurized.feather")
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 41 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   LDA1                                                                           1957 non-null   float64
#  1   LDA2                                                                           1957 non-null   float64
#  2   ocLDA_neg                                                                      1957 non-null   float64
#  3   ocLDA_neu                                                                      1957 non-null   float64
#  4   ocLDA_pos                                                                      1957 non-null   float64
#  5   ocSVM_sgdlinear_LDA1                                                           1957 non-null   float64
#  6   ocSVM_sgdlinear_LDA2                                                           1957 non-null   float64
#  7   ocSVM_sgdlinear_neg                                                            1957 non-null   float64
#  8   ocSVM_sgdlinear_neu                                                            1957 non-null   float64
#  9   ocSVM_sgdlinear_pos                                                            1957 non-null   float64
#  10  LDA-LOF_neg_20                                                                 1957 non-null   float64
#  11  LDA-LOF_neu_20                                                                 1957 non-null   float64
#  12  LDA-LOF_pos_20                                                                 1957 non-null   float64
#  13  LDA-ocSVM_sgdlinear_neg                                                        1957 non-null   float64
#  14  LDA-ocSVM_sgdlinear_neu                                                        1957 non-null   float64
#  15  LDA-ocSVM_sgdlinear_pos                                                        1957 non-null   float64
#  16  LDA-ocSVM_rbf_neg                                                              1957 non-null   float64
#  17  LDA-ocSVM_rbf_neu                                                              1957 non-null   float64
#  18  LDA-ocSVM_rbf_pos                                                              1957 non-null   float64
#  19  LDA-ocSVM_sigmoid_neg                                                          1957 non-null   float64
#  20  LDA-ocSVM_sigmoid_neu                                                          1957 non-null   float64
#  21  LDA-ocSVM_sigmoid_pos                                                          1957 non-null   float64
#  22  spherical-LDA1                                                                 1957 non-null   float64
#  23  spherical-LDA2                                                                 1957 non-null   float64
#  24  spherical-ocLDA_neg                                                            1957 non-null   float64
#  25  spherical-ocLDA_neu                                                            1957 non-null   float64
#  26  spherical-ocLDA_pos                                                            1957 non-null   float64
#  27  theta_LDA1+LDA2                                                                1957 non-null   float64
#  28  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos                                            1957 non-null   float64
#  29  phi_ocLDA_neg+ocLDA_neu+ocLDA_pos                                              1957 non-null   float64
#  30  theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2                                1957 non-null   float64
#  31  theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos              1957 non-null   float64
#  32  phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos                1957 non-null   float64
#  33  theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                             1957 non-null   float64
#  34  phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                               1957 non-null   float64
#  35  theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  36  phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos    1957 non-null   float64
#  37  theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                    1957 non-null   float64
#  38  phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                      1957 non-null   float64
#  39  theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos        1957 non-null   float64
#  40  phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos          1957 non-null   float64
# dtypes: float64(41)
# memory usage: 627.0 KB
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  ocSVM_sgdlinear_LDA1  \
# 0 -1.093794  0.716794   0.359546  -1.050666   1.313265             -1.713079
# 1 -1.495297  0.634760   0.689889  -1.455015   1.452485             -1.358674
# 2 -1.162448  1.776413  -0.303944  -1.063195   2.289499             -1.307652
# 3 -0.078153  2.026152  -1.214974   0.030274   1.938538             -1.770817
# 4 -1.204043  1.609548  -0.163523  -1.113435   2.163436             -2.212166
#
#    ocSVM_sgdlinear_LDA2  ocSVM_sgdlinear_neg  ocSVM_sgdlinear_neu  \
# 0              1.043159            -0.066793            -0.371055
# 1              0.725619            -0.156481            -0.411990
# 2              1.232700             0.119876             0.005031
# 3              0.730669             0.755949             0.498820
# 4              1.188897             0.301460            -0.087051
#
#    ocSVM_sgdlinear_pos  ...  \
# 0             0.161404  ...
# 1             0.011212  ...
# 2             0.358435  ...
# 3             0.943271  ...
# 4             0.572149  ...
#
#    theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                          -0.838690
# 1                                          -0.681846
# 2                                          -0.459528
# 3                                          -0.965463
# 4                                          -1.140414
#
#    phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos  \
# 0                                          -1.684763
# 1                                          -1.326493
# 2                                          -1.362937
# 3                                          -1.193533
# 4                                          -1.860018
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                           3.922299
# 1                                           5.372276
# 2                                           1.728630
# 3                                          -0.163847
# 4                                          -0.078408
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                         -2.359325
# 1                                         -3.833649
# 2                                         -0.806233
# 3                                          0.663235
# 4                                         -2.698287
#
#    theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                          -0.000069
# 1                                          -0.000066
# 2                                          -0.000082
# 3                                          -0.000458
# 4                                          -0.000079
#
#    phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  \
# 0                                          -0.843274
# 1                                          -0.729811
# 2                                          -1.322914
# 3                                          -5.014475
# 4                                          -1.220368
#
#    theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                          -1.363317
# 1                                          -1.790280
# 2                                          -1.410170
# 3                                           0.163934
# 4                                          -1.472351
#
#    phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos  \
# 0                                          -1.073870
# 1                                          -1.290961
# 2                                          -4.019192
# 3                                          -3.243898
# 4                                          -3.416148
#
#    theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos  \
# 0                                          -0.328495
# 1                                          -0.251212
# 2                                          -0.707235
# 3                                          -0.972772
# 4                                          -0.658010
#
#    phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos
# 0                                          -1.005927
# 1                                          -0.780120
# 2                                          -1.708261
# 3                                          -4.533063
# 4                                          -1.633397
#
# [5 rows x 41 columns]
# time: 120 ms

# %%
training_data = (
    pd.read_feather(f"./scaled_features_ready_for_selection.feather")
    .set_index("id")
    .head(1)
)
assert sorted(all_features) == sorted(list(data.columns))
assert set(training_data.columns) - set(all_features) == set()
assert set(all_features) - set(training_data.columns) == set()
assert set(data.columns) - set(training_data.columns) == set()
assert len(data.columns) == len(training_data.columns)
assert set(data.columns) == set(training_data.columns)
_ = gc_collect()
# Out:
# time: 184 ms

# %% [markdown]
# # Final visualization

# %%
for features in features_:
    if len(features) == 3:
        plot3d(data, labels, *features)
    elif len(features) == 2:
        plot2d(data, labels, *features)
    else:
        plot1d(data, labels, *features)
# Out:
# time: 4.12 s

# %% [markdown]
# # Discussion

# %% [markdown]
# Now that we have the features, let's evaluate them in the next notebook. The visualizations don't look so clean, so let's hope for the best.|

# %%
print(f"Time elapsed since notebook_begin_time: {time() - notebook_begin_time} s")
_ = gc_collect()
# Out:
# Time elapsed since notebook_begin_time: 62.99597120285034 s
# time: 178 ms

# %% [markdown]
# [^top](#Contents)
