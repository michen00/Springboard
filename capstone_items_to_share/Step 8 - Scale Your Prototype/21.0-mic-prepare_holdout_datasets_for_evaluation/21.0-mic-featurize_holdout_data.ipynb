# %% [markdown]
# # Contents
# * [Introduction](#Introduction)
# * [Imports and configuration](#Imports-and-configuration)
# * [Load data](#Load-data)
# * [Linear discriminant analysis of FRILL embeddings](#Linear-discriminant-analysis-of-FRILL-embeddings)
# * [One-class linear discriminant analysis of FRILL embeddings](#One-class-linear-discriminant-analysis-of-FRILL-embeddings)
# * [Local outlier factor of FRILL embeddings](#Local-outlier-factor-of-FRILL-embeddings)
# * [Local outlier factor of LDA components of FRILL embeddings](#Local-outlier-factor-of-LDA-components-of-FRILL-embeddings)
# * [One-class SVM scores of FRILL embeddings (and their LDA components) and of the LDA components of the FRILL embeddings](#One-class-SVM-scores-of-FRILL-embeddings-(and-their-LDA-components)-and-of-the-LDA-components-of-the-FRILL-embeddings)
# * [Spherical coordinates](#Spherical-coordinates)
# * [LDA components of spherical FRILL-based features](#LDA-components-of-spherical-FRILL-based-features)
# * [One-class LDA components of spherical FRILL-based features](#One-class-LDA-components-of-spherical-FRILL-based-features)
# * [Aggregate and scale](#Aggregate-and-scale)
# * [Discussion](#Discussion)

# %% [markdown]
# # Introduction
#
# Three holdout datasets have been identified. This notebook prepares the labels and metadata for these datasets and then prepares them for extraction of FRILL embeddings.

# %% [markdown]
# # Imports and configuration

# %%
from time import time

notebook_begin_time = time()

# set random seeds

from os import environ
from random import seed as random_seed
from numpy.random import seed as np_seed
from tensorflow.random import set_seed


def reset_seeds(seed: int) -> None:
    """Utility function for resetting random seeds"""
    environ["PYTHONHASHSEED"] = str(seed)
    random_seed(seed)
    np_seed(seed)
    set_seed(seed)


reset_seeds(SEED := 2021)
del environ
del random_seed
del np_seed
del set_seed
del reset_seeds

# %%
# extensions
# %load_ext autotime
# %load_ext lab_black
# %load_ext nb_black

# %%
# core
import numpy as np
import pandas as pd

# utility
from copy import deepcopy
from joblib import load as joblib_load
from pathlib import Path
from gc import collect as gc_collect
from tqdm.notebook import tqdm

# faster
import swifter
from sklearnex import patch_sklearn

patch_sklearn()
del patch_sklearn

# spherical coordinates
from numpy import arctan2, hypot, sqrt

# typing
from typing import List

# display outputs w/o print calls
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
del InteractiveShell
# Out:
# time: 3.62 s
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
# Location of exported feature extractors
FEATURE_EXTRACTORS = "../19.0-mic-extract_FRILL-based_features_from_full_data"

# Location where this notebook will output
OUT_FOLDER = "."

_ = gc_collect()
# Out:
# time: 120 ms

# %% [markdown]
# # Setup

# %%
# valence label codes
VALENCE = {"neg": 0, "neu": 1, "pos": 2}
VALENCES = ("neg", "neu", "pos")
NEIGHBORS = (10, 20, 30)
OC_SVM = ("sgdlinear", "rbf", "sigmoid", "poly5", "poly6")

feature_trio = lambda prefix, suffix: [
    f"{f'{prefix}_' if prefix else ''}{valence}{f'_{suffix}' if suffix else ''}"
    for valence in VALENCES
]

load_extractor = lambda feature_file: joblib_load(
    f"{FEATURE_EXTRACTORS}/{feature_file}.joblib"
)


def spot_check(data: pd.DataFrame, labels: pd.DataFrame) -> None:
    """Spot check feature extraction process"""
    assert all(data.index == labels.index)
    assert not data.isnull().values.any()
    print(data.info())
    print(data.head())


_ = gc_collect()
# Out:
# time: 126 ms

# %% [markdown]
# # Load data

# %%
frill = pd.read_feather("holdout_FRILL.feather")
labels = pd.read_feather("holdout_labels.feather").set_index("id")
spot_check(frill, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Columns: 2048 entries, 0 to 2047
# dtypes: float32(2048)
# memory usage: 15.3 MB
# None
#           0         1         2         3         4         5         6  \
# 0 -0.035624  0.148898 -0.109508 -0.016199 -0.084427 -0.067872  0.174007
# 1 -0.103035  0.082011  0.110948 -0.060209 -0.073397  0.009772 -0.020830
# 2 -0.065101  0.038458 -0.029423  0.005429 -0.023002  0.152135  0.053979
# 3  0.083481  0.138969 -0.030347  0.062699  0.073357 -0.039354 -0.089715
# 4  0.019141  0.170539 -0.056348  0.032532 -0.089482  0.079703  0.037175
#
#           7         8         9  ...      2038      2039      2040      2041  \
# 0 -0.033383 -0.017896 -0.024012  ... -0.153698  0.041551 -0.003445 -0.059062
# 1  0.044276  0.046892 -0.115516  ...  0.065289  0.075569 -0.089013 -0.161597
# 2 -0.039011  0.017791 -0.077413  ... -0.042246 -0.004320 -0.040200 -0.049798
# 3  0.113456  0.039636 -0.041954  ...  0.022920 -0.181787  0.011134 -0.073927
# 4  0.046567 -0.053409 -0.061816  ...  0.078809 -0.044437 -0.086229  0.048539
#
#        2042      2043      2044      2045      2046      2047
# 0 -0.028037 -0.026091  0.101007 -0.078234  0.112814  0.098813
# 1  0.017945  0.073644  0.058319  0.030772  0.066552  0.088602
# 2 -0.081791 -0.091844  0.164188  0.060485 -0.003494  0.048290
# 3 -0.014689  0.049779  0.044533 -0.063511  0.020476 -0.018876
# 4  0.104972 -0.050087  0.052254  0.117372  0.042914  0.049517
#
# [5 rows x 2048 columns]
# time: 263 ms

# %% [markdown]
# # Linear discriminant analysis components of FRILL embeddings

# %%
data = pd.DataFrame(
    load_extractor("LDA1_-_LDA2").transform(frill), columns=["LDA1", "LDA2"]
)
spot_check(data, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LDA1    1957 non-null   float64
#  1   LDA2    1957 non-null   float64
# dtypes: float64(2)
# memory usage: 30.7 KB
# None
#        LDA1      LDA2
# 0 -1.001496  1.190528
# 1 -0.614103  0.555738
# 2 -1.283616  0.439167
# 3 -0.174906  1.891036
# 4 -1.165987  1.732043
# time: 340 ms

# %% [markdown]
# # One-class linear discriminant analysis of FRILL embeddings

# %%
df = deepcopy(frill)
for valence in VALENCES:
    feature = f"ocLDA_{valence}"
    df[feature] = np.squeeze(
        load_extractor(feature).transform(df.loc[:, frill.columns])
    )
    del feature
    _ = gc_collect()
data = pd.concat(
    [data, df.loc[:, feature_trio("ocLDA", "")]],
    axis="columns",
)
spot_check(data, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LDA1       1957 non-null   float64
#  1   LDA2       1957 non-null   float64
#  2   ocLDA_neg  1957 non-null   float64
#  3   ocLDA_neu  1957 non-null   float64
#  4   ocLDA_pos  1957 non-null   float64
# dtypes: float64(5)
# memory usage: 76.6 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688
# time: 778 ms

# %%
del df
_ = gc_collect()
# Out:
# time: 117 ms

# %% [markdown]
# # Local outlier factor of FRILL embeddings

# %%
for n_neighbors in tqdm(NEIGHBORS):
    for valence in tqdm(VALENCES):
        feature = f"LOF_{valence}_{n_neighbors}"
        data[feature] = load_extractor(feature).score_samples(frill)

spot_check(data, labels)

for valence in tqdm(VALENCES):
    feature = f"LOF_{valence}_PCA"
    data[feature] = load_extractor(feature).transform(
        data.loc[:, [f"LOF_{valence}_{k}" for k in NEIGHBORS]]
    )

spot_check(data, labels)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LDA1        1957 non-null   float64
#  1   LDA2        1957 non-null   float64
#  2   ocLDA_neg   1957 non-null   float64
#  3   ocLDA_neu   1957 non-null   float64
#  4   ocLDA_pos   1957 non-null   float64
#  5   LOF_neg_10  1957 non-null   float32
#  6   LOF_neu_10  1957 non-null   float32
#  7   LOF_pos_10  1957 non-null   float32
#  8   LOF_neg_20  1957 non-null   float32
#  9   LOF_neu_20  1957 non-null   float32
#  10  LOF_pos_20  1957 non-null   float32
#  11  LOF_neg_30  1957 non-null   float32
#  12  LOF_neu_30  1957 non-null   float32
#  13  LOF_pos_30  1957 non-null   float32
# dtypes: float32(9), float64(5)
# memory usage: 145.4 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  LOF_pos_20  LOF_neg_30  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991   -1.443974   -1.132774
# 1   -1.296963   -1.413960   -1.240734   -1.276801   -1.260644   -1.196489
# 2   -1.117705   -1.139015   -1.076433   -1.123352   -1.118295   -1.075534
# 3   -1.251665   -1.578528   -1.404248   -1.214691   -1.435516   -1.386666
# 4   -1.270247   -1.323458   -1.170957   -1.143541   -1.251012   -1.155581
#
#    LOF_neu_30  LOF_pos_30
# 0   -1.113829   -1.442318
# 1   -1.234203   -1.200986
# 2   -1.119792   -1.099220
# 3   -1.202199   -1.350497
# 4   -1.144400   -1.214233
#   0%|          | 0/3 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LDA1         1957 non-null   float64
#  1   LDA2         1957 non-null   float64
#  2   ocLDA_neg    1957 non-null   float64
#  3   ocLDA_neu    1957 non-null   float64
#  4   ocLDA_pos    1957 non-null   float64
#  5   LOF_neg_10   1957 non-null   float32
#  6   LOF_neu_10   1957 non-null   float32
#  7   LOF_pos_10   1957 non-null   float32
#  8   LOF_neg_20   1957 non-null   float32
#  9   LOF_neu_20   1957 non-null   float32
#  10  LOF_pos_20   1957 non-null   float32
#  11  LOF_neg_30   1957 non-null   float32
#  12  LOF_neu_30   1957 non-null   float32
#  13  LOF_pos_30   1957 non-null   float32
#  14  LOF_neg_PCA  1957 non-null   float32
#  15  LOF_neu_PCA  1957 non-null   float32
#  16  LOF_pos_PCA  1957 non-null   float32
# dtypes: float32(12), float64(5)
# memory usage: 168.3 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  LOF_pos_20  LOF_neg_30  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991   -1.443974   -1.132774
# 1   -1.296963   -1.413960   -1.240734   -1.276801   -1.260644   -1.196489
# 2   -1.117705   -1.139015   -1.076433   -1.123352   -1.118295   -1.075534
# 3   -1.251665   -1.578528   -1.404248   -1.214691   -1.435516   -1.386666
# 4   -1.270247   -1.323458   -1.170957   -1.143541   -1.251012   -1.155581
#
#    LOF_neu_30  LOF_pos_30  LOF_neg_PCA  LOF_neu_PCA  LOF_pos_PCA
# 0   -1.113829   -1.442318    -0.050180     0.079285    -0.581153
# 1   -1.234203   -1.200986    -0.251847    -0.153213    -0.259397
# 2   -1.119792   -1.099220     0.057059     0.105166     0.041439
# 3   -1.202199   -1.350497    -0.554875    -0.072543    -0.541881
# 4   -1.144400   -1.214233    -0.106864    -0.008758    -0.208536
# time: 45.6 s

# %% [markdown]
# # Local outlier factor of LDA components of FRILL embeddings

# %%
for n_neighbors in tqdm(NEIGHBORS):
    for valence in tqdm(VALENCES):
        feature = f"LDA-LOF_{valence}_{n_neighbors}"
        data[feature] = load_extractor(feature).score_samples(
            data.loc[:, ["LDA1", "LDA2"]]
        )

spot_check(data, labels)

for valence in tqdm(VALENCES):
    feature = f"LDA-LOF_{valence}_PCA"
    data[feature] = load_extractor(feature).transform(
        data.loc[:, [f"LDA-LOF_{valence}_{k}" for k in NEIGHBORS]]
    )

spot_check(data, labels)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LDA1            1957 non-null   float64
#  1   LDA2            1957 non-null   float64
#  2   ocLDA_neg       1957 non-null   float64
#  3   ocLDA_neu       1957 non-null   float64
#  4   ocLDA_pos       1957 non-null   float64
#  5   LOF_neg_10      1957 non-null   float32
#  6   LOF_neu_10      1957 non-null   float32
#  7   LOF_pos_10      1957 non-null   float32
#  8   LOF_neg_20      1957 non-null   float32
#  9   LOF_neu_20      1957 non-null   float32
#  10  LOF_pos_20      1957 non-null   float32
#  11  LOF_neg_30      1957 non-null   float32
#  12  LOF_neu_30      1957 non-null   float32
#  13  LOF_pos_30      1957 non-null   float32
#  14  LOF_neg_PCA     1957 non-null   float32
#  15  LOF_neu_PCA     1957 non-null   float32
#  16  LOF_pos_PCA     1957 non-null   float32
#  17  LDA-LOF_neg_10  1957 non-null   float64
#  18  LDA-LOF_neu_10  1957 non-null   float64
#  19  LDA-LOF_pos_10  1957 non-null   float64
#  20  LDA-LOF_neg_20  1957 non-null   float64
#  21  LDA-LOF_neu_20  1957 non-null   float64
#  22  LDA-LOF_pos_20  1957 non-null   float64
#  23  LDA-LOF_neg_30  1957 non-null   float64
#  24  LDA-LOF_neu_30  1957 non-null   float64
#  25  LDA-LOF_pos_30  1957 non-null   float64
# dtypes: float32(12), float64(14)
# memory usage: 305.9 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  LOF_pos_PCA  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...    -0.581153
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...    -0.259397
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...     0.041439
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...    -0.541881
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...    -0.208536
#
#    LDA-LOF_neg_10  LDA-LOF_neu_10  LDA-LOF_pos_10  LDA-LOF_neg_20  \
# 0       -1.034290       -1.000557       -1.054362       -1.044115
# 1       -1.026830       -1.005252       -1.088208       -0.998103
# 2       -1.033347       -0.996270       -0.999330       -1.013485
# 3       -1.007436       -1.012776       -1.114729       -1.039304
# 4       -1.070502       -1.084462       -1.121573       -1.092355
#
#    LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-LOF_neg_30  LDA-LOF_neu_30  \
# 0       -1.105907       -1.044294       -1.010185       -1.235911
# 1       -1.009125       -1.001816       -0.990437       -1.015906
# 2       -1.097084       -0.983438       -0.997601       -1.168142
# 3       -1.049529       -1.089277       -1.053788       -1.037357
# 4       -1.257476       -1.060198       -1.083948       -1.308126
#
#    LDA-LOF_pos_30
# 0       -1.056285
# 1       -0.996915
# 2       -0.993240
# 3       -1.035601
# 4       -1.012482
#
# [5 rows x 26 columns]
#   0%|          | 0/3 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LDA1             1957 non-null   float64
#  1   LDA2             1957 non-null   float64
#  2   ocLDA_neg        1957 non-null   float64
#  3   ocLDA_neu        1957 non-null   float64
#  4   ocLDA_pos        1957 non-null   float64
#  5   LOF_neg_10       1957 non-null   float32
#  6   LOF_neu_10       1957 non-null   float32
#  7   LOF_pos_10       1957 non-null   float32
#  8   LOF_neg_20       1957 non-null   float32
#  9   LOF_neu_20       1957 non-null   float32
#  10  LOF_pos_20       1957 non-null   float32
#  11  LOF_neg_30       1957 non-null   float32
#  12  LOF_neu_30       1957 non-null   float32
#  13  LOF_pos_30       1957 non-null   float32
#  14  LOF_neg_PCA      1957 non-null   float32
#  15  LOF_neu_PCA      1957 non-null   float32
#  16  LOF_pos_PCA      1957 non-null   float32
#  17  LDA-LOF_neg_10   1957 non-null   float64
#  18  LDA-LOF_neu_10   1957 non-null   float64
#  19  LDA-LOF_pos_10   1957 non-null   float64
#  20  LDA-LOF_neg_20   1957 non-null   float64
#  21  LDA-LOF_neu_20   1957 non-null   float64
#  22  LDA-LOF_pos_20   1957 non-null   float64
#  23  LDA-LOF_neg_30   1957 non-null   float64
#  24  LDA-LOF_neu_30   1957 non-null   float64
#  25  LDA-LOF_pos_30   1957 non-null   float64
#  26  LDA-LOF_neg_PCA  1957 non-null   float64
#  27  LDA-LOF_neu_PCA  1957 non-null   float64
#  28  LDA-LOF_pos_PCA  1957 non-null   float64
# dtypes: float32(12), float64(17)
# memory usage: 351.8 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  LDA-LOF_pos_10  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...       -1.054362
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...       -1.088208
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...       -0.999330
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...       -1.114729
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...       -1.121573
#
#    LDA-LOF_neg_20  LDA-LOF_neu_20  LDA-LOF_pos_20  LDA-LOF_neg_30  \
# 0       -1.044115       -1.105907       -1.044294       -1.010185
# 1       -0.998103       -1.009125       -1.001816       -0.990437
# 2       -1.013485       -1.097084       -0.983438       -0.997601
# 3       -1.039304       -1.049529       -1.089277       -1.053788
# 4       -1.092355       -1.257476       -1.060198       -1.083948
#
#    LDA-LOF_neu_30  LDA-LOF_pos_30  LDA-LOF_neg_PCA  LDA-LOF_neu_PCA  \
# 0       -1.235911       -1.056285         0.005455         0.001976
# 1       -1.015906       -0.996915         0.048191         0.186477
# 2       -1.168142       -0.993240         0.031359         0.050228
# 3       -1.037357       -1.035601        -0.003135         0.146538
# 4       -1.308126       -1.012482        -0.086739        -0.174336
#
#    LDA-LOF_pos_PCA
# 0         0.070664
# 1         0.112274
# 2         0.174107
# 3         0.023888
# 4         0.050818
#
# [5 rows x 29 columns]
# time: 449 ms

# %% [markdown]
# # One-class SVM scores of FRILL embeddings (and their LDA components) and of the LDA components of the FRILL embeddings

# %%
for oc_svm in tqdm(OC_SVM):
    prefix = f"ocSVM_{oc_svm}"
    # one-class scores of FRILL embeddings
    for valence in VALENCES:
        feature = f"{prefix}_{valence}"
        data[feature] = load_extractor(feature).score_samples(frill)
    # LDA components of one-class scores of FRILL embeddings
    df = data.loc[:, feature_trio(prefix, "")]
    features = [f"{prefix}_LDA1", f"{prefix}_LDA2"]
    df = pd.DataFrame(
        load_extractor("_-_".join(features)).transform(df), columns=features
    )
    data = pd.concat([data, df], axis="columns")
    del df
    del features
    _ = gc_collect()
    # one-class scores of LDA components of FRILL embeddings
    for feature in feature_trio(f"LDA-{prefix}", ""):
        data[feature] = load_extractor(feature).score_samples(
            data.loc[:, ["LDA1", "LDA2"]]
        )
spot_check(data, labels)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 69 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LOF_neg_10               1957 non-null   float32
#  6   LOF_neu_10               1957 non-null   float32
#  7   LOF_pos_10               1957 non-null   float32
#  8   LOF_neg_20               1957 non-null   float32
#  9   LOF_neu_20               1957 non-null   float32
#  10  LOF_pos_20               1957 non-null   float32
#  11  LOF_neg_30               1957 non-null   float32
#  12  LOF_neu_30               1957 non-null   float32
#  13  LOF_pos_30               1957 non-null   float32
#  14  LOF_neg_PCA              1957 non-null   float32
#  15  LOF_neu_PCA              1957 non-null   float32
#  16  LOF_pos_PCA              1957 non-null   float32
#  17  LDA-LOF_neg_10           1957 non-null   float64
#  18  LDA-LOF_neu_10           1957 non-null   float64
#  19  LDA-LOF_pos_10           1957 non-null   float64
#  20  LDA-LOF_neg_20           1957 non-null   float64
#  21  LDA-LOF_neu_20           1957 non-null   float64
#  22  LDA-LOF_pos_20           1957 non-null   float64
#  23  LDA-LOF_neg_30           1957 non-null   float64
#  24  LDA-LOF_neu_30           1957 non-null   float64
#  25  LDA-LOF_pos_30           1957 non-null   float64
#  26  LDA-LOF_neg_PCA          1957 non-null   float64
#  27  LDA-LOF_neu_PCA          1957 non-null   float64
#  28  LDA-LOF_pos_PCA          1957 non-null   float64
#  29  ocSVM_sgdlinear_neg      1957 non-null   float64
#  30  ocSVM_sgdlinear_neu      1957 non-null   float64
#  31  ocSVM_sgdlinear_pos      1957 non-null   float64
#  32  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  33  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  34  LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  35  LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  36  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  37  ocSVM_rbf_neg            1957 non-null   float64
#  38  ocSVM_rbf_neu            1957 non-null   float64
#  39  ocSVM_rbf_pos            1957 non-null   float64
#  40  ocSVM_rbf_LDA1           1957 non-null   float64
#  41  ocSVM_rbf_LDA2           1957 non-null   float64
#  42  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  43  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  44  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  45  ocSVM_sigmoid_neg        1957 non-null   float64
#  46  ocSVM_sigmoid_neu        1957 non-null   float64
#  47  ocSVM_sigmoid_pos        1957 non-null   float64
#  48  ocSVM_sigmoid_LDA1       1957 non-null   float64
#  49  ocSVM_sigmoid_LDA2       1957 non-null   float64
#  50  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  51  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  52  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  53  ocSVM_poly5_neg          1957 non-null   float64
#  54  ocSVM_poly5_neu          1957 non-null   float64
#  55  ocSVM_poly5_pos          1957 non-null   float64
#  56  ocSVM_poly5_LDA1         1957 non-null   float64
#  57  ocSVM_poly5_LDA2         1957 non-null   float64
#  58  LDA-ocSVM_poly5_neg      1957 non-null   float64
#  59  LDA-ocSVM_poly5_neu      1957 non-null   float64
#  60  LDA-ocSVM_poly5_pos      1957 non-null   float64
#  61  ocSVM_poly6_neg          1957 non-null   float64
#  62  ocSVM_poly6_neu          1957 non-null   float64
#  63  ocSVM_poly6_pos          1957 non-null   float64
#  64  ocSVM_poly6_LDA1         1957 non-null   float64
#  65  ocSVM_poly6_LDA2         1957 non-null   float64
#  66  LDA-ocSVM_poly6_neg      1957 non-null   float64
#  67  LDA-ocSVM_poly6_neu      1957 non-null   float64
#  68  LDA-ocSVM_poly6_pos      1957 non-null   float64
# dtypes: float32(12), float64(57)
# memory usage: 963.3 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  LDA-ocSVM_poly5_neu  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...          -208.929305
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...           -11.617114
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...          -218.639273
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...           -12.043912
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...          -708.255804
#
#    LDA-ocSVM_poly5_pos  ocSVM_poly6_neg  ocSVM_poly6_neu  ocSVM_poly6_pos  \
# 0             0.000039         3.070262         0.697668         1.209082
# 1             0.000001         2.707450         0.623396         1.064647
# 2             0.000010         3.560355         0.862953         1.409045
# 3             0.000163         6.571688         1.454933         2.371760
# 4             0.000229         5.016795         1.031890         1.887000
#
#    ocSVM_poly6_LDA1  ocSVM_poly6_LDA2  LDA-ocSVM_poly6_neg  \
# 0         -0.392961          0.285280          1664.602412
# 1         -0.328475          0.242286            38.293673
# 2         -0.394055          0.343421           793.769504
# 3         -1.222963          0.295605          5763.655093
# 4         -0.926832          0.356653          9696.335102
#
#    LDA-ocSVM_poly6_neu  LDA-ocSVM_poly6_pos
# 0           395.325571            65.052503
# 1             9.852249             1.475788
# 2           235.463271            26.652357
# 3          1027.228634           185.923277
# 4          2153.740325           377.354692
#
# [5 rows x 69 columns]
# time: 7min 4s

# %% [markdown]
# # Spherical coordinates

# %%
features_ = [["LDA1", "LDA2"], feature_trio("ocLDA", "")]

for n_neighbors in NEIGHBORS:
    features_.extend(
        [
            feature_trio(f"LDA-LOF", n_neighbors),
            feature_trio(f"LOF", n_neighbors),
        ]
    )
features_.extend(
    [
        feature_trio(f"LDA-LOF", "PCA"),
        feature_trio(f"LOF", "PCA"),
    ]
)
for descriptor in OC_SVM:
    features_.extend(
        [
            feature_trio(f"ocSVM_{descriptor}", ""),
            [f"ocSVM_{descriptor}_LDA1", f"ocSVM_{descriptor}_LDA2"],
            feature_trio(f"LDA-ocSVM_{descriptor}", ""),
        ]
    )

all_features = []
for feature_set in features_:
    all_features.extend(feature_set)
assert sorted(all_features) == sorted(list(data.columns))

_ = gc_collect()
# Out:
# time: 117 ms

# %%
sphericals = {}
for features in features_:
    combo = "+".join(features)
    df = data.loc[:, features]
    x, y = df[features[0]], df[features[1]]
    theta, phi = f"theta_{combo}", f"phi_{combo}"
    sphericals[theta] = arctan2(y, x)
    # convert to polar
    if len(features) == 3:
        sphericals[phi] = arctan2(sqrt(x ** 2 + y ** 2), df[features[2]])
    del df
    del x
    del y
    del combo
    _ = gc_collect()

sphericals = pd.DataFrame(sphericals)
sphericals.head()
sphericals.info()
# Out:
#    theta_LDA1+LDA2  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0         2.270171                            -1.836805
# 1         2.406045                            -1.616909
# 2         2.811944                            -1.202803
# 3         1.663026                            -3.072482
# 4         2.163299                            -2.046872
#
#    phi_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0                           0.586375
# 1                           0.667643
# 2                           0.982068
# 3                           0.632624
# 4                           0.541106
#
#    theta_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10  \
# 0                                          -2.372771
# 1                                          -2.366813
# 2                                          -2.374460
# 3                                          -2.353551
# 4                                          -2.349717
#
#    phi_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10  \
# 0                                          2.203119
# 1                                          2.218946
# 2                                          2.178971
# 3                                          2.233436
# 4                                          2.205294
#
#    theta_LOF_neg_10+LOF_neu_10+LOF_pos_10  \
# 0                               -2.349876
# 1                               -2.369632
# 2                               -2.338157
# 3                               -2.447289
# 4                               -2.322934
#
#    phi_LOF_neg_10+LOF_neu_10+LOF_pos_10  \
# 0                              2.322760
# 1                              2.220962
# 2                              2.203633
# 3                              2.249757
# 4                              2.221186
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          -2.327462
# 1                                          -2.350703
# 2                                          -2.316605
# 3                                          -2.351299
# 4                                          -2.286041
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          2.172485
# 1                                          2.185424
# 2                                          2.153088
# 3                                          2.206230
# 4                                          2.137620
#
#    theta_LOF_neg_20+LOF_neu_20+LOF_pos_20  ...  \
# 0                               -2.359419  ...
# 1                               -2.341869  ...
# 2                               -2.334869  ...
# 3                               -2.428448  ...
# 4                               -2.368039  ...
#
#    theta_ocSVM_poly5_neg+ocSVM_poly5_neu+ocSVM_poly5_pos  \
# 0                                           0.236955
# 1                                           0.238272
# 2                                           0.248262
# 3                                           0.229963
# 4                                           0.215748
#
#    phi_ocSVM_poly5_neg+ocSVM_poly5_neu+ocSVM_poly5_pos  \
# 0                                           1.206338
# 1                                           1.217777
# 2                                           1.208120
# 3                                           1.232911
# 4                                           1.219682
#
#    theta_ocSVM_poly5_LDA1+ocSVM_poly5_LDA2  \
# 0                                -0.574844
# 1                                -0.353619
# 2                                -0.689257
# 3                                -0.103535
# 4                                -0.227366
#
#    theta_LDA-ocSVM_poly5_neg+LDA-ocSVM_poly5_neu+LDA-ocSVM_poly5_pos  \
# 0                                          -1.570796
# 1                                          -1.570796
# 2                                          -1.570796
# 3                                          -1.570805
# 4                                          -1.570796
#
#    phi_LDA-ocSVM_poly5_neg+LDA-ocSVM_poly5_neu+LDA-ocSVM_poly5_pos  \
# 0                                           1.570796
# 1                                           1.570796
# 2                                           1.570796
# 3                                           1.570783
# 4                                           1.570796
#
#    theta_ocSVM_poly6_neg+ocSVM_poly6_neu+ocSVM_poly6_pos  \
# 0                                           0.223440
# 1                                           0.226308
# 2                                           0.237793
# 3                                           0.217880
# 4                                           0.202858
#
#    phi_ocSVM_poly6_neg+ocSVM_poly6_neu+ocSVM_poly6_pos  \
# 0                                           1.204146
# 1                                           1.204854
# 2                                           1.203616
# 3                                           1.232009
# 4                                           1.217804
#
#    theta_ocSVM_poly6_LDA1+ocSVM_poly6_LDA2  \
# 0                                 2.513645
# 1                                 2.506070
# 2                                 2.424746
# 3                                 2.904429
# 4                                 2.774251
#
#    theta_LDA-ocSVM_poly6_neg+LDA-ocSVM_poly6_neu+LDA-ocSVM_poly6_pos  \
# 0                                           0.233170
# 1                                           0.251820
# 2                                           0.288371
# 3                                           0.176373
# 4                                           0.218571
#
#    phi_LDA-ocSVM_poly6_neg+LDA-ocSVM_poly6_neu+LDA-ocSVM_poly6_pos
# 0                                           1.532792
# 1                                           1.533490
# 2                                           1.538617
# 3                                           1.539050
# 4                                           1.532823
#
# [5 rows x 44 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 44 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   theta_LDA1+LDA2                                                                1957 non-null   float64
#  1   theta_ocLDA_neg+ocLDA_neu+ocLDA_pos                                            1957 non-null   float64
#  2   phi_ocLDA_neg+ocLDA_neu+ocLDA_pos                                              1957 non-null   float64
#  3   theta_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10                             1957 non-null   float64
#  4   phi_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10                               1957 non-null   float64
#  5   theta_LOF_neg_10+LOF_neu_10+LOF_pos_10                                         1957 non-null   float32
#  6   phi_LOF_neg_10+LOF_neu_10+LOF_pos_10                                           1957 non-null   float32
#  7   theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                             1957 non-null   float64
#  8   phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20                               1957 non-null   float64
#  9   theta_LOF_neg_20+LOF_neu_20+LOF_pos_20                                         1957 non-null   float32
#  10  phi_LOF_neg_20+LOF_neu_20+LOF_pos_20                                           1957 non-null   float32
#  11  theta_LDA-LOF_neg_30+LDA-LOF_neu_30+LDA-LOF_pos_30                             1957 non-null   float64
#  12  phi_LDA-LOF_neg_30+LDA-LOF_neu_30+LDA-LOF_pos_30                               1957 non-null   float64
#  13  theta_LOF_neg_30+LOF_neu_30+LOF_pos_30                                         1957 non-null   float32
#  14  phi_LOF_neg_30+LOF_neu_30+LOF_pos_30                                           1957 non-null   float32
#  15  theta_LDA-LOF_neg_PCA+LDA-LOF_neu_PCA+LDA-LOF_pos_PCA                          1957 non-null   float64
#  16  phi_LDA-LOF_neg_PCA+LDA-LOF_neu_PCA+LDA-LOF_pos_PCA                            1957 non-null   float64
#  17  theta_LOF_neg_PCA+LOF_neu_PCA+LOF_pos_PCA                                      1957 non-null   float32
#  18  phi_LOF_neg_PCA+LOF_neu_PCA+LOF_pos_PCA                                        1957 non-null   float32
#  19  theta_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos              1957 non-null   float64
#  20  phi_ocSVM_sgdlinear_neg+ocSVM_sgdlinear_neu+ocSVM_sgdlinear_pos                1957 non-null   float64
#  21  theta_ocSVM_sgdlinear_LDA1+ocSVM_sgdlinear_LDA2                                1957 non-null   float64
#  22  theta_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  23  phi_LDA-ocSVM_sgdlinear_neg+LDA-ocSVM_sgdlinear_neu+LDA-ocSVM_sgdlinear_pos    1957 non-null   float64
#  24  theta_ocSVM_rbf_neg+ocSVM_rbf_neu+ocSVM_rbf_pos                                1957 non-null   float64
#  25  phi_ocSVM_rbf_neg+ocSVM_rbf_neu+ocSVM_rbf_pos                                  1957 non-null   float64
#  26  theta_ocSVM_rbf_LDA1+ocSVM_rbf_LDA2                                            1957 non-null   float64
#  27  theta_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                    1957 non-null   float64
#  28  phi_LDA-ocSVM_rbf_neg+LDA-ocSVM_rbf_neu+LDA-ocSVM_rbf_pos                      1957 non-null   float64
#  29  theta_ocSVM_sigmoid_neg+ocSVM_sigmoid_neu+ocSVM_sigmoid_pos                    1957 non-null   float64
#  30  phi_ocSVM_sigmoid_neg+ocSVM_sigmoid_neu+ocSVM_sigmoid_pos                      1957 non-null   float64
#  31  theta_ocSVM_sigmoid_LDA1+ocSVM_sigmoid_LDA2                                    1957 non-null   float64
#  32  theta_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos        1957 non-null   float64
#  33  phi_LDA-ocSVM_sigmoid_neg+LDA-ocSVM_sigmoid_neu+LDA-ocSVM_sigmoid_pos          1957 non-null   float64
#  34  theta_ocSVM_poly5_neg+ocSVM_poly5_neu+ocSVM_poly5_pos                          1957 non-null   float64
#  35  phi_ocSVM_poly5_neg+ocSVM_poly5_neu+ocSVM_poly5_pos                            1957 non-null   float64
#  36  theta_ocSVM_poly5_LDA1+ocSVM_poly5_LDA2                                        1957 non-null   float64
#  37  theta_LDA-ocSVM_poly5_neg+LDA-ocSVM_poly5_neu+LDA-ocSVM_poly5_pos              1957 non-null   float64
#  38  phi_LDA-ocSVM_poly5_neg+LDA-ocSVM_poly5_neu+LDA-ocSVM_poly5_pos                1957 non-null   float64
#  39  theta_ocSVM_poly6_neg+ocSVM_poly6_neu+ocSVM_poly6_pos                          1957 non-null   float64
#  40  phi_ocSVM_poly6_neg+ocSVM_poly6_neu+ocSVM_poly6_pos                            1957 non-null   float64
#  41  theta_ocSVM_poly6_LDA1+ocSVM_poly6_LDA2                                        1957 non-null   float64
#  42  theta_LDA-ocSVM_poly6_neg+LDA-ocSVM_poly6_neu+LDA-ocSVM_poly6_pos              1957 non-null   float64
#  43  phi_LDA-ocSVM_poly6_neg+LDA-ocSVM_poly6_neu+LDA-ocSVM_poly6_pos                1957 non-null   float64
# dtypes: float32(8), float64(36)
# memory usage: 611.7 KB
# time: 2.72 s

# %%
assert all(sphericals.index == labels.index)
assert all(sphericals.index == data.index)
spot_check(data, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 69 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LOF_neg_10               1957 non-null   float32
#  6   LOF_neu_10               1957 non-null   float32
#  7   LOF_pos_10               1957 non-null   float32
#  8   LOF_neg_20               1957 non-null   float32
#  9   LOF_neu_20               1957 non-null   float32
#  10  LOF_pos_20               1957 non-null   float32
#  11  LOF_neg_30               1957 non-null   float32
#  12  LOF_neu_30               1957 non-null   float32
#  13  LOF_pos_30               1957 non-null   float32
#  14  LOF_neg_PCA              1957 non-null   float32
#  15  LOF_neu_PCA              1957 non-null   float32
#  16  LOF_pos_PCA              1957 non-null   float32
#  17  LDA-LOF_neg_10           1957 non-null   float64
#  18  LDA-LOF_neu_10           1957 non-null   float64
#  19  LDA-LOF_pos_10           1957 non-null   float64
#  20  LDA-LOF_neg_20           1957 non-null   float64
#  21  LDA-LOF_neu_20           1957 non-null   float64
#  22  LDA-LOF_pos_20           1957 non-null   float64
#  23  LDA-LOF_neg_30           1957 non-null   float64
#  24  LDA-LOF_neu_30           1957 non-null   float64
#  25  LDA-LOF_pos_30           1957 non-null   float64
#  26  LDA-LOF_neg_PCA          1957 non-null   float64
#  27  LDA-LOF_neu_PCA          1957 non-null   float64
#  28  LDA-LOF_pos_PCA          1957 non-null   float64
#  29  ocSVM_sgdlinear_neg      1957 non-null   float64
#  30  ocSVM_sgdlinear_neu      1957 non-null   float64
#  31  ocSVM_sgdlinear_pos      1957 non-null   float64
#  32  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  33  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  34  LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  35  LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  36  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  37  ocSVM_rbf_neg            1957 non-null   float64
#  38  ocSVM_rbf_neu            1957 non-null   float64
#  39  ocSVM_rbf_pos            1957 non-null   float64
#  40  ocSVM_rbf_LDA1           1957 non-null   float64
#  41  ocSVM_rbf_LDA2           1957 non-null   float64
#  42  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  43  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  44  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  45  ocSVM_sigmoid_neg        1957 non-null   float64
#  46  ocSVM_sigmoid_neu        1957 non-null   float64
#  47  ocSVM_sigmoid_pos        1957 non-null   float64
#  48  ocSVM_sigmoid_LDA1       1957 non-null   float64
#  49  ocSVM_sigmoid_LDA2       1957 non-null   float64
#  50  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  51  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  52  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  53  ocSVM_poly5_neg          1957 non-null   float64
#  54  ocSVM_poly5_neu          1957 non-null   float64
#  55  ocSVM_poly5_pos          1957 non-null   float64
#  56  ocSVM_poly5_LDA1         1957 non-null   float64
#  57  ocSVM_poly5_LDA2         1957 non-null   float64
#  58  LDA-ocSVM_poly5_neg      1957 non-null   float64
#  59  LDA-ocSVM_poly5_neu      1957 non-null   float64
#  60  LDA-ocSVM_poly5_pos      1957 non-null   float64
#  61  ocSVM_poly6_neg          1957 non-null   float64
#  62  ocSVM_poly6_neu          1957 non-null   float64
#  63  ocSVM_poly6_pos          1957 non-null   float64
#  64  ocSVM_poly6_LDA1         1957 non-null   float64
#  65  ocSVM_poly6_LDA2         1957 non-null   float64
#  66  LDA-ocSVM_poly6_neg      1957 non-null   float64
#  67  LDA-ocSVM_poly6_neu      1957 non-null   float64
#  68  LDA-ocSVM_poly6_pos      1957 non-null   float64
# dtypes: float32(12), float64(57)
# memory usage: 963.3 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  LDA-ocSVM_poly5_neu  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...          -208.929305
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...           -11.617114
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...          -218.639273
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...           -12.043912
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...          -708.255804
#
#    LDA-ocSVM_poly5_pos  ocSVM_poly6_neg  ocSVM_poly6_neu  ocSVM_poly6_pos  \
# 0             0.000039         3.070262         0.697668         1.209082
# 1             0.000001         2.707450         0.623396         1.064647
# 2             0.000010         3.560355         0.862953         1.409045
# 3             0.000163         6.571688         1.454933         2.371760
# 4             0.000229         5.016795         1.031890         1.887000
#
#    ocSVM_poly6_LDA1  ocSVM_poly6_LDA2  LDA-ocSVM_poly6_neg  \
# 0         -0.392961          0.285280          1664.602412
# 1         -0.328475          0.242286            38.293673
# 2         -0.394055          0.343421           793.769504
# 3         -1.222963          0.295605          5763.655093
# 4         -0.926832          0.356653          9696.335102
#
#    LDA-ocSVM_poly6_neu  LDA-ocSVM_poly6_pos
# 0           395.325571            65.052503
# 1             9.852249             1.475788
# 2           235.463271            26.652357
# 3          1027.228634           185.923277
# 4          2153.740325           377.354692
#
# [5 rows x 69 columns]
# time: 21 ms

# %% [markdown]
# # LDA components of spherical FRILL-based features

# %%
features = ["spherical-LDA1", "spherical-LDA2"]
df = pd.DataFrame(
    load_extractor("_-_".join(features)).transform(sphericals), columns=features
)
assert all(df.index == labels.index)
assert all(df.index == data.index)
_ = gc_collect()
# Out:
# time: 128 ms

# %%
df_ = pd.concat(
    [
        data,
        df,
    ],
    axis="columns",
)
spot_check(df_, labels)
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 71 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LOF_neg_10               1957 non-null   float32
#  6   LOF_neu_10               1957 non-null   float32
#  7   LOF_pos_10               1957 non-null   float32
#  8   LOF_neg_20               1957 non-null   float32
#  9   LOF_neu_20               1957 non-null   float32
#  10  LOF_pos_20               1957 non-null   float32
#  11  LOF_neg_30               1957 non-null   float32
#  12  LOF_neu_30               1957 non-null   float32
#  13  LOF_pos_30               1957 non-null   float32
#  14  LOF_neg_PCA              1957 non-null   float32
#  15  LOF_neu_PCA              1957 non-null   float32
#  16  LOF_pos_PCA              1957 non-null   float32
#  17  LDA-LOF_neg_10           1957 non-null   float64
#  18  LDA-LOF_neu_10           1957 non-null   float64
#  19  LDA-LOF_pos_10           1957 non-null   float64
#  20  LDA-LOF_neg_20           1957 non-null   float64
#  21  LDA-LOF_neu_20           1957 non-null   float64
#  22  LDA-LOF_pos_20           1957 non-null   float64
#  23  LDA-LOF_neg_30           1957 non-null   float64
#  24  LDA-LOF_neu_30           1957 non-null   float64
#  25  LDA-LOF_pos_30           1957 non-null   float64
#  26  LDA-LOF_neg_PCA          1957 non-null   float64
#  27  LDA-LOF_neu_PCA          1957 non-null   float64
#  28  LDA-LOF_pos_PCA          1957 non-null   float64
#  29  ocSVM_sgdlinear_neg      1957 non-null   float64
#  30  ocSVM_sgdlinear_neu      1957 non-null   float64
#  31  ocSVM_sgdlinear_pos      1957 non-null   float64
#  32  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  33  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  34  LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  35  LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  36  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  37  ocSVM_rbf_neg            1957 non-null   float64
#  38  ocSVM_rbf_neu            1957 non-null   float64
#  39  ocSVM_rbf_pos            1957 non-null   float64
#  40  ocSVM_rbf_LDA1           1957 non-null   float64
#  41  ocSVM_rbf_LDA2           1957 non-null   float64
#  42  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  43  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  44  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  45  ocSVM_sigmoid_neg        1957 non-null   float64
#  46  ocSVM_sigmoid_neu        1957 non-null   float64
#  47  ocSVM_sigmoid_pos        1957 non-null   float64
#  48  ocSVM_sigmoid_LDA1       1957 non-null   float64
#  49  ocSVM_sigmoid_LDA2       1957 non-null   float64
#  50  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  51  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  52  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  53  ocSVM_poly5_neg          1957 non-null   float64
#  54  ocSVM_poly5_neu          1957 non-null   float64
#  55  ocSVM_poly5_pos          1957 non-null   float64
#  56  ocSVM_poly5_LDA1         1957 non-null   float64
#  57  ocSVM_poly5_LDA2         1957 non-null   float64
#  58  LDA-ocSVM_poly5_neg      1957 non-null   float64
#  59  LDA-ocSVM_poly5_neu      1957 non-null   float64
#  60  LDA-ocSVM_poly5_pos      1957 non-null   float64
#  61  ocSVM_poly6_neg          1957 non-null   float64
#  62  ocSVM_poly6_neu          1957 non-null   float64
#  63  ocSVM_poly6_pos          1957 non-null   float64
#  64  ocSVM_poly6_LDA1         1957 non-null   float64
#  65  ocSVM_poly6_LDA2         1957 non-null   float64
#  66  LDA-ocSVM_poly6_neg      1957 non-null   float64
#  67  LDA-ocSVM_poly6_neu      1957 non-null   float64
#  68  LDA-ocSVM_poly6_pos      1957 non-null   float64
#  69  spherical-LDA1           1957 non-null   float64
#  70  spherical-LDA2           1957 non-null   float64
# dtypes: float32(12), float64(59)
# memory usage: 993.9 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  ocSVM_poly6_neg  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...         3.070262
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...         2.707450
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...         3.560355
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...         6.571688
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...         5.016795
#
#    ocSVM_poly6_neu  ocSVM_poly6_pos  ocSVM_poly6_LDA1  ocSVM_poly6_LDA2  \
# 0         0.697668         1.209082         -0.392961          0.285280
# 1         0.623396         1.064647         -0.328475          0.242286
# 2         0.862953         1.409045         -0.394055          0.343421
# 3         1.454933         2.371760         -1.222963          0.295605
# 4         1.031890         1.887000         -0.926832          0.356653
#
#    LDA-ocSVM_poly6_neg  LDA-ocSVM_poly6_neu  LDA-ocSVM_poly6_pos  \
# 0          1664.602412           395.325571            65.052503
# 1            38.293673             9.852249             1.475788
# 2           793.769504           235.463271            26.652357
# 3          5763.655093          1027.228634           185.923277
# 4          9696.335102          2153.740325           377.354692
#
#    spherical-LDA1  spherical-LDA2
# 0       -0.757583        0.159719
# 1       -0.771626        0.078771
# 2       -0.639456        0.024716
# 3       -0.920840        0.316908
# 4       -1.339164        0.386423
#
# [5 rows x 71 columns]
# time: 136 ms

# %%
data = df_
spot_check(data, labels)
del df
del df_
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 71 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LOF_neg_10               1957 non-null   float32
#  6   LOF_neu_10               1957 non-null   float32
#  7   LOF_pos_10               1957 non-null   float32
#  8   LOF_neg_20               1957 non-null   float32
#  9   LOF_neu_20               1957 non-null   float32
#  10  LOF_pos_20               1957 non-null   float32
#  11  LOF_neg_30               1957 non-null   float32
#  12  LOF_neu_30               1957 non-null   float32
#  13  LOF_pos_30               1957 non-null   float32
#  14  LOF_neg_PCA              1957 non-null   float32
#  15  LOF_neu_PCA              1957 non-null   float32
#  16  LOF_pos_PCA              1957 non-null   float32
#  17  LDA-LOF_neg_10           1957 non-null   float64
#  18  LDA-LOF_neu_10           1957 non-null   float64
#  19  LDA-LOF_pos_10           1957 non-null   float64
#  20  LDA-LOF_neg_20           1957 non-null   float64
#  21  LDA-LOF_neu_20           1957 non-null   float64
#  22  LDA-LOF_pos_20           1957 non-null   float64
#  23  LDA-LOF_neg_30           1957 non-null   float64
#  24  LDA-LOF_neu_30           1957 non-null   float64
#  25  LDA-LOF_pos_30           1957 non-null   float64
#  26  LDA-LOF_neg_PCA          1957 non-null   float64
#  27  LDA-LOF_neu_PCA          1957 non-null   float64
#  28  LDA-LOF_pos_PCA          1957 non-null   float64
#  29  ocSVM_sgdlinear_neg      1957 non-null   float64
#  30  ocSVM_sgdlinear_neu      1957 non-null   float64
#  31  ocSVM_sgdlinear_pos      1957 non-null   float64
#  32  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  33  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  34  LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  35  LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  36  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  37  ocSVM_rbf_neg            1957 non-null   float64
#  38  ocSVM_rbf_neu            1957 non-null   float64
#  39  ocSVM_rbf_pos            1957 non-null   float64
#  40  ocSVM_rbf_LDA1           1957 non-null   float64
#  41  ocSVM_rbf_LDA2           1957 non-null   float64
#  42  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  43  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  44  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  45  ocSVM_sigmoid_neg        1957 non-null   float64
#  46  ocSVM_sigmoid_neu        1957 non-null   float64
#  47  ocSVM_sigmoid_pos        1957 non-null   float64
#  48  ocSVM_sigmoid_LDA1       1957 non-null   float64
#  49  ocSVM_sigmoid_LDA2       1957 non-null   float64
#  50  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  51  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  52  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  53  ocSVM_poly5_neg          1957 non-null   float64
#  54  ocSVM_poly5_neu          1957 non-null   float64
#  55  ocSVM_poly5_pos          1957 non-null   float64
#  56  ocSVM_poly5_LDA1         1957 non-null   float64
#  57  ocSVM_poly5_LDA2         1957 non-null   float64
#  58  LDA-ocSVM_poly5_neg      1957 non-null   float64
#  59  LDA-ocSVM_poly5_neu      1957 non-null   float64
#  60  LDA-ocSVM_poly5_pos      1957 non-null   float64
#  61  ocSVM_poly6_neg          1957 non-null   float64
#  62  ocSVM_poly6_neu          1957 non-null   float64
#  63  ocSVM_poly6_pos          1957 non-null   float64
#  64  ocSVM_poly6_LDA1         1957 non-null   float64
#  65  ocSVM_poly6_LDA2         1957 non-null   float64
#  66  LDA-ocSVM_poly6_neg      1957 non-null   float64
#  67  LDA-ocSVM_poly6_neu      1957 non-null   float64
#  68  LDA-ocSVM_poly6_pos      1957 non-null   float64
#  69  spherical-LDA1           1957 non-null   float64
#  70  spherical-LDA2           1957 non-null   float64
# dtypes: float32(12), float64(59)
# memory usage: 993.9 KB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  ocSVM_poly6_neg  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...         3.070262
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...         2.707450
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...         3.560355
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...         6.571688
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...         5.016795
#
#    ocSVM_poly6_neu  ocSVM_poly6_pos  ocSVM_poly6_LDA1  ocSVM_poly6_LDA2  \
# 0         0.697668         1.209082         -0.392961          0.285280
# 1         0.623396         1.064647         -0.328475          0.242286
# 2         0.862953         1.409045         -0.394055          0.343421
# 3         1.454933         2.371760         -1.222963          0.295605
# 4         1.031890         1.887000         -0.926832          0.356653
#
#    LDA-ocSVM_poly6_neg  LDA-ocSVM_poly6_neu  LDA-ocSVM_poly6_pos  \
# 0          1664.602412           395.325571            65.052503
# 1            38.293673             9.852249             1.475788
# 2           793.769504           235.463271            26.652357
# 3          5763.655093          1027.228634           185.923277
# 4          9696.335102          2153.740325           377.354692
#
#    spherical-LDA1  spherical-LDA2
# 0       -0.757583        0.159719
# 1       -0.771626        0.078771
# 2       -0.639456        0.024716
# 3       -0.920840        0.316908
# 4       -1.339164        0.386423
#
# [5 rows x 71 columns]
# time: 133 ms

# %% [markdown]
# # One-class LDA components of spherical FRILL-based features

# %%
df = pd.concat(
    [
        data,
        pd.DataFrame(
            {
                feature: np.squeeze(load_extractor(feature).transform(sphericals))
                for feature in feature_trio("spherical-ocLDA", "")
            }
        ),
    ],
    axis="columns",
)
spot_check(df, labels)
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Data columns (total 74 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LDA1                     1957 non-null   float64
#  1   LDA2                     1957 non-null   float64
#  2   ocLDA_neg                1957 non-null   float64
#  3   ocLDA_neu                1957 non-null   float64
#  4   ocLDA_pos                1957 non-null   float64
#  5   LOF_neg_10               1957 non-null   float32
#  6   LOF_neu_10               1957 non-null   float32
#  7   LOF_pos_10               1957 non-null   float32
#  8   LOF_neg_20               1957 non-null   float32
#  9   LOF_neu_20               1957 non-null   float32
#  10  LOF_pos_20               1957 non-null   float32
#  11  LOF_neg_30               1957 non-null   float32
#  12  LOF_neu_30               1957 non-null   float32
#  13  LOF_pos_30               1957 non-null   float32
#  14  LOF_neg_PCA              1957 non-null   float32
#  15  LOF_neu_PCA              1957 non-null   float32
#  16  LOF_pos_PCA              1957 non-null   float32
#  17  LDA-LOF_neg_10           1957 non-null   float64
#  18  LDA-LOF_neu_10           1957 non-null   float64
#  19  LDA-LOF_pos_10           1957 non-null   float64
#  20  LDA-LOF_neg_20           1957 non-null   float64
#  21  LDA-LOF_neu_20           1957 non-null   float64
#  22  LDA-LOF_pos_20           1957 non-null   float64
#  23  LDA-LOF_neg_30           1957 non-null   float64
#  24  LDA-LOF_neu_30           1957 non-null   float64
#  25  LDA-LOF_pos_30           1957 non-null   float64
#  26  LDA-LOF_neg_PCA          1957 non-null   float64
#  27  LDA-LOF_neu_PCA          1957 non-null   float64
#  28  LDA-LOF_pos_PCA          1957 non-null   float64
#  29  ocSVM_sgdlinear_neg      1957 non-null   float64
#  30  ocSVM_sgdlinear_neu      1957 non-null   float64
#  31  ocSVM_sgdlinear_pos      1957 non-null   float64
#  32  ocSVM_sgdlinear_LDA1     1957 non-null   float64
#  33  ocSVM_sgdlinear_LDA2     1957 non-null   float64
#  34  LDA-ocSVM_sgdlinear_neg  1957 non-null   float64
#  35  LDA-ocSVM_sgdlinear_neu  1957 non-null   float64
#  36  LDA-ocSVM_sgdlinear_pos  1957 non-null   float64
#  37  ocSVM_rbf_neg            1957 non-null   float64
#  38  ocSVM_rbf_neu            1957 non-null   float64
#  39  ocSVM_rbf_pos            1957 non-null   float64
#  40  ocSVM_rbf_LDA1           1957 non-null   float64
#  41  ocSVM_rbf_LDA2           1957 non-null   float64
#  42  LDA-ocSVM_rbf_neg        1957 non-null   float64
#  43  LDA-ocSVM_rbf_neu        1957 non-null   float64
#  44  LDA-ocSVM_rbf_pos        1957 non-null   float64
#  45  ocSVM_sigmoid_neg        1957 non-null   float64
#  46  ocSVM_sigmoid_neu        1957 non-null   float64
#  47  ocSVM_sigmoid_pos        1957 non-null   float64
#  48  ocSVM_sigmoid_LDA1       1957 non-null   float64
#  49  ocSVM_sigmoid_LDA2       1957 non-null   float64
#  50  LDA-ocSVM_sigmoid_neg    1957 non-null   float64
#  51  LDA-ocSVM_sigmoid_neu    1957 non-null   float64
#  52  LDA-ocSVM_sigmoid_pos    1957 non-null   float64
#  53  ocSVM_poly5_neg          1957 non-null   float64
#  54  ocSVM_poly5_neu          1957 non-null   float64
#  55  ocSVM_poly5_pos          1957 non-null   float64
#  56  ocSVM_poly5_LDA1         1957 non-null   float64
#  57  ocSVM_poly5_LDA2         1957 non-null   float64
#  58  LDA-ocSVM_poly5_neg      1957 non-null   float64
#  59  LDA-ocSVM_poly5_neu      1957 non-null   float64
#  60  LDA-ocSVM_poly5_pos      1957 non-null   float64
#  61  ocSVM_poly6_neg          1957 non-null   float64
#  62  ocSVM_poly6_neu          1957 non-null   float64
#  63  ocSVM_poly6_pos          1957 non-null   float64
#  64  ocSVM_poly6_LDA1         1957 non-null   float64
#  65  ocSVM_poly6_LDA2         1957 non-null   float64
#  66  LDA-ocSVM_poly6_neg      1957 non-null   float64
#  67  LDA-ocSVM_poly6_neu      1957 non-null   float64
#  68  LDA-ocSVM_poly6_pos      1957 non-null   float64
#  69  spherical-LDA1           1957 non-null   float64
#  70  spherical-LDA2           1957 non-null   float64
#  71  spherical-ocLDA_neg      1957 non-null   float64
#  72  spherical-ocLDA_neu      1957 non-null   float64
#  73  spherical-ocLDA_pos      1957 non-null   float64
# dtypes: float32(12), float64(62)
# memory usage: 1.0 MB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  ocSVM_poly6_LDA1  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...         -0.392961
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...         -0.328475
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...         -0.394055
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...         -1.222963
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...         -0.926832
#
#    ocSVM_poly6_LDA2  LDA-ocSVM_poly6_neg  LDA-ocSVM_poly6_neu  \
# 0          0.285280          1664.602412           395.325571
# 1          0.242286            38.293673             9.852249
# 2          0.343421           793.769504           235.463271
# 3          0.295605          5763.655093          1027.228634
# 4          0.356653          9696.335102          2153.740325
#
#    LDA-ocSVM_poly6_pos  spherical-LDA1  spherical-LDA2  spherical-ocLDA_neg  \
# 0            65.052503       -0.757583        0.159719             0.160947
# 1             1.475788       -0.771626        0.078771             0.240286
# 2            26.652357       -0.639456        0.024716             0.236040
# 3           185.923277       -0.920840        0.316908             0.083912
# 4           377.354692       -1.339164        0.386423             0.189782
#
#    spherical-ocLDA_neu  spherical-ocLDA_pos
# 0            -0.689767             0.515451
# 1            -0.724108             0.452851
# 2            -0.610498             0.340403
# 3            -0.806871             0.732102
# 4            -1.192547             1.000663
#
# [5 rows x 74 columns]
# time: 219 ms

# %%
data = pd.concat([df, sphericals], axis="columns")
spot_check(data, labels)
_ = gc_collect()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Columns: 118 entries, LDA1 to phi_LDA-ocSVM_poly6_neg+LDA-ocSVM_poly6_neu+LDA-ocSVM_poly6_pos
# dtypes: float32(20), float64(98)
# memory usage: 1.6 MB
# None
#        LDA1      LDA2  ocLDA_neg  ocLDA_neu  ocLDA_pos  LOF_neg_10  \
# 0 -1.001496  1.190528  -0.258172  -0.947540   1.478330   -1.163084
# 1 -0.614103  0.555738  -0.027168  -0.588753   0.747540   -1.332296
# 2 -1.283616  0.439167   0.486838  -1.262689   0.903614   -1.078094
# 3 -0.174906  1.891036  -1.311590  -0.090789   1.793279   -1.503324
# 4 -1.165987  1.732043  -0.560913  -1.087816   2.036688   -1.188440
#
#    LOF_neu_10  LOF_pos_10  LOF_neg_20  LOF_neu_20  ...  \
# 0   -1.177876   -1.548195   -1.121199   -1.113991  ...
# 1   -1.296963   -1.413960   -1.240734   -1.276801  ...
# 2   -1.117705   -1.139015   -1.076433   -1.123352  ...
# 3   -1.251665   -1.578528   -1.404248   -1.214691  ...
# 4   -1.270247   -1.323458   -1.170957   -1.143541  ...
#
#    theta_ocSVM_poly5_neg+ocSVM_poly5_neu+ocSVM_poly5_pos  \
# 0                                           0.236955
# 1                                           0.238272
# 2                                           0.248262
# 3                                           0.229963
# 4                                           0.215748
#
#    phi_ocSVM_poly5_neg+ocSVM_poly5_neu+ocSVM_poly5_pos  \
# 0                                           1.206338
# 1                                           1.217777
# 2                                           1.208120
# 3                                           1.232911
# 4                                           1.219682
#
#    theta_ocSVM_poly5_LDA1+ocSVM_poly5_LDA2  \
# 0                                -0.574844
# 1                                -0.353619
# 2                                -0.689257
# 3                                -0.103535
# 4                                -0.227366
#
#    theta_LDA-ocSVM_poly5_neg+LDA-ocSVM_poly5_neu+LDA-ocSVM_poly5_pos  \
# 0                                          -1.570796
# 1                                          -1.570796
# 2                                          -1.570796
# 3                                          -1.570805
# 4                                          -1.570796
#
#    phi_LDA-ocSVM_poly5_neg+LDA-ocSVM_poly5_neu+LDA-ocSVM_poly5_pos  \
# 0                                           1.570796
# 1                                           1.570796
# 2                                           1.570796
# 3                                           1.570783
# 4                                           1.570796
#
#    theta_ocSVM_poly6_neg+ocSVM_poly6_neu+ocSVM_poly6_pos  \
# 0                                           0.223440
# 1                                           0.226308
# 2                                           0.237793
# 3                                           0.217880
# 4                                           0.202858
#
#    phi_ocSVM_poly6_neg+ocSVM_poly6_neu+ocSVM_poly6_pos  \
# 0                                           1.204146
# 1                                           1.204854
# 2                                           1.203616
# 3                                           1.232009
# 4                                           1.217804
#
#    theta_ocSVM_poly6_LDA1+ocSVM_poly6_LDA2  \
# 0                                 2.513645
# 1                                 2.506070
# 2                                 2.424746
# 3                                 2.904429
# 4                                 2.774251
#
#    theta_LDA-ocSVM_poly6_neg+LDA-ocSVM_poly6_neu+LDA-ocSVM_poly6_pos  \
# 0                                           0.233170
# 1                                           0.251820
# 2                                           0.288371
# 3                                           0.176373
# 4                                           0.218571
#
#    phi_LDA-ocSVM_poly6_neg+LDA-ocSVM_poly6_neu+LDA-ocSVM_poly6_pos
# 0                                           1.532792
# 1                                           1.533490
# 2                                           1.538617
# 3                                           1.539050
# 4                                           1.532823
#
# [5 rows x 118 columns]
# time: 153 ms

# %%
training_data = (
    pd.read_feather(
        f"../19.0-mic-extract_FRILL-based_features_from_full_data/unscaled_features_ready_for_selection.feather"
    )
    .set_index("id")
    .head(1)
)
assert len(data.columns) == len(training_data.columns)
assert set(data.columns) == set(training_data.columns)
data = data.loc[
    :, training_data.columns
]  # with the guarantee of the preceding assertion, ensure congruent column order
assert all(data.columns == training_data.columns)
del sphericals
del training_data
_ = gc_collect()
# Out:
# time: 209 ms

# %% [markdown]
# # Uniform scaling with quantile transformation (omitted)

# %%
# scaler = load_extractor("preselect_QTuni")
# data = pd.DataFrame(scaler.transform(data), columns=scaler.feature_names_in_)
# del scaler
_ = gc_collect()
spot_check(data, labels)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Columns: 118 entries, theta_LDA1+LDA2 to LDA-ocSVM_poly6_pos
# dtypes: float32(20), float64(98)
# memory usage: 1.6 MB
# None
#    theta_LDA1+LDA2  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0         2.270171                            -1.836805
# 1         2.406045                            -1.616909
# 2         2.811944                            -1.202803
# 3         1.663026                            -3.072482
# 4         2.163299                            -2.046872
#
#    phi_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0                           0.586375
# 1                           0.667643
# 2                           0.982068
# 3                           0.632624
# 4                           0.541106
#
#    theta_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10  \
# 0                                          -2.372771
# 1                                          -2.366813
# 2                                          -2.374460
# 3                                          -2.353551
# 4                                          -2.349717
#
#    phi_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10  \
# 0                                          2.203119
# 1                                          2.218946
# 2                                          2.178971
# 3                                          2.233436
# 4                                          2.205294
#
#    theta_LOF_neg_10+LOF_neu_10+LOF_pos_10  \
# 0                               -2.349876
# 1                               -2.369632
# 2                               -2.338157
# 3                               -2.447289
# 4                               -2.322934
#
#    phi_LOF_neg_10+LOF_neu_10+LOF_pos_10  \
# 0                              2.322760
# 1                              2.220962
# 2                              2.203633
# 3                              2.249757
# 4                              2.221186
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          -2.327462
# 1                                          -2.350703
# 2                                          -2.316605
# 3                                          -2.351299
# 4                                          -2.286041
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          2.172485
# 1                                          2.185424
# 2                                          2.153088
# 3                                          2.206230
# 4                                          2.137620
#
#    theta_LOF_neg_20+LOF_neu_20+LOF_pos_20  ...  LDA-ocSVM_poly5_neu  \
# 0                               -2.359419  ...          -208.929305
# 1                               -2.341869  ...           -11.617114
# 2                               -2.334869  ...          -218.639273
# 3                               -2.428448  ...           -12.043912
# 4                               -2.368039  ...          -708.255804
#
#    LDA-ocSVM_poly5_pos  ocSVM_poly6_neg  ocSVM_poly6_neu  ocSVM_poly6_pos  \
# 0             0.000039         3.070262         0.697668         1.209082
# 1             0.000001         2.707450         0.623396         1.064647
# 2             0.000010         3.560355         0.862953         1.409045
# 3             0.000163         6.571688         1.454933         2.371760
# 4             0.000229         5.016795         1.031890         1.887000
#
#    ocSVM_poly6_LDA1  ocSVM_poly6_LDA2  LDA-ocSVM_poly6_neg  \
# 0         -0.392961          0.285280          1664.602412
# 1         -0.328475          0.242286            38.293673
# 2         -0.394055          0.343421           793.769504
# 3         -1.222963          0.295605          5763.655093
# 4         -0.926832          0.356653          9696.335102
#
#    LDA-ocSVM_poly6_neu  LDA-ocSVM_poly6_pos
# 0           395.325571            65.052503
# 1             9.852249             1.475788
# 2           235.463271            26.652357
# 3          1027.228634           185.923277
# 4          2153.740325           377.354692
#
# [5 rows x 118 columns]
# time: 133 ms

# %%
data.columns = data.columns.astype(str)
data.to_feather(f"{OUT_FOLDER}/holdout_featurized.feather")
data = pd.read_feather(f"{OUT_FOLDER}/holdout_featurized.feather")
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957 entries, 0 to 1956
# Columns: 118 entries, theta_LDA1+LDA2 to LDA-ocSVM_poly6_pos
# dtypes: float32(20), float64(98)
# memory usage: 1.6 MB
#    theta_LDA1+LDA2  theta_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0         2.270171                            -1.836805
# 1         2.406045                            -1.616909
# 2         2.811944                            -1.202803
# 3         1.663026                            -3.072482
# 4         2.163299                            -2.046872
#
#    phi_ocLDA_neg+ocLDA_neu+ocLDA_pos  \
# 0                           0.586375
# 1                           0.667643
# 2                           0.982068
# 3                           0.632624
# 4                           0.541106
#
#    theta_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10  \
# 0                                          -2.372771
# 1                                          -2.366813
# 2                                          -2.374460
# 3                                          -2.353551
# 4                                          -2.349717
#
#    phi_LDA-LOF_neg_10+LDA-LOF_neu_10+LDA-LOF_pos_10  \
# 0                                          2.203119
# 1                                          2.218946
# 2                                          2.178971
# 3                                          2.233436
# 4                                          2.205294
#
#    theta_LOF_neg_10+LOF_neu_10+LOF_pos_10  \
# 0                               -2.349876
# 1                               -2.369632
# 2                               -2.338157
# 3                               -2.447289
# 4                               -2.322934
#
#    phi_LOF_neg_10+LOF_neu_10+LOF_pos_10  \
# 0                              2.322760
# 1                              2.220962
# 2                              2.203633
# 3                              2.249757
# 4                              2.221186
#
#    theta_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          -2.327462
# 1                                          -2.350703
# 2                                          -2.316605
# 3                                          -2.351299
# 4                                          -2.286041
#
#    phi_LDA-LOF_neg_20+LDA-LOF_neu_20+LDA-LOF_pos_20  \
# 0                                          2.172485
# 1                                          2.185424
# 2                                          2.153088
# 3                                          2.206230
# 4                                          2.137620
#
#    theta_LOF_neg_20+LOF_neu_20+LOF_pos_20  ...  LDA-ocSVM_poly5_neu  \
# 0                               -2.359419  ...          -208.929305
# 1                               -2.341869  ...           -11.617114
# 2                               -2.334869  ...          -218.639273
# 3                               -2.428448  ...           -12.043912
# 4                               -2.368039  ...          -708.255804
#
#    LDA-ocSVM_poly5_pos  ocSVM_poly6_neg  ocSVM_poly6_neu  ocSVM_poly6_pos  \
# 0             0.000039         3.070262         0.697668         1.209082
# 1             0.000001         2.707450         0.623396         1.064647
# 2             0.000010         3.560355         0.862953         1.409045
# 3             0.000163         6.571688         1.454933         2.371760
# 4             0.000229         5.016795         1.031890         1.887000
#
#    ocSVM_poly6_LDA1  ocSVM_poly6_LDA2  LDA-ocSVM_poly6_neg  \
# 0         -0.392961          0.285280          1664.602412
# 1         -0.328475          0.242286            38.293673
# 2         -0.394055          0.343421           793.769504
# 3         -1.222963          0.295605          5763.655093
# 4         -0.926832          0.356653          9696.335102
#
#    LDA-ocSVM_poly6_neu  LDA-ocSVM_poly6_pos
# 0           395.325571            65.052503
# 1             9.852249             1.475788
# 2           235.463271            26.652357
# 3          1027.228634           185.923277
# 4          2153.740325           377.354692
#
# [5 rows x 118 columns]
# time: 121 ms

# %% [markdown]
# # Discussion

# %% [markdown]
# Now that we have the features, let's evaluate them in the next notebook.

# %%
print(f"Time elapsed since notebook_begin_time: {time() - notebook_begin_time} s")
_ = gc_collect()
# Out:
# Time elapsed since notebook_begin_time: 486.60900688171387 s
# time: 104 ms

# %% [markdown]
# [^top](#Contents)
